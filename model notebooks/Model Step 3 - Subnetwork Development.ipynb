# %% [markdown]
# ### Notebook Overview: Model Step 3 – Subnetwork Development
#
# This notebook constructs illicit-only subnetworks from the classified Bitcoin transaction dataset. It represents the third stage of the AML detection pipeline and operationalises the subgraph extraction methodology described in the thesis. The goal is to isolate self-contained clusters of illicit activity that can be further analysed and ranked.
#
# **Purpose**
# The notebook transforms the classified transaction data into directed graph structures that reflect the movement of Bitcoin between transactions. Starting from transactions predicted as illicit, a forward breadth-first search (BFS) expansion identifies all reachable transactions, creating a self-contained subnetwork that captures the flow of funds within that illicit cluster.
#
# **Key Steps**
# - Import transaction predictions and edgelist data from BigQuery.
# - Filter to include only transactions classified as illicit.
# - Use a directed graph representation (txn–txn) to model Bitcoin flows between transactions.
# - Perform a forward BFS from each illicit transaction to trace all connected downstream nodes.
# - Assign unique Subnetwork IDs and compute basic graph properties (e.g., size, node/edge count, total BTC transferred).
# - Export subnetwork tables to BigQuery for ranking and visualisation in the next stage.
#
# This process produces a collection of reproducible subnetworks that represent individual clusters of illicit Bitcoin activity. By isolating and structuring these networks, subsequent ranking and visualisation can focus on the most influential or financially significant regions of the transaction graph.
#
# **Context and Attribution**
# This notebook forms part of the technical work developed in support of the research thesis titled:
# _“Detection, Ranking and Visualisation of Money Laundering Networks on the Bitcoin Blockchain”_
# by Jennifer Payne (RMIT University).
#
# GitHub Repository: [https://github.com/majorpayne-2021/rmit_master_thesis](https://github.com/majorpayne-2021/rmit_master_thesis)
# Elliptic++ Dataset Source: [https://github.com/git-disl/EllipticPlusPlus](https://github.com/git-disl/EllipticPlusPlus)

# %%
# Data cleaning and manipulation
import pandas as pd
import numpy as np
import math
import time

# GCP libraries
from pandas_gbq import to_gbq # write pandas df to a GCP BigQuery table
import gcsfs
import importlib.util
import os
import inspect

# Set up display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# Suppress FutureWarnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# --------------
# ##### Read in Txn Subnetwork Classes & Modules
# --------------

# %%
# Define bucket and file path
bucket_name = "thesis_classes"
file_name = "txn_subnetworks.py"
gcs_path = f"gs://{bucket_name}/{file_name}"

# Initialize GCS filesystem
fs = gcsfs.GCSFileSystem()

# Local filename to save the script temporarily
local_file = f"/tmp/{file_name}"

# Download the file from GCS to local storage
fs.get(gcs_path, local_file)

# Dynamically import the module
module_name = "txn_subnetworks"
spec = importlib.util.spec_from_file_location(module_name, local_file)
module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(module)

# %%
# Use inspect to get classes and functions
classes = [name for name, obj in inspect.getmembers(module, inspect.isclass)]

# Print results
print("Classes in module:")
for cls in classes:
    print(f"  - {cls}")
# Out:
# Classes in module:
#   - Line2D
#   - build_txn_subnetwork
#   - combinations
#   - defaultdict
#   - reporting
#   - visualise_subnetwork

# %%
# Instantiate the classes
build_network = module.build_txn_subnetwork()
build_report = module.reporting()

# %% [markdown]
# --------------
# ##### Read in Datasets
# --------------

# %%
# Get txn edgelist
# %%bigquery df_txn_edgelist
select * from `extreme-torch-467913-m6.txn.txn_edgelist`;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df_txn_edgelist.head(1)
# Out:
#       txId1  txId2
# 0  36186840   1076

# %%
# get txn prediction
# %%bigquery df_txn_pred
select * from `extreme-torch-467913-m6.txn.txn_pred_final`;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df_txn_pred.head(1)
# Out:
#         txId  Time step  class class_label     pred_model  \
# 0  230550390          1      2       Licit  Random Forest
#
#    pred_model_threshold  pred_proba  pred_class pred_class_label  final_class  \
# 0                0.3000      0.0932           0            Licit            0
#
#   final_class_label
# 0             Licit

# %%
list_illicit_seeds = df_txn_pred[(df_txn_pred['final_class_label'] == 'Illicit')]['txId'].tolist()

# %%
len(list_illicit_seeds)
# Out:
# 49707

# %% [markdown]
# --------------
# ##### Build Subnetworks for all Illicit Nodes
# --------------

# %% [markdown]
# Build subnetwork

# %%
start_time = time.time()

# 1) Build naive (possibly overlapping) subnetworks per seed
nodes_all, edges_all = build_network.build_subnetworks_naive(
    edges_df=df_txn_edgelist,
    labels_df=df_txn_pred,
    seed_txns=list_illicit_seeds,
    progress=True,
    progress_every=1000,   # summary every 100 seeds
)

end_time = time.time()
elapsed_minutes = (end_time - start_time) / 60
print(f"Function took {elapsed_minutes:.2f} minutes")
# Out:
# Commencing subnetwork development from seed nodes. seeds=49707  update_per_batch=1000
# [  1000/49707] single node network: 699  |  multi-node network: 301  (cumulative single: 699, multi: 301)  largest_nodes=9 (seed=15012776)
# [  2000/49707] single node network: 756  |  multi-node network: 244  (cumulative single: 1455, multi: 545)  largest_nodes=9 (seed=15012776)
# [  3000/49707] single node network: 716  |  multi-node network: 284  (cumulative single: 2171, multi: 829)  largest_nodes=23 (seed=226358329)
# [  4000/49707] single node network: 682  |  multi-node network: 318  (cumulative single: 2853, multi: 1147)  largest_nodes=23 (seed=226358329)
# [  5000/49707] single node network: 636  |  multi-node network: 364  (cumulative single: 3489, multi: 1511)  largest_nodes=23 (seed=226358329)
# [  6000/49707] single node network: 581  |  multi-node network: 419  (cumulative single: 4070, multi: 1930)  largest_nodes=24 (seed=175050552)
# [  7000/49707] single node network: 781  |  multi-node network: 219  (cumulative single: 4851, multi: 2149)  largest_nodes=24 (seed=175050552)
# [  8000/49707] single node network: 633  |  multi-node network: 367  (cumulative single: 5484, multi: 2516)  largest_nodes=29 (seed=234890828)
# [  9000/49707] single node network: 544  |  multi-node network: 456  (cumulative single: 6028, multi: 2972)  largest_nodes=29 (seed=234890828)
# [ 10000/49707] single node network: 546  |  multi-node network: 454  (cumulative single: 6574, multi: 3426)  largest_nodes=29 (seed=234890828)
# [ 11000/49707] single node network: 619  |  multi-node network: 381  (cumulative single: 7193, multi: 3807)  largest_nodes=29 (seed=234890828)
# [ 12000/49707] single node network: 617  |  multi-node network: 383  (cumulative single: 7810, multi: 4190)  largest_nodes=29 (seed=234890828)
# [ 13000/49707] single node network: 578  |  multi-node network: 422  (cumulative single: 8388, multi: 4612)  largest_nodes=29 (seed=234890828)
# [ 14000/49707] single node network: 512  |  multi-node network: 488  (cumulative single: 8900, multi: 5100)  largest_nodes=34 (seed=248886883)
# [ 15000/49707] single node network: 510  |  multi-node network: 490  (cumulative single: 9410, multi: 5590)  largest_nodes=34 (seed=248886883)
# [ 16000/49707] single node network: 509  |  multi-node network: 491  (cumulative single: 9919, multi: 6081)  largest_nodes=34 (seed=248886883)
# [ 17000/49707] single node network: 527  |  multi-node network: 473  (cumulative single: 10446, multi: 6554)  largest_nodes=34 (seed=248886883)
# [ 18000/49707] single node network: 455  |  multi-node network: 545  (cumulative single: 10901, multi: 7099)  largest_nodes=66 (seed=344492255)
# [ 19000/49707] single node network: 261  |  multi-node network: 739  (cumulative single: 11162, multi: 7838)  largest_nodes=71 (seed=372530534)
# [ 20000/49707] single node network: 365  |  multi-node network: 635  (cumulative single: 11527, multi: 8473)  largest_nodes=71 (seed=372530534)
# [ 21000/49707] single node network: 487  |  multi-node network: 513  (cumulative single: 12014, multi: 8986)  largest_nodes=71 (seed=372530534)
# [ 22000/49707] single node network: 443  |  multi-node network: 557  (cumulative single: 12457, multi: 9543)  largest_nodes=71 (seed=372530534)
# [ 23000/49707] single node network: 380  |  multi-node network: 620  (cumulative single: 12837, multi: 10163)  largest_nodes=71 (seed=372530534)
# [ 24000/49707] single node network: 417  |  multi-node network: 583  (cumulative single: 13254, multi: 10746)  largest_nodes=71 (seed=372530534)
# [ 25000/49707] single node network: 396  |  multi-node network: 604  (cumulative single: 13650, multi: 11350)  largest_nodes=71 (seed=372530534)
# [ 26000/49707] single node network: 470  |  multi-node network: 530  (cumulative single: 14120, multi: 11880)  largest_nodes=71 (seed=372530534)
# [ 27000/49707] single node network: 406  |  multi-node network: 594  (cumulative single: 14526, multi: 12474)  largest_nodes=71 (seed=372530534)
# [ 28000/49707] single node network: 400  |  multi-node network: 600  (cumulative single: 14926, multi: 13074)  largest_nodes=183 (seed=46085970)
# [ 29000/49707] single node network: 376  |  multi-node network: 624  (cumulative single: 15302, multi: 13698)  largest_nodes=183 (seed=46085970)
# [ 30000/49707] single node network: 587  |  multi-node network: 413  (cumulative single: 15889, multi: 14111)  largest_nodes=183 (seed=46085970)
# [ 31000/49707] single node network: 465  |  multi-node network: 535  (cumulative single: 16354, multi: 14646)  largest_nodes=183 (seed=46085970)
# [ 32000/49707] single node network: 471  |  multi-node network: 529  (cumulative single: 16825, multi: 15175)  largest_nodes=183 (seed=46085970)
# [ 33000/49707] single node network: 624  |  multi-node network: 376  (cumulative single: 17449, multi: 15551)  largest_nodes=183 (seed=46085970)
# [ 34000/49707] single node network: 654  |  multi-node network: 346  (cumulative single: 18103, multi: 15897)  largest_nodes=183 (seed=46085970)
# [ 35000/49707] single node network: 642  |  multi-node network: 358  (cumulative single: 18745, multi: 16255)  largest_nodes=183 (seed=46085970)
# [ 36000/49707] single node network: 555  |  multi-node network: 445  (cumulative single: 19300, multi: 16700)  largest_nodes=183 (seed=46085970)
# [ 37000/49707] single node network: 676  |  multi-node network: 324  (cumulative single: 19976, multi: 17024)  largest_nodes=183 (seed=46085970)
# [ 38000/49707] single node network: 624  |  multi-node network: 376  (cumulative single: 20600, multi: 17400)  largest_nodes=183 (seed=46085970)
# [ 39000/49707] single node network: 644  |  multi-node network: 356  (cumulative single: 21244, multi: 17756)  largest_nodes=183 (seed=46085970)
# [ 40000/49707] single node network: 510  |  multi-node network: 490  (cumulative single: 21754, multi: 18246)  largest_nodes=183 (seed=46085970)
# [ 41000/49707] single node network: 663  |  multi-node network: 337  (cumulative single: 22417, multi: 18583)  largest_nodes=183 (seed=46085970)
# [ 42000/49707] single node network: 503  |  multi-node network: 497  (cumulative single: 22920, multi: 19080)  largest_nodes=183 (seed=46085970)
# [ 43000/49707] single node network: 590  |  multi-node network: 410  (cumulative single: 23510, multi: 19490)  largest_nodes=183 (seed=46085970)
# [ 44000/49707] single node network: 612  |  multi-node network: 388  (cumulative single: 24122, multi: 19878)  largest_nodes=183 (seed=46085970)
# [ 45000/49707] single node network: 674  |  multi-node network: 326  (cumulative single: 24796, multi: 20204)  largest_nodes=183 (seed=46085970)
# [ 46000/49707] single node network: 658  |  multi-node network: 342  (cumulative single: 25454, multi: 20546)  largest_nodes=183 (seed=46085970)
# [ 47000/49707] single node network: 712  |  multi-node network: 288  (cumulative single: 26166, multi: 20834)  largest_nodes=183 (seed=46085970)
# [ 48000/49707] single node network: 485  |  multi-node network: 515  (cumulative single: 26651, multi: 21349)  largest_nodes=183 (seed=46085970)
# [ 49000/49707] single node network: 520  |  multi-node network: 480  (cumulative single: 27171, multi: 21829)  largest_nodes=183 (seed=46085970)
# Seed list scanning is now complete. seeds=49707  single node network=27549 (55.4%)  multi-node network=22158 (44.6%)  largest_nodes=183 (seed=46085970)
# Function took 80.27 minutes

# %% [markdown]
# Deduplicate subnetworks which are a subset of a larger subnetwork

# %%
# 2) Deduplicate: drop any subnetwork whose node set is a subset of another
nodes_dedup, edges_dedup, dedup_report, id_map = build_network.deduplicate_subnetworks_by_node_subset(
    nodes_all, edges_all, relabel=False, progress=True
)
# Out:
# Dedup by node-subset: 49707 → 32507 subnetworks kept (17200 removed).
#   - drop 5 (seed=230472386) ⊆ kept 258 (seed=230472385)
#   - drop 11 (seed=230543020) ⊆ kept 340 (seed=230543016)
#   - drop 15 (seed=16843895) ⊆ kept 500 (seed=230456346)
#   - drop 20 (seed=232038046) ⊆ kept 271 (seed=230464746)
#   - drop 49 (seed=91787015) ⊆ kept 270 (seed=230586841)
#   - drop 52 (seed=232375025) ⊆ kept 309 (seed=230451709)
#   - drop 56 (seed=144657595) ⊆ kept 290 (seed=231994074)
#   - drop 59 (seed=231994234) ⊆ kept 165 (seed=231994227)
#   - drop 60 (seed=76867000) ⊆ kept 230 (seed=230645551)
#   - drop 61 (seed=230456370) ⊆ kept 157 (seed=230521240)
#   - drop 62 (seed=87889638) ⊆ kept 230 (seed=230645551)
#   - drop 67 (seed=226715158) ⊆ kept 48 (seed=232008935)
#   - drop 70 (seed=233997270) ⊆ kept 240 (seed=232359167)
#   - drop 79 (seed=231994244) ⊆ kept 165 (seed=231994227)
#   - drop 80 (seed=2718109) ⊆ kept 156 (seed=230330936)
#   - drop 81 (seed=81270783) ⊆ kept 133 (seed=81273866)
#   - drop 85 (seed=230789891) ⊆ kept 146 (seed=232354179)
#   - drop 87 (seed=232345695) ⊆ kept 159 (seed=232364856)
#   - drop 98 (seed=230330969) ⊆ kept 184 (seed=230330962)
#   - drop 99 (seed=231994241) ⊆ kept 165 (seed=231994227)
#   - drop 107 (seed=233997266) ⊆ kept 240 (seed=232359167)
#   - drop 108 (seed=2755110) ⊆ kept 304 (seed=232349061)
#   - drop 110 (seed=230586765) ⊆ kept 156 (seed=230330936)
#   - drop 113 (seed=232633987) ⊆ kept 304 (seed=232349061)
#   - drop 115 (seed=230643071) ⊆ kept 304 (seed=232349061)
#   - drop 121 (seed=230582115) ⊆ kept 92 (seed=231994199)
#   - drop 124 (seed=37232608) ⊆ kept 184 (seed=230330962)
#   - drop 125 (seed=60492142) ⊆ kept 248 (seed=231994189)
#   - drop 126 (seed=230456367) ⊆ kept 157 (seed=230521240)
#   - drop 127 (seed=230586846) ⊆ kept 270 (seed=230586841)
#   - drop 136 (seed=232437270) ⊆ kept 118 (seed=232890478)
#   - drop 143 (seed=230402464) ⊆ kept 77 (seed=2712012)
#   - drop 145 (seed=231994103) ⊆ kept 131 (seed=231994093)
#   - drop 148 (seed=53204177) ⊆ kept 232 (seed=232895769)
#   - drop 149 (seed=81270780) ⊆ kept 133 (seed=81273866)
#   - drop 150 (seed=91224338) ⊆ kept 184 (seed=230330962)
#   - drop 154 (seed=53204033) ⊆ kept 232 (seed=232895769)
#   - drop 158 (seed=230540205) ⊆ kept 240 (seed=232359167)
#   - drop 162 (seed=62111535) ⊆ kept 159 (seed=232364856)
#   - drop 163 (seed=230402461) ⊆ kept 77 (seed=2712012)
#   - drop 166 (seed=232431919) ⊆ kept 201 (seed=232007290)
#   - drop 169 (seed=22508445) ⊆ kept 132 (seed=232366613)
#   - drop 172 (seed=38793679) ⊆ kept 120 (seed=198356667)
#   - drop 176 (seed=13963119) ⊆ kept 183 (seed=232423037)
#   - drop 177 (seed=230330975) ⊆ kept 184 (seed=230330962)
#   - drop 179 (seed=185535373) ⊆ kept 123 (seed=2713814)
#   - drop 185 (seed=230569374) ⊆ kept 147 (seed=31730193)
#   - drop 187 (seed=232404317) ⊆ kept 216 (seed=232949014)
#   - drop 188 (seed=230401741) ⊆ kept 178 (seed=230401735)
#   - drop 189 (seed=234431154) ⊆ kept 134 (seed=3688992)
#   - drop 196 (seed=232377194) ⊆ kept 68 (seed=230331777)
#   - drop 198 (seed=81270779) ⊆ kept 303 (seed=230586770)
#   - drop 199 (seed=231994202) ⊆ kept 92 (seed=231994199)
#   - drop 202 (seed=232375027) ⊆ kept 309 (seed=230451709)
#   - drop 203 (seed=232008934) ⊆ kept 48 (seed=232008935)
#   - drop 204 (seed=232404316) ⊆ kept 216 (seed=232949014)
#   - drop 207 (seed=231994080) ⊆ kept 290 (seed=231994074)
#   - drop 209 (seed=230645348) ⊆ kept 219 (seed=230645343)
#   - drop 213 (seed=231036666) ⊆ kept 235 (seed=35761910)
#   - drop 215 (seed=230401687) ⊆ kept 66 (seed=93274562)
#   - drop 218 (seed=58140282) ⊆ kept 75 (seed=232634240)
#   - drop 222 (seed=230659438) ⊆ kept 73 (seed=230340242)
#   - drop 224 (seed=230401350) ⊆ kept 66 (seed=93274562)
#   - drop 227 (seed=232608734) ⊆ kept 240 (seed=232359167)
#   - drop 228 (seed=86711289) ⊆ kept 170 (seed=231994205)
#   - drop 231 (seed=230814629) ⊆ kept 131 (seed=231994093)
#   - drop 234 (seed=232027325) ⊆ kept 191 (seed=232629400)
#   - drop 236 (seed=230402452) ⊆ kept 91 (seed=230402450)
#   - drop 238 (seed=230586868) ⊆ kept 286 (seed=53204358)
#   - drop 239 (seed=231994110) ⊆ kept 123 (seed=2713814)
#   - drop 242 (seed=232662128) ⊆ kept 229 (seed=89871612)
#   - drop 243 (seed=32484448) ⊆ kept 290 (seed=231994074)
#   - drop 249 (seed=2302253) ⊆ kept 248 (seed=231994189)
#   - drop 250 (seed=53204038) ⊆ kept 232 (seed=232895769)
#   - drop 253 (seed=232895350) ⊆ kept 132 (seed=232366613)
#   - drop 259 (seed=183378998) ⊆ kept 264 (seed=82950160)
#   - drop 260 (seed=230401717) ⊆ kept 66 (seed=93274562)
#   - drop 263 (seed=53637885) ⊆ kept 147 (seed=31730193)
#   - drop 265 (seed=230422101) ⊆ kept 308 (seed=230422103)
#   - drop 275 (seed=232895760) ⊆ kept 103 (seed=232895633)
#   - drop 276 (seed=230400936) ⊆ kept 287 (seed=230400933)
#   - drop 277 (seed=231994232) ⊆ kept 165 (seed=231994227)
#   - drop 278 (seed=51571237) ⊆ kept 240 (seed=232359167)
#   - drop 280 (seed=7547833) ⊆ kept 201 (seed=232007290)
#   - drop 283 (seed=230400865) ⊆ kept 138 (seed=230569371)
#   - drop 285 (seed=230451671) ⊆ kept 200 (seed=231994024)
#   - drop 288 (seed=231994184) ⊆ kept 305 (seed=13327496)
#   - drop 292 (seed=232634213) ⊆ kept 86 (seed=2893829)
#   - drop 296 (seed=232404256) ⊆ kept 103 (seed=232895633)
#   - drop 297 (seed=91416769) ⊆ kept 147 (seed=31730193)
#   - drop 300 (seed=232895771) ⊆ kept 232 (seed=232895769)
#   - drop 307 (seed=82937696) ⊆ kept 290 (seed=231994074)
#   - drop 312 (seed=2716232) ⊆ kept 71 (seed=2714634)
#   - drop 322 (seed=76864772) ⊆ kept 420 (seed=75597534)
#   - drop 330 (seed=76864766) ⊆ kept 359 (seed=75597414)
#   - drop 337 (seed=76866754) ⊆ kept 334 (seed=76865952)
#   - drop 352 (seed=75605130) ⊆ kept 413 (seed=75604437)
#   - drop 356 (seed=75601042) ⊆ kept 357 (seed=75600712)
#   - drop 372 (seed=76865990) ⊆ kept 423 (seed=75598324)
#   - drop 378 (seed=76867009) ⊆ kept 423 (seed=75598324)
#   - drop 379 (seed=75604985) ⊆ kept 370 (seed=75604435)
#   - drop 398 (seed=76867013) ⊆ kept 376 (seed=76866368)
#   - drop 404 (seed=75598035) ⊆ kept 380 (seed=75600864)
#   - drop 409 (seed=75598038) ⊆ kept 412 (seed=75600868)
#   - drop 410 (seed=75601028) ⊆ kept 434 (seed=232067342)
#   - drop 417 (seed=76866764) ⊆ kept 325 (seed=76865975)
#   - drop 425 (seed=75598645) ⊆ kept 399 (seed=75597407)
#   - drop 426 (seed=75601037) ⊆ kept 355 (seed=75600707)
#   - drop 427 (seed=75597531) ⊆ kept 362 (seed=75600734)
#   - drop 445 (seed=232068046) ⊆ kept 363 (seed=75604061)
#   - drop 450 (seed=232374913) ⊆ kept 191 (seed=232629400)
#   - drop 452 (seed=232376720) ⊆ kept 144 (seed=231992552)
#   - drop 460 (seed=33176841) ⊆ kept 77 (seed=2712012)
#   - drop 479 (seed=232349148) ⊆ kept 190 (seed=12780016)
#   - drop 482 (seed=3159656) ⊆ kept 462 (seed=86352592)
#   - drop 490 (seed=230524948) ⊆ kept 476 (seed=232472560)
#   - drop 495 (seed=230436765) ⊆ kept 383 (seed=75601049)
#   - drop 506 (seed=79871665) ⊆ kept 155 (seed=123661757)
#   - drop 508 (seed=232686668) ⊆ kept 627 (seed=230473474)
#   - drop 512 (seed=230440152) ⊆ kept 191 (seed=232629400)
#   - drop 516 (seed=230549076) ⊆ kept 496 (seed=230547944)
#   - drop 518 (seed=230658142) ⊆ kept 73 (seed=230340242)
#   - drop 519 (seed=43560505) ⊆ kept 105 (seed=230344662)
#   - drop 520 (seed=27405707) ⊆ kept 73 (seed=230340242)
#   - drop 523 (seed=75603986) ⊆ kept 538 (seed=79480955)
#   - drop 524 (seed=232070567) ⊆ kept 542 (seed=231473071)
#   - drop 527 (seed=232000573) ⊆ kept 535 (seed=232000574)
#   - drop 530 (seed=231136221) ⊆ kept 544 (seed=14407957)
#   - drop 531 (seed=35125414) ⊆ kept 545 (seed=231184466)
#   - drop 532 (seed=232340237) ⊆ kept 541 (seed=232340238)
#   - drop 534 (seed=233393437) ⊆ kept 537 (seed=232688102)
#   - drop 539 (seed=5119724) ⊆ kept 540 (seed=212382148)
#   - drop 550 (seed=87889652) ⊆ kept 556 (seed=231193618)
#   - drop 551 (seed=3880946) ⊆ kept 558 (seed=81421232)
#   - drop 564 (seed=17863556) ⊆ kept 17 (seed=232455961)
#   - drop 565 (seed=231264468) ⊆ kept 570 (seed=232899517)
#   - drop 566 (seed=234494896) ⊆ kept 472 (seed=232959351)
#   - drop 569 (seed=231264467) ⊆ kept 570 (seed=232899517)
#   - drop 580 (seed=230427466) ⊆ kept 581 (seed=178273573)
#   - drop 584 (seed=138186597) ⊆ kept 581 (seed=178273573)
#   - drop 592 (seed=52434550) ⊆ kept 598 (seed=230593153)
#   - drop 596 (seed=203423879) ⊆ kept 598 (seed=230593153)
#   - drop 602 (seed=232023197) ⊆ kept 612 (seed=230805627)
#   - drop 606 (seed=230530302) ⊆ kept 612 (seed=230805627)
#   - drop 607 (seed=230531151) ⊆ kept 612 (seed=230805627)
#   - drop 608 (seed=55924498) ⊆ kept 616 (seed=72390341)
#   - drop 609 (seed=232010801) ⊆ kept 612 (seed=230805627)
#   - drop 610 (seed=160252749) ⊆ kept 615 (seed=232902867)
#   - drop 613 (seed=87395840) ⊆ kept 612 (seed=230805627)
#   - drop 617 (seed=31190284) ⊆ kept 612 (seed=230805627)
#   - drop 624 (seed=75604077) ⊆ kept 626 (seed=230590958)
#   - drop 628 (seed=232655296) ⊆ kept 627 (seed=230473474)
#   - drop 629 (seed=32877982) ⊆ kept 623 (seed=230409257)
#   - drop 630 (seed=230428210) ⊆ kept 631 (seed=230425284)
#   - drop 634 (seed=83431059) ⊆ kept 631 (seed=230425284)
#   - drop 635 (seed=232686665) ⊆ kept 627 (seed=230473474)
#   - drop 638 (seed=230417055) ⊆ kept 658 (seed=230593193)
#   - drop 642 (seed=76865406) ⊆ kept 654 (seed=232009156)
#   - drop 643 (seed=232897337) ⊆ kept 652 (seed=42479462)
#   - drop 644 (seed=230425996) ⊆ kept 654 (seed=232009156)
#   - drop 645 (seed=75600739) ⊆ kept 650 (seed=232004810)
#   - drop 647 (seed=176351469) ⊆ kept 662 (seed=230427468)
#   - drop 648 (seed=230417569) ⊆ kept 640 (seed=75604392)
#   - drop 649 (seed=232003676) ⊆ kept 658 (seed=230593193)
#   - drop 651 (seed=227540127) ⊆ kept 640 (seed=75604392)
#   - drop 655 (seed=232431863) ⊆ kept 640 (seed=75604392)
#   - drop 656 (seed=31178240) ⊆ kept 652 (seed=42479462)
#   - drop 657 (seed=230425992) ⊆ kept 654 (seed=232009156)
#   - drop 660 (seed=231263589) ⊆ kept 640 (seed=75604392)
#   - drop 664 (seed=234439569) ⊆ kept 662 (seed=230427468)
#   - drop 667 (seed=234472023) ⊆ kept 677 (seed=234442472)
#   - drop 669 (seed=232413175) ⊆ kept 677 (seed=234442472)
#   - drop 670 (seed=230594125) ⊆ kept 681 (seed=230594114)
#   - drop 671 (seed=232007419) ⊆ kept 627 (seed=230473474)
#   - drop 676 (seed=81167039) ⊆ kept 681 (seed=230594114)
#   - drop 678 (seed=230594099) ⊆ kept 675 (seed=230594094)
#   - drop 679 (seed=230593845) ⊆ kept 672 (seed=89914148)
#   - drop 680 (seed=230594121) ⊆ kept 681 (seed=230594114)
#   - drop 682 (seed=234472020) ⊆ kept 677 (seed=234442472)
#   - drop 686 (seed=79840192) ⊆ kept 695 (seed=230528718)
#   - drop 689 (seed=6595740) ⊆ kept 695 (seed=230528718)
#   - drop 690 (seed=232018284) ⊆ kept 688 (seed=230590626)
#   - drop 691 (seed=230415011) ⊆ kept 688 (seed=230590626)
#   - drop 692 (seed=230415013) ⊆ kept 688 (seed=230590626)
#   - drop 696 (seed=233101918) ⊆ kept 722 (seed=230415432)
#   - drop 697 (seed=76866421) ⊆ kept 722 (seed=230415432)
#   - drop 699 (seed=232010159) ⊆ kept 700 (seed=230333889)
#   - drop 701 (seed=75598034) ⊆ kept 707 (seed=230468697)
#   - drop 705 (seed=31636038) ⊆ kept 703 (seed=234469371)
#   - drop 706 (seed=230424193) ⊆ kept 718 (seed=230424188)
#   - drop 709 (seed=79340428) ⊆ kept 718 (seed=230424188)
#   - drop 710 (seed=232658521) ⊆ kept 719 (seed=232658519)
#   - drop 712 (seed=63454082) ⊆ kept 722 (seed=230415432)
#   - drop 713 (seed=230417075) ⊆ kept 700 (seed=230333889)
#   - drop 714 (seed=230417077) ⊆ kept 700 (seed=230333889)
#   - drop 720 (seed=232431871) ⊆ kept 703 (seed=234469371)
#   - drop 725 (seed=232897397) ⊆ kept 731 (seed=28406373)
#   - drop 726 (seed=75598439) ⊆ kept 727 (seed=75598031)
#   - drop 735 (seed=232014177) ⊆ kept 736 (seed=230334382)
#   - drop 738 (seed=230423014) ⊆ kept 736 (seed=230334382)
#   - drop 739 (seed=16407238) ⊆ kept 736 (seed=230334382)
#   - drop 740 (seed=232431906) ⊆ kept 736 (seed=230334382)
#   - drop 741 (seed=76865962) ⊆ kept 746 (seed=61820358)
#   - drop 744 (seed=232897359) ⊆ kept 742 (seed=75600733)
#   - drop 745 (seed=232949013) ⊆ kept 742 (seed=75600733)
#   - drop 747 (seed=113900112) ⊆ kept 742 (seed=75600733)
#   - drop 748 (seed=101765418) ⊆ kept 742 (seed=75600733)
#   - drop 749 (seed=225944002) ⊆ kept 750 (seed=34031118)
#   - drop 751 (seed=91794795) ⊆ kept 742 (seed=75600733)
#   - drop 754 (seed=75600709) ⊆ kept 755 (seed=230333927)
#   - drop 757 (seed=75600751) ⊆ kept 762 (seed=232004428)
#   - drop 761 (seed=232403829) ⊆ kept 758 (seed=232431866)
#   - drop 765 (seed=120695667) ⊆ kept 755 (seed=230333927)
#   - drop 766 (seed=232004444) ⊆ kept 755 (seed=230333927)
#   - drop 771 (seed=31175224) ⊆ kept 769 (seed=232018188)
#   - drop 772 (seed=232897353) ⊆ kept 773 (seed=200614200)
#   - drop 775 (seed=82927541) ⊆ kept 776 (seed=230336176)
#   - drop 780 (seed=232403825) ⊆ kept 779 (seed=76865985)
#   - drop 784 (seed=232004062) ⊆ kept 785 (seed=75605325)
#   - drop 791 (seed=71597253) ⊆ kept 789 (seed=230425274)
#   - drop 796 (seed=230425290) ⊆ kept 801 (seed=61923904)
#   - drop 798 (seed=76865412) ⊆ kept 797 (seed=75600755)
#   - drop 803 (seed=51077588) ⊆ kept 797 (seed=75600755)
#   - drop 804 (seed=230425547) ⊆ kept 797 (seed=75600755)
#   - drop 805 (seed=76864767) ⊆ kept 807 (seed=230406773)
#   - drop 808 (seed=232431856) ⊆ kept 807 (seed=230406773)
#   - drop 813 (seed=62195631) ⊆ kept 241 (seed=232658952)
#   - drop 819 (seed=230428191) ⊆ kept 822 (seed=230428187)
#   - drop 821 (seed=20924225) ⊆ kept 822 (seed=230428187)
#   - drop 824 (seed=230428237) ⊆ kept 822 (seed=230428187)
#   - drop 831 (seed=232893748) ⊆ kept 839 (seed=15012776)
#   - drop 832 (seed=230580682) ⊆ kept 839 (seed=15012776)
#   - drop 833 (seed=232367893) ⊆ kept 839 (seed=15012776)
#   - drop 835 (seed=232631007) ⊆ kept 844 (seed=92083566)
#   - drop 836 (seed=231991147) ⊆ kept 839 (seed=15012776)
#   - drop 837 (seed=3686712) ⊆ kept 839 (seed=15012776)
#   - drop 840 (seed=75696726) ⊆ kept 838 (seed=232368264)
#   - drop 841 (seed=15012778) ⊆ kept 839 (seed=15012776)
#   - drop 842 (seed=232893904) ⊆ kept 839 (seed=15012776)
#   - drop 843 (seed=28260618) ⊆ kept 839 (seed=15012776)
#   - drop 852 (seed=313103798) ⊆ kept 1089 (seed=312948010)
#   - drop 853 (seed=314789831) ⊆ kept 985 (seed=309940401)
#   - drop 868 (seed=310421373) ⊆ kept 958 (seed=310070183)
#   - drop 872 (seed=310457364) ⊆ kept 935 (seed=309927402)
#   - drop 897 (seed=310076143) ⊆ kept 992 (seed=310076146)
#   - drop 908 (seed=310425105) ⊆ kept 1181 (seed=309932224)
#   - drop 926 (seed=310067990) ⊆ kept 917 (seed=309938432)
#   - drop 929 (seed=310415582) ⊆ kept 917 (seed=309938432)
#   - drop 933 (seed=239100804) ⊆ kept 946 (seed=239100805)
#   - drop 944 (seed=310432097) ⊆ kept 956 (seed=310432098)
#   - drop 945 (seed=310415897) ⊆ kept 957 (seed=309970292)
#   - drop 948 (seed=313107338) ⊆ kept 927 (seed=310429851)
#   - drop 949 (seed=310064814) ⊆ kept 1006 (seed=309927738)
#   - drop 951 (seed=310414968) ⊆ kept 988 (seed=312807984)
#   - drop 953 (seed=310414787) ⊆ kept 974 (seed=310414790)
#   - drop 954 (seed=309927399) ⊆ kept 935 (seed=309927402)
#   - drop 961 (seed=310099000) ⊆ kept 985 (seed=309940401)
#   - drop 966 (seed=310064831) ⊆ kept 1025 (seed=312115193)
#   - drop 969 (seed=310401435) ⊆ kept 1016 (seed=310046255)
#   - drop 972 (seed=310054702) ⊆ kept 964 (seed=310054706)
#   - drop 973 (seed=310415048) ⊆ kept 988 (seed=312807984)
#   - drop 975 (seed=309927727) ⊆ kept 960 (seed=309927730)
#   - drop 977 (seed=310067206) ⊆ kept 982 (seed=309970289)
#   - drop 979 (seed=309927737) ⊆ kept 1006 (seed=309927738)
#   - drop 986 (seed=310064836) ⊆ kept 1025 (seed=312115193)
#   - drop 994 (seed=310415586) ⊆ kept 917 (seed=309938432)
#   - drop 996 (seed=310415767) ⊆ kept 957 (seed=309970292)
#   - drop 1002 (seed=310065960) ⊆ kept 960 (seed=309927730)
#   - drop 1003 (seed=247114712) ⊆ kept 963 (seed=310066495)
#   - drop 1007 (seed=236798499) ⊆ kept 1025 (seed=312115193)
#   - drop 1009 (seed=310433251) ⊆ kept 970 (seed=310101622)
#   - drop 1012 (seed=310067210) ⊆ kept 982 (seed=309970289)
#   - drop 1015 (seed=310419869) ⊆ kept 963 (seed=310066495)
#   - drop 1017 (seed=310068450) ⊆ kept 957 (seed=309970292)
#   - drop 1021 (seed=310415320) ⊆ kept 947 (seed=310415405)
#   - drop 1022 (seed=58822427) ⊆ kept 1011 (seed=309927414)
#   - drop 1024 (seed=310065954) ⊆ kept 935 (seed=309927402)
#   - drop 1028 (seed=310433542) ⊆ kept 991 (seed=312813857)
#   - drop 1032 (seed=102888654) ⊆ kept 1031 (seed=310081695)
#   - drop 1042 (seed=310529088) ⊆ kept 990 (seed=310529093)
#   - drop 1044 (seed=314835655) ⊆ kept 991 (seed=312813857)
#   - drop 1048 (seed=310484373) ⊆ kept 1070 (seed=310157981)
#   - drop 1058 (seed=310073612) ⊆ kept 930 (seed=310073616)
#   - drop 1059 (seed=309930092) ⊆ kept 976 (seed=309930098)
#   - drop 1071 (seed=244298425) ⊆ kept 1087 (seed=312810103)
#   - drop 1075 (seed=284201439) ⊆ kept 1056 (seed=64185277)
#   - drop 1091 (seed=312507459) ⊆ kept 1163 (seed=113885702)
#   - drop 1106 (seed=143976827) ⊆ kept 1107 (seed=309990682)
#   - drop 1113 (seed=310420237) ⊆ kept 982 (seed=309970289)
#   - drop 1118 (seed=234212447) ⊆ kept 1000 (seed=312114873)
#   - drop 1122 (seed=314825960) ⊆ kept 1178 (seed=312874955)
#   - drop 1124 (seed=310401434) ⊆ kept 1016 (seed=310046255)
#   - drop 1126 (seed=310074271) ⊆ kept 1018 (seed=309927449)
#   - drop 1130 (seed=241522889) ⊆ kept 1165 (seed=112261685)
#   - drop 1142 (seed=309988547) ⊆ kept 1083 (seed=108987494)
#   - drop 1143 (seed=310489742) ⊆ kept 1029 (seed=310065161)
#   - drop 1145 (seed=97535343) ⊆ kept 1095 (seed=304722219)
#   - drop 1147 (seed=310410659) ⊆ kept 1014 (seed=310410665)
#   - drop 1153 (seed=260906301) ⊆ kept 1077 (seed=312506262)
#   - drop 1155 (seed=313112553) ⊆ kept 1138 (seed=304721858)
#   - drop 1158 (seed=310420397) ⊆ kept 982 (seed=309970289)
#   - drop 1159 (seed=151748468) ⊆ kept 1169 (seed=304786757)
#   - drop 1160 (seed=312494610) ⊆ kept 1154 (seed=25458637)
#   - drop 1162 (seed=304792023) ⊆ kept 1156 (seed=309984787)
#   - drop 1167 (seed=113885703) ⊆ kept 1097 (seed=25458639)
#   - drop 1176 (seed=306859468) ⊆ kept 1031 (seed=310081695)
#   - drop 1179 (seed=314791778) ⊆ kept 968 (seed=310091673)
#   - drop 1182 (seed=310422881) ⊆ kept 918 (seed=309950844)
#   - drop 1184 (seed=310071274) ⊆ kept 976 (seed=309930098)
#   - drop 1188 (seed=312940219) ⊆ kept 1070 (seed=310157981)
#   - drop 1192 (seed=258624857) ⊆ kept 1046 (seed=310401700)
#   - drop 1193 (seed=310142682) ⊆ kept 1186 (seed=310142686)
#   - drop 1197 (seed=312823044) ⊆ kept 1196 (seed=290276321)
#   - drop 1199 (seed=310157975) ⊆ kept 1070 (seed=310157981)
#   - drop 1200 (seed=310457723) ⊆ kept 976 (seed=309930098)
#   - drop 1201 (seed=312886489) ⊆ kept 1023 (seed=309935574)
#   - drop 1208 (seed=310166977) ⊆ kept 1310 (seed=312152966)
#   - drop 1214 (seed=312818668) ⊆ kept 1229 (seed=312818664)
#   - drop 1215 (seed=310075518) ⊆ kept 1222 (seed=134371258)
#   - drop 1217 (seed=310075149) ⊆ kept 1235 (seed=310075151)
#   - drop 1219 (seed=312903980) ⊆ kept 1221 (seed=312903977)
#   - drop 1223 (seed=310121612) ⊆ kept 1006 (seed=309927738)
#   - drop 1244 (seed=310459382) ⊆ kept 947 (seed=310415405)
#   - drop 1247 (seed=310422576) ⊆ kept 1253 (seed=310422578)
#   - drop 1249 (seed=310509804) ⊆ kept 1252 (seed=310112536)
#   - drop 1254 (seed=312217303) ⊆ kept 1006 (seed=309927738)
#   - drop 1265 (seed=310433260) ⊆ kept 1268 (seed=310097360)
#   - drop 1266 (seed=310121653) ⊆ kept 1267 (seed=128704356)
#   - drop 1269 (seed=310121648) ⊆ kept 1267 (seed=128704356)
#   - drop 1274 (seed=310433262) ⊆ kept 1268 (seed=310097360)
#   - drop 1275 (seed=312881634) ⊆ kept 976 (seed=309930098)
#   - drop 1279 (seed=309938430) ⊆ kept 917 (seed=309938432)
#   - drop 1284 (seed=248619117) ⊆ kept 1286 (seed=310147431)
#   - drop 1285 (seed=310446622) ⊆ kept 1282 (seed=304885944)
#   - drop 1287 (seed=216087557) ⊆ kept 917 (seed=309938432)
#   - drop 1291 (seed=312830017) ⊆ kept 917 (seed=309938432)
#   - drop 1299 (seed=312152984) ⊆ kept 1310 (seed=312152966)
#   - drop 1304 (seed=310443752) ⊆ kept 1306 (seed=310109920)
#   - drop 1307 (seed=310434141) ⊆ kept 1303 (seed=310099921)
#   - drop 1312 (seed=310444881) ⊆ kept 1314 (seed=310096064)
#   - drop 1316 (seed=310444880) ⊆ kept 1314 (seed=310096064)
#   - drop 1317 (seed=310448147) ⊆ kept 1314 (seed=310096064)
#   - drop 1327 (seed=310146492) ⊆ kept 1333 (seed=310146277)
#   - drop 1331 (seed=252434988) ⊆ kept 1333 (seed=310146277)
#   - drop 1332 (seed=310146485) ⊆ kept 1333 (seed=310146277)
#   - drop 1334 (seed=310443417) ⊆ kept 1348 (seed=310109278)
#   - drop 1336 (seed=310443406) ⊆ kept 1345 (seed=310109281)
#   - drop 1339 (seed=277250280) ⊆ kept 1348 (seed=310109278)
#   - drop 1342 (seed=310443414) ⊆ kept 1348 (seed=310109278)
#   - drop 1344 (seed=310443402) ⊆ kept 1345 (seed=310109281)
#   - drop 1353 (seed=283498861) ⊆ kept 1366 (seed=310111556)
#   - drop 1361 (seed=310456628) ⊆ kept 1359 (seed=310093973)
#   - drop 1374 (seed=310454844) ⊆ kept 1369 (seed=310087947)
#   - drop 1381 (seed=310448089) ⊆ kept 1377 (seed=310444501)
#   - drop 1385 (seed=243647793) ⊆ kept 1388 (seed=310108586)
#   - drop 1386 (seed=310464863) ⊆ kept 1390 (seed=310112343)
#   - drop 1387 (seed=310442489) ⊆ kept 1388 (seed=310108586)
#   - drop 1395 (seed=310444032) ⊆ kept 1391 (seed=310094385)
#   - drop 1415 (seed=245791235) ⊆ kept 1881 (seed=241396533)
#   - drop 1433 (seed=245801422) ⊆ kept 1617 (seed=245794496)
#   - drop 1445 (seed=245410507) ⊆ kept 1551 (seed=245408440)
#   - drop 1460 (seed=245410508) ⊆ kept 1696 (seed=245408544)
#   - drop 1467 (seed=24857165) ⊆ kept 1881 (seed=241396533)
#   - drop 1474 (seed=199271269) ⊆ kept 1538 (seed=244325651)
#   - drop 1475 (seed=245213142) ⊆ kept 1502 (seed=245213130)
#   - drop 1480 (seed=245162316) ⊆ kept 1492 (seed=244282218)
#   - drop 1482 (seed=244679362) ⊆ kept 1485 (seed=244297620)
#   - drop 1483 (seed=245430339) ⊆ kept 1492 (seed=244282218)
#   - drop 1488 (seed=246120818) ⊆ kept 1496 (seed=186963463)
#   - drop 1503 (seed=141785740) ⊆ kept 1514 (seed=244659790)
#   - drop 1504 (seed=245784122) ⊆ kept 1465 (seed=245784120)
#   - drop 1516 (seed=246122078) ⊆ kept 1523 (seed=246121816)
#   - drop 1520 (seed=250227793) ⊆ kept 1491 (seed=250210142)
#   - drop 1522 (seed=245162042) ⊆ kept 1492 (seed=244282218)
#   - drop 1526 (seed=245208340) ⊆ kept 1469 (seed=244678787)
#   - drop 1527 (seed=244659797) ⊆ kept 1870 (seed=244659801)
#   - drop 1528 (seed=245786770) ⊆ kept 1492 (seed=244282218)
#   - drop 1532 (seed=245826568) ⊆ kept 1477 (seed=245725003)
#   - drop 1533 (seed=246095991) ⊆ kept 1498 (seed=246037939)
#   - drop 1537 (seed=245811295) ⊆ kept 1552 (seed=245787009)
#   - drop 1545 (seed=202485124) ⊆ kept 1751 (seed=203605998)
#   - drop 1550 (seed=244714428) ⊆ kept 1863 (seed=244714408)
#   - drop 1561 (seed=54419051) ⊆ kept 1543 (seed=245244795)
#   - drop 1562 (seed=84351290) ⊆ kept 1648 (seed=244798986)
#   - drop 1563 (seed=202485113) ⊆ kept 1727 (seed=229021799)
#   - drop 1567 (seed=203606010) ⊆ kept 1702 (seed=245469814)
#   - drop 1570 (seed=107355946) ⊆ kept 1870 (seed=244659801)
#   - drop 1571 (seed=203606725) ⊆ kept 1817 (seed=244792578)
#   - drop 1574 (seed=244792214) ⊆ kept 1717 (seed=244792204)
#   - drop 1576 (seed=245867191) ⊆ kept 1670 (seed=245867187)
#   - drop 1582 (seed=246147973) ⊆ kept 1652 (seed=246147968)
#   - drop 1584 (seed=203605868) ⊆ kept 1766 (seed=202484687)
#   - drop 1585 (seed=203605939) ⊆ kept 1603 (seed=246145482)
#   - drop 1590 (seed=246172351) ⊆ kept 1791 (seed=246172347)
#   - drop 1596 (seed=203606991) ⊆ kept 1684 (seed=203606829)
#   - drop 1598 (seed=202483527) ⊆ kept 1818 (seed=244712154)
#   - drop 1599 (seed=244716233) ⊆ kept 1564 (seed=202971548)
#   - drop 1600 (seed=203608656) ⊆ kept 1825 (seed=246146267)
#   - drop 1601 (seed=246156772) ⊆ kept 1898 (seed=245372179)
#   - drop 1605 (seed=244714415) ⊆ kept 1863 (seed=244714408)
#   - drop 1607 (seed=244714442) ⊆ kept 1657 (seed=202971551)
#   - drop 1608 (seed=245475540) ⊆ kept 1811 (seed=245475538)
#   - drop 1609 (seed=245500065) ⊆ kept 1684 (seed=203606829)
#   - drop 1613 (seed=203605978) ⊆ kept 1821 (seed=244800589)
#   - drop 1616 (seed=244375778) ⊆ kept 1553 (seed=203609937)
#   - drop 1618 (seed=203605863) ⊆ kept 1648 (seed=244798986)
#   - drop 1622 (seed=244359401) ⊆ kept 1758 (seed=244359221)
#   - drop 1624 (seed=246143602) ⊆ kept 1750 (seed=246143390)
#   - drop 1628 (seed=246167979) ⊆ kept 1767 (seed=203605976)
#   - drop 1631 (seed=244771198) ⊆ kept 1856 (seed=244770994)
#   - drop 1632 (seed=202484126) ⊆ kept 1782 (seed=245499065)
#   - drop 1638 (seed=244359439) ⊆ kept 1746 (seed=244359431)
#   - drop 1642 (seed=54649862) ⊆ kept 1492 (seed=244282218)
#   - drop 1645 (seed=244713023) ⊆ kept 1768 (seed=244713015)
#   - drop 1646 (seed=245498492) ⊆ kept 1810 (seed=245498485)
#   - drop 1647 (seed=203605786) ⊆ kept 1719 (seed=202483512)
#   - drop 1649 (seed=245246572) ⊆ kept 1844 (seed=54640346)
#   - drop 1653 (seed=244792834) ⊆ kept 1817 (seed=244792578)
#   - drop 1661 (seed=244713769) ⊆ kept 1700 (seed=244713761)
#   - drop 1662 (seed=244714420) ⊆ kept 1863 (seed=244714408)
#   - drop 1663 (seed=244359446) ⊆ kept 1594 (seed=203606400)
#   - drop 1666 (seed=244310656) ⊆ kept 1787 (seed=203605810)
#   - drop 1667 (seed=244713773) ⊆ kept 1700 (seed=244713761)
#   - drop 1669 (seed=245789139) ⊆ kept 1514 (seed=244659790)
#   - drop 1672 (seed=244713490) ⊆ kept 1569 (seed=244713485)
#   - drop 1673 (seed=246065037) ⊆ kept 1881 (seed=241396533)
#   - drop 1676 (seed=244376101) ⊆ kept 1704 (seed=229021501)
#   - drop 1677 (seed=244713473) ⊆ kept 1566 (seed=244713345)
#   - drop 1678 (seed=244799126) ⊆ kept 1648 (seed=244798986)
#   - drop 1679 (seed=245466704) ⊆ kept 1813 (seed=245466538)
#   - drop 1683 (seed=244801024) ⊆ kept 1821 (seed=244800589)
#   - drop 1689 (seed=202972466) ⊆ kept 1626 (seed=244377124)
#   - drop 1691 (seed=244802143) ⊆ kept 1546 (seed=229022183)
#   - drop 1698 (seed=203609045) ⊆ kept 1874 (seed=203609030)
#   - drop 1701 (seed=245264209) ⊆ kept 1794 (seed=203609674)
#   - drop 1706 (seed=244712140) ⊆ kept 1699 (seed=244712128)
#   - drop 1707 (seed=245475889) ⊆ kept 1643 (seed=245475650)
#   - drop 1726 (seed=203608650) ⊆ kept 1644 (seed=246407579)
#   - drop 1728 (seed=244715934) ⊆ kept 1748 (seed=244715929)
#   - drop 1730 (seed=245475655) ⊆ kept 1643 (seed=245475650)
#   - drop 1737 (seed=245475554) ⊆ kept 1727 (seed=229021799)
#   - drop 1739 (seed=203608264) ⊆ kept 1546 (seed=229022183)
#   - drop 1741 (seed=245242347) ⊆ kept 1512 (seed=244682775)
#   - drop 1742 (seed=245791487) ⊆ kept 1870 (seed=244659801)
#   - drop 1743 (seed=203607394) ⊆ kept 1629 (seed=202972480)
#   - drop 1744 (seed=203609146) ⊆ kept 1684 (seed=203606829)
#   - drop 1756 (seed=203607380) ⊆ kept 1659 (seed=202485377)
#   - drop 1762 (seed=244715410) ⊆ kept 1715 (seed=202484662)
#   - drop 1764 (seed=117673960) ⊆ kept 1700 (seed=244713761)
#   - drop 1773 (seed=245467220) ⊆ kept 1772 (seed=245466985)
#   - drop 1783 (seed=203609761) ⊆ kept 1710 (seed=244713638)
#   - drop 1789 (seed=203606799) ⊆ kept 1733 (seed=203606068)
#   - drop 1793 (seed=246407835) ⊆ kept 1644 (seed=246407579)
#   - drop 1796 (seed=245475534) ⊆ kept 1848 (seed=245475278)
#   - drop 1799 (seed=244374717) ⊆ kept 1688 (seed=202482975)
#   - drop 1801 (seed=246171340) ⊆ kept 1685 (seed=246171250)
#   - drop 1804 (seed=203606710) ⊆ kept 1748 (seed=244715929)
#   - drop 1807 (seed=202971560) ⊆ kept 1685 (seed=246171250)
#   - drop 1808 (seed=245475640) ⊆ kept 1575 (seed=245475635)
#   - drop 1809 (seed=244792200) ⊆ kept 1637 (seed=244792196)
#   - drop 1812 (seed=244374348) ⊆ kept 1855 (seed=244374343)
#   - drop 1814 (seed=245484434) ⊆ kept 1798 (seed=245484025)
#   - drop 1820 (seed=244713019) ⊆ kept 1768 (seed=244713015)
#   - drop 1829 (seed=244713335) ⊆ kept 1768 (seed=244713015)
#   - drop 1831 (seed=245476791) ⊆ kept 1797 (seed=245476786)
#   - drop 1832 (seed=244713643) ⊆ kept 1710 (seed=244713638)
#   - drop 1833 (seed=246176712) ⊆ kept 1840 (seed=246176704)
#   - drop 1841 (seed=244793189) ⊆ kept 1549 (seed=244792874)
#   - drop 1842 (seed=245475615) ⊆ kept 1727 (seed=229021799)
#   - drop 1846 (seed=244801889) ⊆ kept 1595 (seed=112261957)
#   - drop 1849 (seed=244712068) ⊆ kept 1852 (seed=244712062)
#   - drop 1853 (seed=246419501) ⊆ kept 1816 (seed=246419113)
#   - drop 1857 (seed=203606159) ⊆ kept 1839 (seed=246144552)
#   - drop 1858 (seed=202482931) ⊆ kept 1798 (seed=245484025)
#   - drop 1860 (seed=202484134) ⊆ kept 1727 (seed=229021799)
#   - drop 1868 (seed=245469252) ⊆ kept 1716 (seed=203605797)
#   - drop 1875 (seed=245480722) ⊆ kept 1843 (seed=245480712)
#   - drop 1876 (seed=244315049) ⊆ kept 1787 (seed=203605810)
#   - drop 1878 (seed=245427441) ⊆ kept 1870 (seed=244659801)
#   - drop 1879 (seed=124511994) ⊆ kept 1881 (seed=241396533)
#   - drop 1888 (seed=244714425) ⊆ kept 1863 (seed=244714408)
#   - drop 1889 (seed=245789076) ⊆ kept 1881 (seed=241396533)
#   - drop 1891 (seed=245299811) ⊆ kept 1881 (seed=241396533)
#   - drop 1892 (seed=143013788) ⊆ kept 1412 (seed=245826026)
#   - drop 1893 (seed=245408442) ⊆ kept 1900 (seed=245194807)
#   - drop 1896 (seed=245422539) ⊆ kept 1920 (seed=244306711)
#   - drop 1899 (seed=180621800) ⊆ kept 1880 (seed=244344638)
#   - drop 1902 (seed=119264177) ⊆ kept 1881 (seed=241396533)
#   - drop 1903 (seed=246870460) ⊆ kept 1975 (seed=244281540)
#   - drop 1904 (seed=92797778) ⊆ kept 1819 (seed=54649856)
#   - drop 1908 (seed=244767695) ⊆ kept 1929 (seed=244767676)
#   - drop 1915 (seed=245287332) ⊆ kept 1901 (seed=245287331)
#   - drop 1918 (seed=244740701) ⊆ kept 1946 (seed=244740454)
#   - drop 1924 (seed=244746552) ⊆ kept 1910 (seed=244741548)
#   - drop 1928 (seed=245407701) ⊆ kept 1525 (seed=245148402)
#   - drop 1932 (seed=245988066) ⊆ kept 1910 (seed=244741548)
#   - drop 1933 (seed=241985683) ⊆ kept 1870 (seed=244659801)
#   - drop 1934 (seed=244758643) ⊆ kept 1912 (seed=244751668)
#   - drop 1935 (seed=245992910) ⊆ kept 1929 (seed=244767676)
#   - drop 1938 (seed=245270873) ⊆ kept 1930 (seed=244741186)
#   - drop 1940 (seed=71076919) ⊆ kept 1870 (seed=244659801)
#   - drop 1945 (seed=244740435) ⊆ kept 1944 (seed=244736727)
#   - drop 1955 (seed=246349282) ⊆ kept 1432 (seed=245413363)
#   - drop 1956 (seed=210102888) ⊆ kept 1444 (seed=244285362)
#   - drop 1958 (seed=245243923) ⊆ kept 1965 (seed=245243914)
#   - drop 1959 (seed=141935694) ⊆ kept 1416 (seed=244287219)
#   - drop 1970 (seed=31012987) ⊆ kept 1975 (seed=244281540)
#   - drop 1980 (seed=246074171) ⊆ kept 1568 (seed=244316493)
#   - drop 1984 (seed=244660443) ⊆ kept 1449 (seed=245316587)
#   - drop 1985 (seed=245722349) ⊆ kept 1417 (seed=245319657)
#   - drop 1987 (seed=245722353) ⊆ kept 1417 (seed=245319657)
#   - drop 1988 (seed=244660441) ⊆ kept 1449 (seed=245316587)
#   - drop 1989 (seed=245150195) ⊆ kept 1992 (seed=69039448)
#   - drop 1991 (seed=147444589) ⊆ kept 1992 (seed=69039448)
#   - drop 1993 (seed=207539690) ⊆ kept 2100 (seed=245297360)
#   - drop 1994 (seed=245163306) ⊆ kept 2023 (seed=244279323)
#   - drop 2003 (seed=245720437) ⊆ kept 2009 (seed=245720442)
#   - drop 2008 (seed=245827421) ⊆ kept 1412 (seed=245826026)
#   - drop 2012 (seed=244661642) ⊆ kept 2016 (seed=244661635)
#   - drop 2014 (seed=245721918) ⊆ kept 2015 (seed=245721922)
#   - drop 2017 (seed=245722305) ⊆ kept 1434 (seed=245722346)
#   - drop 2018 (seed=244661641) ⊆ kept 2016 (seed=244661635)
#   - drop 2019 (seed=245723635) ⊆ kept 2013 (seed=245723638)
#   - drop 2021 (seed=245152341) ⊆ kept 2020 (seed=244660132)
#   - drop 2022 (seed=244660101) ⊆ kept 2020 (seed=244660132)
#   - drop 2024 (seed=245296029) ⊆ kept 2023 (seed=244279323)
#   - drop 2026 (seed=245723125) ⊆ kept 2027 (seed=244281822)
#   - drop 2028 (seed=244660136) ⊆ kept 2023 (seed=244279323)
#   - drop 2029 (seed=245297361) ⊆ kept 2025 (seed=244280299)
#   - drop 2030 (seed=244660135) ⊆ kept 2023 (seed=244279323)
#   - drop 2031 (seed=245723398) ⊆ kept 2027 (seed=244281822)
#   - drop 2035 (seed=245823975) ⊆ kept 1446 (seed=245823974)
#   - drop 2037 (seed=246377381) ⊆ kept 2033 (seed=176072245)
#   - drop 2039 (seed=245824494) ⊆ kept 2038 (seed=245824195)
#   - drop 2040 (seed=245824490) ⊆ kept 2038 (seed=245824195)
#   - drop 2042 (seed=245824497) ⊆ kept 2038 (seed=245824195)
#   - drop 2044 (seed=105937224) ⊆ kept 2047 (seed=106620284)
#   - drop 2052 (seed=50156267) ⊆ kept 2054 (seed=246096058)
#   - drop 2053 (seed=132151678) ⊆ kept 2054 (seed=246096058)
#   - drop 2055 (seed=227205208) ⊆ kept 2054 (seed=246096058)
#   - drop 2056 (seed=35178102) ⊆ kept 2054 (seed=246096058)
#   - drop 2057 (seed=128117820) ⊆ kept 2054 (seed=246096058)
#   - drop 2058 (seed=246152474) ⊆ kept 1694 (seed=229634330)
#   - drop 2059 (seed=246065039) ⊆ kept 2062 (seed=245448249)
#   - drop 2061 (seed=245406518) ⊆ kept 2060 (seed=244688641)
#   - drop 2064 (seed=245724947) ⊆ kept 2060 (seed=244688641)
#   - drop 2065 (seed=245722725) ⊆ kept 2075 (seed=245297355)
#   - drop 2066 (seed=246345661) ⊆ kept 1530 (seed=246367699)
#   - drop 2067 (seed=246367703) ⊆ kept 1530 (seed=246367699)
#   - drop 2068 (seed=246367708) ⊆ kept 1530 (seed=246367699)
#   - drop 2069 (seed=246345660) ⊆ kept 1530 (seed=246367699)
#   - drop 2070 (seed=245406561) ⊆ kept 2075 (seed=245297355)
#   - drop 2071 (seed=246367711) ⊆ kept 1530 (seed=246367699)
#   - drop 2072 (seed=106620285) ⊆ kept 1530 (seed=246367699)
#   - drop 2073 (seed=245724944) ⊆ kept 1530 (seed=246367699)
#   - drop 2076 (seed=246367706) ⊆ kept 1530 (seed=246367699)
#   - drop 2078 (seed=209642011) ⊆ kept 2077 (seed=205521882)
#   - drop 2079 (seed=245150188) ⊆ kept 2077 (seed=205521882)
#   - drop 2080 (seed=244659844) ⊆ kept 2077 (seed=205521882)
#   - drop 2081 (seed=245149335) ⊆ kept 2083 (seed=203977390)
#   - drop 2082 (seed=245149668) ⊆ kept 2083 (seed=203977390)
#   - drop 2084 (seed=109116935) ⊆ kept 2083 (seed=203977390)
#   - drop 2085 (seed=245721938) ⊆ kept 2087 (seed=244659893)
#   - drop 2086 (seed=105937513) ⊆ kept 2092 (seed=245297745)
#   - drop 2088 (seed=245153595) ⊆ kept 2092 (seed=245297745)
#   - drop 2090 (seed=244659872) ⊆ kept 2092 (seed=245297745)
#   - drop 2091 (seed=245407153) ⊆ kept 2089 (seed=160263848)
#   - drop 2093 (seed=132545846) ⊆ kept 2100 (seed=245297360)
#   - drop 2094 (seed=244688975) ⊆ kept 2108 (seed=244281818)
#   - drop 2097 (seed=245152655) ⊆ kept 2095 (seed=244659889)
#   - drop 2099 (seed=245298465) ⊆ kept 2100 (seed=245297360)
#   - drop 2101 (seed=245297770) ⊆ kept 2100 (seed=245297360)
#   - drop 2102 (seed=153725867) ⊆ kept 2100 (seed=245297360)
#   - drop 2103 (seed=244661053) ⊆ kept 2100 (seed=245297360)
#   - drop 2104 (seed=245152656) ⊆ kept 2095 (seed=244659889)
#   - drop 2105 (seed=245297774) ⊆ kept 2100 (seed=245297360)
#   - drop 2106 (seed=245297767) ⊆ kept 2100 (seed=245297360)
#   - drop 2107 (seed=245297773) ⊆ kept 2100 (seed=245297360)
#   - drop 2109 (seed=245297765) ⊆ kept 2100 (seed=245297360)
#   - drop 2114 (seed=246039365) ⊆ kept 2116 (seed=246039182)
#   - drop 2118 (seed=245269243) ⊆ kept 2113 (seed=245269235)
#   - drop 2119 (seed=245269238) ⊆ kept 2113 (seed=245269235)
#   - drop 2120 (seed=105937512) ⊆ kept 2121 (seed=244659868)
#   - drop 2123 (seed=244660479) ⊆ kept 2122 (seed=175233393)
#   - drop 2124 (seed=244660481) ⊆ kept 2122 (seed=175233393)
#   - drop 2127 (seed=245407475) ⊆ kept 2125 (seed=105937225)
#   - drop 2128 (seed=246096958) ⊆ kept 2138 (seed=109145051)
#   - drop 2129 (seed=246097454) ⊆ kept 2126 (seed=102877989)
#   - drop 2137 (seed=246097175) ⊆ kept 2138 (seed=109145051)
#   - drop 2144 (seed=245265627) ⊆ kept 2141 (seed=110818526)
#   - drop 2147 (seed=245195159) ⊆ kept 2146 (seed=245195158)
#   - drop 2149 (seed=245407748) ⊆ kept 2151 (seed=177692478)
#   - drop 2167 (seed=28387608) ⊆ kept 2375 (seed=88979033)
#   - drop 2172 (seed=86720686) ⊆ kept 2266 (seed=86720131)
#   - drop 2177 (seed=86804192) ⊆ kept 2215 (seed=60651800)
#   - drop 2197 (seed=279437707) ⊆ kept 2169 (seed=87743860)
#   - drop 2198 (seed=62536085) ⊆ kept 2300 (seed=86708156)
#   - drop 2200 (seed=86715918) ⊆ kept 2239 (seed=86548714)
#   - drop 2207 (seed=43798580) ⊆ kept 2206 (seed=87607232)
#   - drop 2212 (seed=19786836) ⊆ kept 2247 (seed=86546606)
#   - drop 2213 (seed=8748612) ⊆ kept 2239 (seed=86548714)
#   - drop 2228 (seed=13395618) ⊆ kept 2276 (seed=13395617)
#   - drop 2233 (seed=124594034) ⊆ kept 2210 (seed=136991170)
#   - drop 2234 (seed=67886347) ⊆ kept 2298 (seed=86707811)
#   - drop 2241 (seed=23106554) ⊆ kept 2287 (seed=279174086)
#   - drop 2245 (seed=86708577) ⊆ kept 2210 (seed=136991170)
#   - drop 2246 (seed=87747984) ⊆ kept 2289 (seed=279171716)
#   - drop 2254 (seed=86708166) ⊆ kept 2210 (seed=136991170)
#   - drop 2255 (seed=86721196) ⊆ kept 2247 (seed=86546606)
#   - drop 2260 (seed=279125608) ⊆ kept 2249 (seed=1842885)
#   - drop 2261 (seed=86715022) ⊆ kept 2259 (seed=18470309)
#   - drop 2268 (seed=86712952) ⊆ kept 2240 (seed=86712956)
#   - drop 2271 (seed=279179624) ⊆ kept 2295 (seed=279179618)
#   - drop 2274 (seed=7660709) ⊆ kept 2259 (seed=18470309)
#   - drop 2279 (seed=86721197) ⊆ kept 2282 (seed=279125474)
#   - drop 2280 (seed=86900129) ⊆ kept 2210 (seed=136991170)
#   - drop 2281 (seed=87604182) ⊆ kept 2247 (seed=86546606)
#   - drop 2286 (seed=3550815) ⊆ kept 2266 (seed=86720131)
#   - drop 2291 (seed=9587540) ⊆ kept 2247 (seed=86546606)
#   - drop 2294 (seed=279008519) ⊆ kept 2249 (seed=1842885)
#   - drop 2301 (seed=86983425) ⊆ kept 2287 (seed=279174086)
#   - drop 2306 (seed=8740239) ⊆ kept 2236 (seed=86610426)
#   - drop 2307 (seed=87747986) ⊆ kept 2277 (seed=86709545)
#   - drop 2308 (seed=86810200) ⊆ kept 2192 (seed=279925683)
#   - drop 2339 (seed=86761325) ⊆ kept 2518 (seed=279004203)
#   - drop 2340 (seed=70209736) ⊆ kept 2210 (seed=136991170)
#   - drop 2344 (seed=279426403) ⊆ kept 2277 (seed=86709545)
#   - drop 2360 (seed=87701786) ⊆ kept 2381 (seed=87701578)
#   - drop 2365 (seed=20971943) ⊆ kept 2272 (seed=279166971)
#   - drop 2369 (seed=86914216) ⊆ kept 2269 (seed=87692781)
#   - drop 2378 (seed=86721159) ⊆ kept 2247 (seed=86546606)
#   - drop 2380 (seed=87701565) ⊆ kept 2247 (seed=86546606)
#   - drop 2384 (seed=86720122) ⊆ kept 2266 (seed=86720131)
#   - drop 2389 (seed=86804267) ⊆ kept 2479 (seed=86592526)
#   - drop 2392 (seed=279424082) ⊆ kept 2507 (seed=44995911)
#   - drop 2393 (seed=88069859) ⊆ kept 2471 (seed=279477581)
#   - drop 2397 (seed=258961960) ⊆ kept 2503 (seed=96258779)
#   - drop 2399 (seed=87030803) ⊆ kept 2247 (seed=86546606)
#   - drop 2414 (seed=279128427) ⊆ kept 2219 (seed=95011100)
#   - drop 2415 (seed=87151259) ⊆ kept 2446 (seed=279493176)
#   - drop 2421 (seed=15886343) ⊆ kept 2210 (seed=136991170)
#   - drop 2422 (seed=250450096) ⊆ kept 2371 (seed=279133780)
#   - drop 2423 (seed=67943877) ⊆ kept 2210 (seed=136991170)
#   - drop 2424 (seed=279647461) ⊆ kept 2432 (seed=87768480)
#   - drop 2430 (seed=87767530) ⊆ kept 2426 (seed=86671068)
#   - drop 2433 (seed=86819821) ⊆ kept 2439 (seed=86659359)
#   - drop 2436 (seed=279493146) ⊆ kept 2448 (seed=86821351)
#   - drop 2438 (seed=86863956) ⊆ kept 2440 (seed=86864126)
#   - drop 2441 (seed=86906701) ⊆ kept 2277 (seed=86709545)
#   - drop 2442 (seed=86858854) ⊆ kept 2452 (seed=86858836)
#   - drop 2444 (seed=86860223) ⊆ kept 2452 (seed=86858836)
#   - drop 2447 (seed=87768475) ⊆ kept 2432 (seed=87768480)
#   - drop 2449 (seed=87802762) ⊆ kept 2463 (seed=86859079)
#   - drop 2453 (seed=87018420) ⊆ kept 2463 (seed=86859079)
#   - drop 2455 (seed=87791777) ⊆ kept 2445 (seed=87791779)
#   - drop 2457 (seed=87029771) ⊆ kept 2432 (seed=87768480)
#   - drop 2459 (seed=58249439) ⊆ kept 2298 (seed=86707811)
#   - drop 2473 (seed=87606969) ⊆ kept 2478 (seed=86589161)
#   - drop 2487 (seed=37990751) ⊆ kept 2211 (seed=87781273)
#   - drop 2490 (seed=87707396) ⊆ kept 2322 (seed=86714561)
#   - drop 2492 (seed=93259603) ⊆ kept 2498 (seed=279015332)
#   - drop 2493 (seed=279437696) ⊆ kept 2322 (seed=86714561)
#   - drop 2494 (seed=86726760) ⊆ kept 2491 (seed=86726770)
#   - drop 2496 (seed=86765472) ⊆ kept 2500 (seed=86765467)
#   - drop 2497 (seed=86725177) ⊆ kept 2347 (seed=86725179)
#   - drop 2513 (seed=86706815) ⊆ kept 2373 (seed=86706819)
#   - drop 2515 (seed=279994266) ⊆ kept 2516 (seed=279994262)
#   - drop 2517 (seed=69745184) ⊆ kept 2262 (seed=279171982)
#   - drop 2525 (seed=97107057) ⊆ kept 2377 (seed=87697210)
#   - drop 2528 (seed=243184227) ⊆ kept 2527 (seed=180422457)
#   - drop 2530 (seed=154378316) ⊆ kept 2543 (seed=24023796)
#   - drop 2532 (seed=279006795) ⊆ kept 2544 (seed=279006468)
#   - drop 2534 (seed=194998823) ⊆ kept 2527 (seed=180422457)
#   - drop 2535 (seed=210622780) ⊆ kept 2542 (seed=2095993)
#   - drop 2536 (seed=84308055) ⊆ kept 2542 (seed=2095993)
#   - drop 2538 (seed=119417031) ⊆ kept 2527 (seed=180422457)
#   - drop 2552 (seed=225262342) ⊆ kept 2754 (seed=224744257)
#   - drop 2556 (seed=225267005) ⊆ kept 2818 (seed=225265911)
#   - drop 2571 (seed=224654893) ⊆ kept 2563 (seed=224655093)
#   - drop 2577 (seed=225689154) ⊆ kept 2582 (seed=225689150)
#   - drop 2579 (seed=225689158) ⊆ kept 2582 (seed=225689150)
#   - drop 2589 (seed=224657262) ⊆ kept 2829 (seed=224644858)
#   - drop 2590 (seed=225341767) ⊆ kept 2621 (seed=226689101)
#   - drop 2601 (seed=78215171) ⊆ kept 2660 (seed=183095531)
#   - drop 2604 (seed=172161478) ⊆ kept 2627 (seed=224252093)
#   - drop 2615 (seed=224210225) ⊆ kept 2631 (seed=225015329)
#   - drop 2617 (seed=225711368) ⊆ kept 2638 (seed=226442666)
#   - drop 2624 (seed=224758702) ⊆ kept 2669 (seed=224758512)
#   - drop 2629 (seed=224209489) ⊆ kept 2710 (seed=154042078)
#   - drop 2648 (seed=225328454) ⊆ kept 2741 (seed=225054518)
#   - drop 2651 (seed=224248715) ⊆ kept 2739 (seed=108762580)
#   - drop 2662 (seed=226440111) ⊆ kept 2726 (seed=140247198)
#   - drop 2671 (seed=224210218) ⊆ kept 2655 (seed=224207477)
#   - drop 2683 (seed=149483327) ⊆ kept 2688 (seed=225074805)
#   - drop 2684 (seed=224209442) ⊆ kept 2631 (seed=225015329)
#   - drop 2699 (seed=224209446) ⊆ kept 2631 (seed=225015329)
#   - drop 2713 (seed=224960991) ⊆ kept 2644 (seed=224960876)
#   - drop 2722 (seed=226433693) ⊆ kept 2690 (seed=223877435)
#   - drop 2723 (seed=224759642) ⊆ kept 2700 (seed=224744902)
#   - drop 2730 (seed=156136933) ⊆ kept 2618 (seed=225928682)
#   - drop 2733 (seed=225665087) ⊆ kept 2649 (seed=225712534)
#   - drop 2740 (seed=224215083) ⊆ kept 2633 (seed=98405532)
#   - drop 2746 (seed=149547562) ⊆ kept 2709 (seed=224767801)
#   - drop 2750 (seed=224760745) ⊆ kept 2603 (seed=168276927)
#   - drop 2755 (seed=225308797) ⊆ kept 2702 (seed=54895491)
#   - drop 2767 (seed=224196225) ⊆ kept 2777 (seed=223876010)
#   - drop 2772 (seed=225898967) ⊆ kept 2812 (seed=183746270)
#   - drop 2773 (seed=226400308) ⊆ kept 2777 (seed=223876010)
#   - drop 2779 (seed=224196238) ⊆ kept 2771 (seed=226400924)
#   - drop 2780 (seed=224695303) ⊆ kept 2801 (seed=224203931)
#   - drop 2788 (seed=224195617) ⊆ kept 2774 (seed=226400327)
#   - drop 2791 (seed=224697457) ⊆ kept 2784 (seed=66230923)
#   - drop 2795 (seed=224204149) ⊆ kept 2812 (seed=183746270)
#   - drop 2797 (seed=225333011) ⊆ kept 2778 (seed=224196601)
#   - drop 2800 (seed=154406496) ⊆ kept 2777 (seed=223876010)
#   - drop 2804 (seed=225690887) ⊆ kept 2673 (seed=225690888)
#   - drop 2811 (seed=225690889) ⊆ kept 2673 (seed=225690888)
#   - drop 2813 (seed=224249340) ⊆ kept 2744 (seed=224249345)
#   - drop 2822 (seed=224655146) ⊆ kept 2793 (seed=226395669)
#   - drop 2826 (seed=156514541) ⊆ kept 2812 (seed=183746270)
#   - drop 2827 (seed=166652268) ⊆ kept 2687 (seed=224627725)
#   - drop 2830 (seed=224204146) ⊆ kept 2812 (seed=183746270)
#   - drop 2846 (seed=225349188) ⊆ kept 2564 (seed=225055156)
#   - drop 2854 (seed=225260627) ⊆ kept 2687 (seed=224627725)
#   - drop 2855 (seed=224192134) ⊆ kept 2708 (seed=224192136)
#   - drop 2857 (seed=225341702) ⊆ kept 2852 (seed=225067160)
#   - drop 2858 (seed=225359720) ⊆ kept 2853 (seed=225359728)
#   - drop 2862 (seed=225366376) ⊆ kept 2563 (seed=224655093)
#   - drop 2870 (seed=225691577) ⊆ kept 2717 (seed=135261165)
#   - drop 2873 (seed=199059214) ⊆ kept 2807 (seed=14297671)
#   - drop 2878 (seed=224257332) ⊆ kept 2876 (seed=224257311)
#   - drop 2879 (seed=199059210) ⊆ kept 2609 (seed=40680011)
#   - drop 2887 (seed=226709801) ⊆ kept 2877 (seed=226704480)
#   - drop 2895 (seed=225689522) ⊆ kept 2871 (seed=106619721)
#   - drop 2898 (seed=226689536) ⊆ kept 2886 (seed=226679264)
#   - drop 2903 (seed=225875856) ⊆ kept 2685 (seed=224189714)
#   - drop 2906 (seed=226667507) ⊆ kept 2876 (seed=224257311)
#   - drop 2909 (seed=226699659) ⊆ kept 2881 (seed=226690274)
#   - drop 2916 (seed=225711361) ⊆ kept 2638 (seed=226442666)
#   - drop 2922 (seed=224736459) ⊆ kept 2924 (seed=224736452)
#   - drop 2937 (seed=224228334) ⊆ kept 2936 (seed=224227962)
#   - drop 2945 (seed=224290378) ⊆ kept 2753 (seed=224290380)
#   - drop 2952 (seed=138669254) ⊆ kept 2953 (seed=225289430)
#   - drop 2959 (seed=224970830) ⊆ kept 2958 (seed=224708365)
#   - drop 2960 (seed=224765210) ⊆ kept 2958 (seed=224708365)
#   - drop 2961 (seed=224765208) ⊆ kept 2958 (seed=224708365)
#   - drop 2967 (seed=204189734) ⊆ kept 2983 (seed=226358329)
#   - drop 2968 (seed=224628044) ⊆ kept 2983 (seed=226358329)
#   - drop 2970 (seed=122684593) ⊆ kept 2983 (seed=226358329)
#   - drop 2971 (seed=154972909) ⊆ kept 2983 (seed=226358329)
#   - drop 2972 (seed=225865568) ⊆ kept 2983 (seed=226358329)
#   - drop 2973 (seed=152738289) ⊆ kept 2983 (seed=226358329)
#   - drop 2975 (seed=224628041) ⊆ kept 2983 (seed=226358329)
#   - drop 2977 (seed=7016381) ⊆ kept 2983 (seed=226358329)
#   - drop 2979 (seed=225255878) ⊆ kept 2983 (seed=226358329)
#   - drop 2981 (seed=225255395) ⊆ kept 2983 (seed=226358329)
#   - drop 2982 (seed=196897382) ⊆ kept 2983 (seed=226358329)
#   - drop 2984 (seed=224629040) ⊆ kept 2983 (seed=226358329)
#   - drop 2985 (seed=225866088) ⊆ kept 2978 (seed=137497185)
#   - drop 2986 (seed=224629035) ⊆ kept 2983 (seed=226358329)
#   - drop 2987 (seed=225255755) ⊆ kept 2983 (seed=226358329)
#   - drop 2988 (seed=224628819) ⊆ kept 2983 (seed=226358329)
#   - drop 2989 (seed=92951470) ⊆ kept 2983 (seed=226358329)
#   - drop 2990 (seed=226358675) ⊆ kept 2983 (seed=226358329)
#   - drop 2991 (seed=225255880) ⊆ kept 2983 (seed=226358329)
#   - drop 2992 (seed=226358361) ⊆ kept 2983 (seed=226358329)
#   - drop 2993 (seed=152500329) ⊆ kept 2983 (seed=226358329)
#   - drop 2994 (seed=225866086) ⊆ kept 2978 (seed=137497185)
#   - drop 2995 (seed=224628817) ⊆ kept 2983 (seed=226358329)
#   - drop 2996 (seed=118281690) ⊆ kept 2978 (seed=137497185)
#   - drop 2997 (seed=224629030) ⊆ kept 2983 (seed=226358329)
#   - drop 3015 (seed=121712094) ⊆ kept 3038 (seed=9605827)
#   - drop 3017 (seed=121885039) ⊆ kept 3002 (seed=8866984)
#   - drop 3020 (seed=121885010) ⊆ kept 3002 (seed=8866984)
#   - drop 3024 (seed=10018231) ⊆ kept 3064 (seed=121259966)
#   - drop 3025 (seed=17122460) ⊆ kept 3064 (seed=121259966)
#   - drop 3026 (seed=121259957) ⊆ kept 3140 (seed=121259951)
#   - drop 3028 (seed=28351466) ⊆ kept 3064 (seed=121259966)
#   - drop 3029 (seed=17120263) ⊆ kept 3061 (seed=121591290)
#   - drop 3030 (seed=10018227) ⊆ kept 3034 (seed=121711167)
#   - drop 3032 (seed=121259878) ⊆ kept 3053 (seed=35403955)
#   - drop 3033 (seed=121591303) ⊆ kept 3064 (seed=121259966)
#   - drop 3035 (seed=121849996) ⊆ kept 3034 (seed=121711167)
#   - drop 3040 (seed=121850009) ⊆ kept 3034 (seed=121711167)
#   - drop 3041 (seed=121849979) ⊆ kept 3034 (seed=121711167)
#   - drop 3043 (seed=57073939) ⊆ kept 3057 (seed=121446538)
#   - drop 3044 (seed=121849944) ⊆ kept 3034 (seed=121711167)
#   - drop 3045 (seed=20254967) ⊆ kept 3034 (seed=121711167)
#   - drop 3046 (seed=103558851) ⊆ kept 3125 (seed=121657236)
#   - drop 3052 (seed=121850038) ⊆ kept 3034 (seed=121711167)
#   - drop 3055 (seed=121850033) ⊆ kept 3034 (seed=121711167)
#   - drop 3056 (seed=121259880) ⊆ kept 3053 (seed=35403955)
#   - drop 3058 (seed=121315594) ⊆ kept 3135 (seed=121315590)
#   - drop 3062 (seed=121849932) ⊆ kept 3034 (seed=121711167)
#   - drop 3067 (seed=120759919) ⊆ kept 3061 (seed=121591290)
#   - drop 3076 (seed=12738515) ⊆ kept 3142 (seed=121656570)
#   - drop 3077 (seed=8994413) ⊆ kept 3064 (seed=121259966)
#   - drop 3078 (seed=121745081) ⊆ kept 3115 (seed=8889497)
#   - drop 3080 (seed=121855218) ⊆ kept 3170 (seed=121743487)
#   - drop 3083 (seed=121850018) ⊆ kept 3034 (seed=121711167)
#   - drop 3087 (seed=121850035) ⊆ kept 3034 (seed=121711167)
#   - drop 3090 (seed=8961748) ⊆ kept 3068 (seed=126312082)
#   - drop 3091 (seed=79979080) ⊆ kept 3082 (seed=88620595)
#   - drop 3092 (seed=118802963) ⊆ kept 3034 (seed=121711167)
#   - drop 3093 (seed=121711175) ⊆ kept 3034 (seed=121711167)
#   - drop 3095 (seed=84198591) ⊆ kept 3034 (seed=121711167)
#   - drop 3096 (seed=121711182) ⊆ kept 3034 (seed=121711167)
#   - drop 3099 (seed=14491667) ⊆ kept 3034 (seed=121711167)
#   - drop 3101 (seed=100292800) ⊆ kept 3064 (seed=121259966)
#   - drop 3102 (seed=121855276) ⊆ kept 3104 (seed=121712535)
#   - drop 3103 (seed=121655565) ⊆ kept 3069 (seed=51972191)
#   - drop 3113 (seed=121259972) ⊆ kept 3064 (seed=121259966)
#   - drop 3114 (seed=107578861) ⊆ kept 3064 (seed=121259966)
#   - drop 3120 (seed=121849926) ⊆ kept 3034 (seed=121711167)
# ...
#   - drop 48782 (seed=3604208) ⊆ kept 48788 (seed=3545882)
#   - drop 48784 (seed=2443153) ⊆ kept 48208 (seed=3141611)
#   - drop 48786 (seed=155226746) ⊆ kept 48280 (seed=155226713)
#   - drop 48787 (seed=3603596) ⊆ kept 48788 (seed=3545882)
#   - drop 48790 (seed=103585216) ⊆ kept 48844 (seed=155634839)
#   - drop 48796 (seed=2144073) ⊆ kept 48840 (seed=2144054)
#   - drop 48800 (seed=155634774) ⊆ kept 48701 (seed=6362475)
#   - drop 48820 (seed=9501884) ⊆ kept 48863 (seed=1869355)
#   - drop 48821 (seed=9501876) ⊆ kept 48863 (seed=1869355)
#   - drop 48823 (seed=9501890) ⊆ kept 48863 (seed=1869355)
#   - drop 48825 (seed=9501611) ⊆ kept 48863 (seed=1869355)
#   - drop 48830 (seed=9502468) ⊆ kept 48863 (seed=1869355)
#   - drop 48831 (seed=9501976) ⊆ kept 48863 (seed=1869355)
#   - drop 48832 (seed=9501962) ⊆ kept 48863 (seed=1869355)
#   - drop 48833 (seed=9501971) ⊆ kept 48863 (seed=1869355)
#   - drop 48834 (seed=9502481) ⊆ kept 48863 (seed=1869355)
#   - drop 48841 (seed=155379882) ⊆ kept 48844 (seed=155634839)
#   - drop 48842 (seed=1871678) ⊆ kept 48863 (seed=1869355)
#   - drop 48843 (seed=9501595) ⊆ kept 48863 (seed=1869355)
#   - drop 48845 (seed=1870717) ⊆ kept 48863 (seed=1869355)
#   - drop 48846 (seed=9501570) ⊆ kept 48863 (seed=1869355)
#   - drop 48847 (seed=1869408) ⊆ kept 48863 (seed=1869355)
#   - drop 48848 (seed=155635289) ⊆ kept 48844 (seed=155634839)
#   - drop 48849 (seed=9501586) ⊆ kept 48863 (seed=1869355)
#   - drop 48850 (seed=155635298) ⊆ kept 48844 (seed=155634839)
#   - drop 48851 (seed=79742247) ⊆ kept 48844 (seed=155634839)
#   - drop 48852 (seed=155635303) ⊆ kept 48844 (seed=155634839)
#   - drop 48853 (seed=3289055) ⊆ kept 48844 (seed=155634839)
#   - drop 48854 (seed=9501604) ⊆ kept 48863 (seed=1869355)
#   - drop 48855 (seed=1869842) ⊆ kept 48863 (seed=1869355)
#   - drop 48856 (seed=1869400) ⊆ kept 48863 (seed=1869355)
#   - drop 48857 (seed=155635294) ⊆ kept 48844 (seed=155634839)
#   - drop 48858 (seed=1869391) ⊆ kept 48863 (seed=1869355)
#   - drop 48859 (seed=9501607) ⊆ kept 48863 (seed=1869355)
#   - drop 48860 (seed=1871687) ⊆ kept 48863 (seed=1869355)
#   - drop 48861 (seed=1869382) ⊆ kept 48863 (seed=1869355)
#   - drop 48862 (seed=1869377) ⊆ kept 48863 (seed=1869355)
#   - drop 48864 (seed=1869372) ⊆ kept 48863 (seed=1869355)
#   - drop 48865 (seed=1869366) ⊆ kept 48863 (seed=1869355)
#   - drop 48866 (seed=1869364) ⊆ kept 48863 (seed=1869355)
#   - drop 48868 (seed=9502516) ⊆ kept 48863 (seed=1869355)
#   - drop 48869 (seed=3372940) ⊆ kept 48863 (seed=1869355)
#   - drop 48870 (seed=147449) ⊆ kept 48863 (seed=1869355)
#   - drop 48871 (seed=9502546) ⊆ kept 48863 (seed=1869355)
#   - drop 48872 (seed=9502557) ⊆ kept 48863 (seed=1869355)
#   - drop 48873 (seed=9502505) ⊆ kept 48863 (seed=1869355)
#   - drop 48874 (seed=9502525) ⊆ kept 48863 (seed=1869355)
#   - drop 48875 (seed=9502553) ⊆ kept 48863 (seed=1869355)
#   - drop 48876 (seed=9502536) ⊆ kept 48863 (seed=1869355)
#   - drop 48877 (seed=9502564) ⊆ kept 48863 (seed=1869355)
#   - drop 48878 (seed=9502561) ⊆ kept 48863 (seed=1869355)
#   - drop 48879 (seed=9502492) ⊆ kept 48863 (seed=1869355)
#   - drop 48890 (seed=158303966) ⊆ kept 48892 (seed=158303968)
#   - drop 48894 (seed=157579683) ⊆ kept 49355 (seed=158867787)
#   - drop 48895 (seed=157642479) ⊆ kept 49544 (seed=139802995)
#   - drop 48910 (seed=158569771) ⊆ kept 49024 (seed=193992040)
#   - drop 48924 (seed=157581544) ⊆ kept 48995 (seed=159123319)
#   - drop 48935 (seed=188724589) ⊆ kept 48905 (seed=188724580)
#   - drop 48936 (seed=172786076) ⊆ kept 49157 (seed=174546201)
#   - drop 48941 (seed=193942006) ⊆ kept 49173 (seed=157990116)
#   - drop 48944 (seed=194083733) ⊆ kept 49235 (seed=194083726)
#   - drop 48951 (seed=188852620) ⊆ kept 48977 (seed=188756758)
#   - drop 48956 (seed=157653328) ⊆ kept 48966 (seed=157587950)
#   - drop 48957 (seed=194428176) ⊆ kept 49106 (seed=159174646)
#   - drop 48960 (seed=158351708) ⊆ kept 49000 (seed=157623010)
#   - drop 48978 (seed=157641092) ⊆ kept 49544 (seed=139802995)
#   - drop 48988 (seed=109080471) ⊆ kept 48993 (seed=157589221)
#   - drop 48989 (seed=139086657) ⊆ kept 49299 (seed=188795568)
#   - drop 48990 (seed=158586301) ⊆ kept 49096 (seed=194025174)
#   - drop 48994 (seed=157589202) ⊆ kept 49270 (seed=157589206)
#   - drop 49002 (seed=158585911) ⊆ kept 49074 (seed=158280179)
#   - drop 49003 (seed=159048040) ⊆ kept 49084 (seed=188661702)
#   - drop 49008 (seed=158398815) ⊆ kept 49474 (seed=158398801)
#   - drop 49014 (seed=194015321) ⊆ kept 49422 (seed=194014858)
#   - drop 49022 (seed=158675077) ⊆ kept 49087 (seed=158675083)
#   - drop 49043 (seed=157581522) ⊆ kept 49339 (seed=158315430)
#   - drop 49044 (seed=158603717) ⊆ kept 49474 (seed=158398801)
#   - drop 49047 (seed=188877146) ⊆ kept 49063 (seed=55812732)
#   - drop 49069 (seed=158648309) ⊆ kept 49156 (seed=158648302)
#   - drop 49070 (seed=157601102) ⊆ kept 49113 (seed=193992829)
#   - drop 49083 (seed=188619405) ⊆ kept 49601 (seed=158573799)
#   - drop 49085 (seed=157590580) ⊆ kept 49178 (seed=157590582)
#   - drop 49090 (seed=160453935) ⊆ kept 49238 (seed=186106229)
#   - drop 49104 (seed=158348917) ⊆ kept 49544 (seed=139802995)
#   - drop 49110 (seed=157597011) ⊆ kept 48903 (seed=188763300)
#   - drop 49112 (seed=178874252) ⊆ kept 49145 (seed=188678239)
#   - drop 49122 (seed=158569773) ⊆ kept 49544 (seed=139802995)
#   - drop 49123 (seed=188700477) ⊆ kept 48995 (seed=159123319)
#   - drop 49131 (seed=194023024) ⊆ kept 49191 (seed=194023016)
#   - drop 49142 (seed=130769029) ⊆ kept 49258 (seed=158580787)
#   - drop 49162 (seed=157920614) ⊆ kept 49091 (seed=180551069)
#   - drop 49163 (seed=158383149) ⊆ kept 48975 (seed=158383145)
#   - drop 49164 (seed=159031247) ⊆ kept 49695 (seed=158360779)
#   - drop 49165 (seed=158398810) ⊆ kept 49474 (seed=158398801)
#   - drop 49172 (seed=157581530) ⊆ kept 49094 (seed=194042330)
#   - drop 49175 (seed=188679300) ⊆ kept 49039 (seed=188679296)
#   - drop 49184 (seed=188876882) ⊆ kept 49187 (seed=163942537)
#   - drop 49186 (seed=157659064) ⊆ kept 49061 (seed=193944831)
#   - drop 49189 (seed=157619649) ⊆ kept 49077 (seed=188775922)
#   - drop 49190 (seed=159101316) ⊆ kept 49039 (seed=188679296)
#   - drop 49192 (seed=100456594) ⊆ kept 49267 (seed=158671379)
#   - drop 49193 (seed=157581547) ⊆ kept 49039 (seed=188679296)
#   - drop 49204 (seed=175516136) ⊆ kept 49141 (seed=194083238)
#   - drop 49208 (seed=157620924) ⊆ kept 49476 (seed=157620930)
#   - drop 49213 (seed=158013590) ⊆ kept 48973 (seed=158580514)
#   - drop 49241 (seed=188677483) ⊆ kept 49269 (seed=188677475)
#   - drop 49246 (seed=159479501) ⊆ kept 49544 (seed=139802995)
#   - drop 49250 (seed=157595848) ⊆ kept 48979 (seed=157595965)
#   - drop 49252 (seed=157600403) ⊆ kept 49074 (seed=158280179)
#   - drop 49254 (seed=157607828) ⊆ kept 49474 (seed=158398801)
#   - drop 49263 (seed=158380255) ⊆ kept 49646 (seed=158380099)
#   - drop 49264 (seed=158587791) ⊆ kept 49034 (seed=188918647)
#   - drop 49268 (seed=184218478) ⊆ kept 49020 (seed=188733184)
#   - drop 49271 (seed=158586299) ⊆ kept 49096 (seed=194025174)
#   - drop 49275 (seed=158671374) ⊆ kept 49230 (seed=161110356)
#   - drop 49276 (seed=158671366) ⊆ kept 49173 (seed=157990116)
#   - drop 49277 (seed=158671357) ⊆ kept 49017 (seed=193941881)
#   - drop 49282 (seed=157577571) ⊆ kept 49440 (seed=157577573)
#   - drop 49283 (seed=163234354) ⊆ kept 49520 (seed=188650969)
#   - drop 49291 (seed=188787597) ⊆ kept 49605 (seed=158627579)
#   - drop 49306 (seed=157619648) ⊆ kept 49137 (seed=158602475)
#   - drop 49312 (seed=157616321) ⊆ kept 49326 (seed=194106483)
#   - drop 49313 (seed=157638563) ⊆ kept 48934 (seed=194374170)
#   - drop 49318 (seed=158587793) ⊆ kept 49004 (seed=158281265)
#   - drop 49319 (seed=157610513) ⊆ kept 49038 (seed=157610517)
#   - drop 49322 (seed=157600390) ⊆ kept 49544 (seed=139802995)
#   - drop 49323 (seed=188965393) ⊆ kept 49106 (seed=159174646)
#   - drop 49331 (seed=157605034) ⊆ kept 49130 (seed=188623818)
#   - drop 49334 (seed=158724556) ⊆ kept 49151 (seed=158724567)
#   - drop 49335 (seed=194407192) ⊆ kept 49141 (seed=194083238)
#   - drop 49337 (seed=158589548) ⊆ kept 49130 (seed=188623818)
#   - drop 49342 (seed=158280174) ⊆ kept 49074 (seed=158280179)
#   - drop 49344 (seed=157600383) ⊆ kept 49314 (seed=158591727)
#   - drop 49345 (seed=157578876) ⊆ kept 49196 (seed=157578884)
#   - drop 49346 (seed=157589243) ⊆ kept 49004 (seed=158281265)
#   - drop 49348 (seed=158612798) ⊆ kept 49582 (seed=189992045)
#   - drop 49350 (seed=157597012) ⊆ kept 48903 (seed=188763300)
#   - drop 49356 (seed=157619643) ⊆ kept 49077 (seed=188775922)
#   - drop 49358 (seed=157605706) ⊆ kept 49174 (seed=188624029)
#   - drop 49360 (seed=158587831) ⊆ kept 49426 (seed=158281690)
#   - drop 49364 (seed=157585515) ⊆ kept 49314 (seed=158591727)
#   - drop 49368 (seed=136350983) ⊆ kept 49174 (seed=188624029)
#   - drop 49369 (seed=157605036) ⊆ kept 49130 (seed=188623818)
#   - drop 49370 (seed=158587865) ⊆ kept 49416 (seed=194044252)
#   - drop 49371 (seed=159736134) ⊆ kept 49149 (seed=158354492)
#   - drop 49374 (seed=157883127) ⊆ kept 49550 (seed=129409140)
#   - drop 49381 (seed=158281469) ⊆ kept 49426 (seed=158281690)
#   - drop 49383 (seed=168258956) ⊆ kept 49174 (seed=188624029)
#   - drop 49384 (seed=157657593) ⊆ kept 49108 (seed=157657596)
#   - drop 49387 (seed=157620920) ⊆ kept 49424 (seed=189093746)
#   - drop 49391 (seed=158591722) ⊆ kept 49314 (seed=158591727)
#   - drop 49393 (seed=4438685) ⊆ kept 49435 (seed=157636234)
#   - drop 49397 (seed=158589551) ⊆ kept 49262 (seed=158277097)
#   - drop 49408 (seed=194015401) ⊆ kept 49062 (seed=194014852)
#   - drop 49412 (seed=157607185) ⊆ kept 49094 (seed=194042330)
#   - drop 49413 (seed=157620860) ⊆ kept 49056 (seed=194087629)
#   - drop 49414 (seed=166036974) ⊆ kept 49091 (seed=180551069)
#   - drop 49415 (seed=194015312) ⊆ kept 49422 (seed=194014858)
#   - drop 49417 (seed=175721161) ⊆ kept 49544 (seed=139802995)
#   - drop 49418 (seed=158275506) ⊆ kept 49411 (seed=158275513)
#   - drop 49425 (seed=70310599) ⊆ kept 49130 (seed=188623818)
#   - drop 49430 (seed=158589543) ⊆ kept 49130 (seed=188623818)
#   - drop 49438 (seed=157622886) ⊆ kept 49424 (seed=189093746)
#   - drop 49439 (seed=157607181) ⊆ kept 49094 (seed=194042330)
#   - drop 49443 (seed=158585912) ⊆ kept 49361 (seed=159257839)
#   - drop 49445 (seed=158574900) ⊆ kept 49076 (seed=188615744)
#   - drop 49447 (seed=194015317) ⊆ kept 49422 (seed=194014858)
#   - drop 49451 (seed=158585907) ⊆ kept 49074 (seed=158280179)
#   - drop 49453 (seed=158398824) ⊆ kept 49474 (seed=158398801)
#   - drop 49455 (seed=157600074) ⊆ kept 49375 (seed=158585869)
#   - drop 49456 (seed=158587830) ⊆ kept 49174 (seed=188624029)
#   - drop 49457 (seed=158589560) ⊆ kept 49094 (seed=194042330)
#   - drop 49459 (seed=162532398) ⊆ kept 49625 (seed=158407668)
#   - drop 49461 (seed=157607824) ⊆ kept 49474 (seed=158398801)
#   - drop 49464 (seed=158571071) ⊆ kept 49521 (seed=158571075)
#   - drop 49465 (seed=98661407) ⊆ kept 48940 (seed=158716248)
#   - drop 49466 (seed=171764031) ⊆ kept 49427 (seed=188930893)
#   - drop 49467 (seed=158716256) ⊆ kept 49051 (seed=158345925)
#   - drop 49473 (seed=157620939) ⊆ kept 49077 (seed=188775922)
#   - drop 49481 (seed=157620914) ⊆ kept 49424 (seed=189093746)
#   - drop 49484 (seed=157601090) ⊆ kept 49113 (seed=193992829)
#   - drop 49485 (seed=157915662) ⊆ kept 49012 (seed=189778402)
#   - drop 49488 (seed=158587825) ⊆ kept 49174 (seed=188624029)
#   - drop 49490 (seed=188641628) ⊆ kept 49149 (seed=158354492)
#   - drop 49491 (seed=158589455) ⊆ kept 49265 (seed=158589443)
#   - drop 49492 (seed=157606810) ⊆ kept 49431 (seed=157606817)
#   - drop 49493 (seed=158612757) ⊆ kept 49411 (seed=158275513)
#   - drop 49494 (seed=159044073) ⊆ kept 49550 (seed=129409140)
#   - drop 49495 (seed=158589466) ⊆ kept 49603 (seed=158589476)
#   - drop 49497 (seed=158587871) ⊆ kept 49416 (seed=194044252)
#   - drop 49507 (seed=159178696) ⊆ kept 49424 (seed=189093746)
#   - drop 49508 (seed=188753533) ⊆ kept 49521 (seed=158571075)
#   - drop 49510 (seed=160456740) ⊆ kept 48964 (seed=194096534)
#   - drop 49511 (seed=157984231) ⊆ kept 49450 (seed=158005812)
#   - drop 49514 (seed=157579988) ⊆ kept 49215 (seed=194035849)
#   - drop 49516 (seed=158612795) ⊆ kept 49479 (seed=158275512)
#   - drop 49519 (seed=157638562) ⊆ kept 49544 (seed=139802995)
#   - drop 49522 (seed=157600399) ⊆ kept 49074 (seed=158280179)
#   - drop 49523 (seed=194395547) ⊆ kept 49474 (seed=158398801)
#   - drop 49526 (seed=158571403) ⊆ kept 48925 (seed=158571478)
#   - drop 49527 (seed=194312038) ⊆ kept 49380 (seed=193974869)
#   - drop 49528 (seed=194023031) ⊆ kept 49191 (seed=194023016)
#   - drop 49532 (seed=158586386) ⊆ kept 49269 (seed=188677475)
#   - drop 49533 (seed=158586302) ⊆ kept 49411 (seed=158275513)
#   - drop 49535 (seed=164414114) ⊆ kept 49188 (seed=188755438)
#   - drop 49537 (seed=158612797) ⊆ kept 49235 (seed=194083726)
#   - drop 49538 (seed=158716652) ⊆ kept 49475 (seed=158716989)
#   - drop 49540 (seed=134443061) ⊆ kept 49496 (seed=158817196)
#   - drop 49542 (seed=158297065) ⊆ kept 49351 (seed=158297049)
#   - drop 49543 (seed=158575483) ⊆ kept 49544 (seed=139802995)
#   - drop 49545 (seed=158586389) ⊆ kept 49411 (seed=158275513)
#   - drop 49547 (seed=159310917) ⊆ kept 49054 (seed=157581518)
#   - drop 49548 (seed=157638553) ⊆ kept 49544 (seed=139802995)
#   - drop 49552 (seed=158612765) ⊆ kept 49411 (seed=158275513)
#   - drop 49556 (seed=171332573) ⊆ kept 49424 (seed=189093746)
#   - drop 49557 (seed=158612801) ⊆ kept 49251 (seed=129015754)
#   - drop 49559 (seed=157600382) ⊆ kept 49544 (seed=139802995)
#   - drop 49562 (seed=157641093) ⊆ kept 49544 (seed=139802995)
#   - drop 49565 (seed=157585526) ⊆ kept 49258 (seed=158580787)
#   - drop 49566 (seed=160456731) ⊆ kept 48891 (seed=194103537)
#   - drop 49567 (seed=157584676) ⊆ kept 48911 (seed=157584683)
#   - drop 49568 (seed=158585882) ⊆ kept 49149 (seed=158354492)
#   - drop 49569 (seed=158315410) ⊆ kept 49411 (seed=158275513)
#   - drop 49570 (seed=158585895) ⊆ kept 49149 (seed=158354492)
#   - drop 49571 (seed=158569764) ⊆ kept 49544 (seed=139802995)
#   - drop 49572 (seed=158292080) ⊆ kept 49327 (seed=158292105)
#   - drop 49573 (seed=157634689) ⊆ kept 49340 (seed=157898791)
#   - drop 49575 (seed=157585120) ⊆ kept 49314 (seed=158591727)
#   - drop 49580 (seed=158612761) ⊆ kept 49520 (seed=188650969)
#   - drop 49581 (seed=159039422) ⊆ kept 49698 (seed=158378208)
#   - drop 49586 (seed=157600389) ⊆ kept 49149 (seed=158354492)
#   - drop 49588 (seed=158290692) ⊆ kept 49300 (seed=158290966)
#   - drop 49589 (seed=188864016) ⊆ kept 49145 (seed=188678239)
#   - drop 49592 (seed=158612799) ⊆ kept 48905 (seed=188724580)
#   - drop 49594 (seed=157957278) ⊆ kept 49265 (seed=158589443)
#   - drop 49595 (seed=190135471) ⊆ kept 49038 (seed=157610517)
#   - drop 49600 (seed=158380071) ⊆ kept 49631 (seed=158379862)
#   - drop 49602 (seed=171550963) ⊆ kept 49006 (seed=189218641)
#   - drop 49613 (seed=158379867) ⊆ kept 49631 (seed=158379862)
#   - drop 49621 (seed=158612793) ⊆ kept 48912 (seed=188612885)
#   - drop 49623 (seed=193972634) ⊆ kept 49138 (seed=193972434)
#   - drop 49624 (seed=187681886) ⊆ kept 49622 (seed=194353118)
#   - drop 49626 (seed=158379865) ⊆ kept 49631 (seed=158379862)
#   - drop 49628 (seed=178784055) ⊆ kept 49141 (seed=194083238)
#   - drop 49638 (seed=116797161) ⊆ kept 49639 (seed=157592221)
#   - drop 49640 (seed=158654078) ⊆ kept 49639 (seed=157592221)
#   - drop 49656 (seed=158653799) ⊆ kept 49673 (seed=158652955)
#   - drop 49657 (seed=158653805) ⊆ kept 49673 (seed=158652955)
#   - drop 49658 (seed=158653791) ⊆ kept 49673 (seed=158652955)
#   - drop 49659 (seed=157617755) ⊆ kept 49673 (seed=158652955)
#   - drop 49663 (seed=157636230) ⊆ kept 49435 (seed=157636234)
#   - drop 49664 (seed=158653775) ⊆ kept 49673 (seed=158652955)
#   - drop 49665 (seed=158653778) ⊆ kept 49673 (seed=158652955)
#   - drop 49666 (seed=157592194) ⊆ kept 49673 (seed=158652955)
#   - drop 49667 (seed=158653733) ⊆ kept 49673 (seed=158652955)
#   - drop 49668 (seed=158653723) ⊆ kept 49673 (seed=158652955)
#   - drop 49669 (seed=158653767) ⊆ kept 49673 (seed=158652955)
#   - drop 49670 (seed=131528663) ⊆ kept 49673 (seed=158652955)
#   - drop 49671 (seed=158653728) ⊆ kept 49673 (seed=158652955)
#   - drop 49672 (seed=158653783) ⊆ kept 49673 (seed=158652955)

# %% [markdown]
# Merge networks that have overlapping nodes

# %%
txn_expanded, edges_expanded, txn_final, edges_final = build_network.merge_subnetworks_by_node_overlap(
    nodes_dedup, edges_dedup,
    min_shared_nodes=1,
    progress=True,
#   group 49029: subnetwork_ids=[49029, 49030, 49060, 49079, 49115, 49224, 49265, 49273, 49353, 49501, 49603] seeds=[158346869, 158347705, 158378706, 158378985, 158589443, 158589447, 158589473, 158589476, 158589481, 158589486, 158589504]
#   group 49037: subnetwork_ids=[49037, 49113] seeds=[157601103, 193992829]
#   group 49054: subnetwork_ids=[49054, 49317] seeds=[157581518, 188664306]
#   group 49074: subnetwork_ids=[49074, 49361] seeds=[158280179, 159257839]
#   group 49077: subnetwork_ids=[49077, 49137, 49373, 49476] seeds=[157620930, 157620932, 158602475, 188775922]
#   group 49094: subnetwork_ids=[49094, 49416, 49428] seeds=[194042330, 194044252, 194047233]
#   group 49141: subnetwork_ids=[49141, 49629] seeds=[194083238, 194407015]
#   group 49174: subnetwork_ids=[49174, 49231, 49321, 49426, 49472, 49504] seeds=[157605705, 158281690, 188624029, 188624030, 194041200, 194043991]
#   group 49188: subnetwork_ids=[49188, 49242] seeds=[188755426, 188755438]
#   group 49300: subnetwork_ids=[49300, 49302, 49304, 49307, 49308, 49309, 49310, 49311, 49315, 49320, 49324, 49325, 49347, 49357, 49366, 49395, 49429] seeds=[158290043, 158290056, 158290063, 158290068, 158290959, 158290960, 158290962, 158290964, 158290966, 158290968, 158290969, 158290970, 158290994, 158290995, 158291557, 158291558, 158291559]
#   group 49394: subnetwork_ids=[49394, 49424, 49437, 49486, 49564] seeds=[157617760, 157620919, 179353335, 189093746, 194091937]
#   group 49474: subnetwork_ids=[49474, 49541] seeds=[158398801, 158988187]
#   group 49496: subnetwork_ids=[49496, 49611] seeds=[158817196, 189724540]
#   group 49550: subnetwork_ids=[49550, 49695] seeds=[129409140, 158360779]

# %%
print(txn_expanded.shape)
txn_expanded.head(1)
# Out:
# (63800, 5)
#     txn_id  hop  subnetwork_id  seed_txn  merged_subnetwork_id
# 0  3084073    0              0   3084073                     0

# %%
print(txn_final.shape)
print(txn_final['merged_subnetwork_id'].nunique())
txn_final.head(1)
# Out:
# (49707, 4)
# 26012
#    merged_subnetwork_id   txn_id  min_hop  \
# 0                     0  3084073        0
#
#                                       seeds_in_group
# 0  [3084073, 9907558, 36385394, 39915271, 2303317...

# %%
print(edges_expanded.shape)
edges_expanded.head(1)
# Out:
# (31804, 7)
#    src_txn_id  dst_txn_id  src_txn_hop  dst_txn_hop  subnetwork_id  seed_txn  \
# 0     3084073   230658142            0            1              0   3084073
#
#    merged_subnetwork_id
# 0                     0

# %%
print(edges_final.shape)
print(edges_final['merged_subnetwork_id'].nunique()) # <-- Only 6123 networks have more than 2 nodes in the subnetwork (i.e. 1 edge).
edges_final.head(1)
# Out:
# (24293, 5)
# 6123
#    merged_subnetwork_id  src_txn_id  dst_txn_id  min_src_hop  min_dst_hop
# 0                     0     3084073   230658142            0            1

# %% [markdown]
# Build network summary table

# %%
summary_final = build_report.summarise_subnetworks(
    txn_expanded, edges_expanded,
    id_col="merged_subnetwork_id",   # <- merged group id from the overlap step
    sort_by="size"
)

# %%
print(len(summary_final))
summary_final.head()
# Out:
# 26012
#    merged_subnetwork_id                                            txn_ids  \
# 0                 17742  [101586718, 130897027, 138779422, 162026612, 1...
# 1                 17750  [19042162, 21210721, 22539188, 25321055, 42227...
# 2                 22362  [25749848, 31657337, 42996770, 64534421, 80201...
# 3                 31404  [14140455, 17006093, 21398242, 28202941, 12142...
# 4                 16356  [10856574, 98902423, 98902477, 98961227, 98961...
#
#    node_count  edge_count  depth  \
# 0         394         438     15
# 1         370        4263     68
# 2         314         357      6
# 3         254         291      5
# 4         225         244      6
#
#                                                seeds  seed_count  \
# 0  [130897027, 176149522, 298005149, 306112320, 3...         223
# 1  [21210721, 42227626, 45587478, 58502892, 73240...         130
# 2  [25749848, 31657337, 42996770, 64534421, 80201...         228
# 3  [14140455, 17006093, 21398242, 28202941, 13925...         158
# 4  [10856574, 98902423, 98902477, 98961227, 98961...         146
#
#    linked_txn_count
# 0               171
# 1               240
# 2                86
# 3                96
# 4                79

# %% [markdown]
# Check the distribution of subnetworks by node count in the dataset

# %%
# 1) Pull the node counts as integers
s = pd.to_numeric(summary_final["node_count"], errors="coerce").dropna().astype(int)
n = int(s.size)

# 2) Distribution table (ascending by node_count)
dist = (
    s.value_counts()
     .sort_index()
     .rename_axis("node_count")
     .reset_index(name="count")
)
dist["pct_population"] = (dist["count"] / n * 100).round(2)
dist["cum_count"] = dist["count"].cumsum()
dist["cum_pct_population"] = (dist["cum_count"] / n * 100).round(2)

dist

# 76% of the subnetworks are composed of only 1 illicit node.
# Out:
#     node_count  count  pct_population  cum_count  cum_pct_population
# 0            1  19889         76.4600      19889             76.4600
# 1            2   3552         13.6600      23441             90.1200
# 2            3    993          3.8200      24434             93.9300
# 3            4    467          1.8000      24901             95.7300
# 4            5    276          1.0600      25177             96.7900
# 5            6    158          0.6100      25335             97.4000
# 6            7    108          0.4200      25443             97.8100
# 7            8     78          0.3000      25521             98.1100
# 8            9     64          0.2500      25585             98.3600
# 9           10     46          0.1800      25631             98.5400
# 10          11     51          0.2000      25682             98.7300
# 11          12     32          0.1200      25714             98.8500
# 12          13     22          0.0800      25736             98.9400
# 13          14     24          0.0900      25760             99.0300
# 14          15     17          0.0700      25777             99.1000
# 15          16     22          0.0800      25799             99.1800
# 16          17     10          0.0400      25809             99.2200
# 17          18     14          0.0500      25823             99.2700
# 18          19     10          0.0400      25833             99.3100
# 19          20     15          0.0600      25848             99.3700
# 20          21     11          0.0400      25859             99.4100
# 21          22     14          0.0500      25873             99.4700
# 22          23     10          0.0400      25883             99.5000
# 23          24      7          0.0300      25890             99.5300
# 24          25      2          0.0100      25892             99.5400
# 25          26      4          0.0200      25896             99.5500
# 26          27      4          0.0200      25900             99.5700
# 27          28      6          0.0200      25906             99.5900
# 28          29      5          0.0200      25911             99.6100
# 29          30      3          0.0100      25914             99.6200
# 30          31      6          0.0200      25920             99.6500
# 31          32      4          0.0200      25924             99.6600
# 32          33      2          0.0100      25926             99.6700
# 33          34      6          0.0200      25932             99.6900
# 34          35      1          0.0000      25933             99.7000
# 35          36      1          0.0000      25934             99.7000
# 36          37      4          0.0200      25938             99.7200
# 37          38      1          0.0000      25939             99.7200
# 38          39      3          0.0100      25942             99.7300
# 39          40      6          0.0200      25948             99.7500
# 40          41      2          0.0100      25950             99.7600
# 41          42      1          0.0000      25951             99.7700
# 42          43      1          0.0000      25952             99.7700
# 43          44      1          0.0000      25953             99.7700
# 44          45      3          0.0100      25956             99.7800
# 45          47      3          0.0100      25959             99.8000
# 46          48      1          0.0000      25960             99.8000
# 47          49      1          0.0000      25961             99.8000
# 48          51      3          0.0100      25964             99.8200
# 49          52      1          0.0000      25965             99.8200
# 50          53      1          0.0000      25966             99.8200
# 51          55      1          0.0000      25967             99.8300
# 52          56      1          0.0000      25968             99.8300
# 53          63      1          0.0000      25969             99.8300
# 54          64      1          0.0000      25970             99.8400
# 55          68      1          0.0000      25971             99.8400
# 56          71      1          0.0000      25972             99.8500
# 57          73      1          0.0000      25973             99.8500
# 58          76      2          0.0100      25975             99.8600
# 59          77      1          0.0000      25976             99.8600
# 60          78      1          0.0000      25977             99.8700
# 61          80      1          0.0000      25978             99.8700
# 62          81      1          0.0000      25979             99.8700
# 63          85      1          0.0000      25980             99.8800
# 64          89      1          0.0000      25981             99.8800
# 65          91      2          0.0100      25983             99.8900
# 66         100      1          0.0000      25984             99.8900
# 67         104      1          0.0000      25985             99.9000
# 68         112      1          0.0000      25986             99.9000
# 69         117      1          0.0000      25987             99.9000
# 70         119      1          0.0000      25988             99.9100
# 71         127      1          0.0000      25989             99.9100
# 72         128      1          0.0000      25990             99.9200
# 73         130      1          0.0000      25991             99.9200
# 74         132      1          0.0000      25992             99.9200
# 75         135      1          0.0000      25993             99.9300
# 76         136      2          0.0100      25995             99.9300
# 77         137      1          0.0000      25996             99.9400
# 78         139      1          0.0000      25997             99.9400
# 79         149      1          0.0000      25998             99.9500
# 80         152      1          0.0000      25999             99.9500
# 81         159      1          0.0000      26000             99.9500
# 82         163      1          0.0000      26001             99.9600
# 83         183      1          0.0000      26002             99.9600
# 84         186      1          0.0000      26003             99.9700
# 85         192      1          0.0000      26004             99.9700
# 86         193      1          0.0000      26005             99.9700
# 87         211      1          0.0000      26006             99.9800
# 88         224      1          0.0000      26007             99.9800
# 89         225      1          0.0000      26008             99.9800
# 90         254      1          0.0000      26009             99.9900
# 91         314      1          0.0000      26010             99.9900
# 92         370      1          0.0000      26011            100.0000
# 93         394      1          0.0000      26012            100.0000

# %% [markdown]
# --------------
# ##### Export Subnetwork Tables to BigQuery
# --------------

# %%
# Define your project ID
project_id = 'extreme-torch-467913-m6'

# %%
# Save DataFrame to BigQuery
to_gbq(dataframe = txn_expanded, destination_table = 'networks.network_txn_expanded', project_id=project_id, if_exists='replace')
to_gbq(dataframe = txn_final, destination_table = 'networks.network_txn_final', project_id=project_id, if_exists='replace')
to_gbq(dataframe = edges_expanded, destination_table = 'networks.network_edges_expanded', project_id=project_id, if_exists='replace')
to_gbq(dataframe = edges_final, destination_table = 'networks.network_edges_final', project_id=project_id, if_exists='replace')
to_gbq(dataframe = summary_final, destination_table = 'networks.network_summary', project_id=project_id, if_exists='replace')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 8004.40it/s]
# 100%|██████████| 1/1 [00:00<00:00, 9709.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 9279.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 9845.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10180.35it/s]

# %% [markdown]
# END
