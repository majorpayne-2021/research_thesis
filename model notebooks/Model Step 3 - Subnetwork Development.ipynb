# %% [markdown]
# ### Notebook Overview: Model Step 3 – Subnetwork Development
#
# This notebook constructs illicit-only subnetworks from the classified Bitcoin transaction dataset. It represents the third stage of the AML detection pipeline and operationalises the subgraph extraction methodology described in the thesis. The goal is to isolate self-contained clusters of illicit activity that can be further analysed and ranked.
#
# **Purpose**
# The notebook transforms the classified transaction data into directed graph structures that reflect the movement of Bitcoin between transactions. Starting from transactions predicted as illicit, a forward breadth-first search (BFS) expansion identifies all reachable transactions, creating a self-contained subnetwork that captures the flow of funds within that illicit cluster.
#
# **Key Steps**
# - Import transaction predictions and edgelist data from BigQuery.
# - Filter to include only transactions classified as illicit.
# - Use a directed graph representation (txn–txn) to model Bitcoin flows between transactions.
# - Perform a forward BFS from each illicit transaction to trace all connected downstream nodes.
# - Assign unique Subnetwork IDs and compute basic graph properties (e.g., size, node/edge count, total BTC transferred).
# - Export subnetwork tables to BigQuery for ranking and visualisation in the next stage.
#
# This process produces a collection of reproducible subnetworks that represent individual clusters of illicit Bitcoin activity. By isolating and structuring these networks, subsequent ranking and visualisation can focus on the most influential or financially significant regions of the transaction graph.
#
# **Context and Attribution**
# This notebook forms part of the technical work developed in support of the research thesis titled:
# _“Detection, Ranking and Visualisation of Money Laundering Networks on the Bitcoin Blockchain”_
# by Jennifer Payne (RMIT University).
#
# GitHub Repository: [https://github.com/majorpayne-2021/rmit_master_thesis](https://github.com/majorpayne-2021/rmit_master_thesis)
# Elliptic++ Dataset Source: [https://github.com/git-disl/EllipticPlusPlus](https://github.com/git-disl/EllipticPlusPlus)

# %%
# Data cleaning and manipulation
import pandas as pd
import numpy as np
import math
import time

# GCP libraries
from pandas_gbq import to_gbq # write pandas df to a GCP BigQuery table
import gcsfs
import importlib.util
import os
import inspect

# Set up display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# Suppress FutureWarnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# --------------
# ##### Read in Txn Subnetwork Classes & Modules
# --------------

# %%
# Define bucket and file path
bucket_name = "thesis_classes"
file_name = "txn_subnetworks.py"
gcs_path = f"gs://{bucket_name}/{file_name}"

# Initialize GCS filesystem
fs = gcsfs.GCSFileSystem()

# Local filename to save the script temporarily
local_file = f"/tmp/{file_name}"

# Download the file from GCS to local storage
fs.get(gcs_path, local_file)

# Dynamically import the module
module_name = "txn_subnetworks"
spec = importlib.util.spec_from_file_location(module_name, local_file)
module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(module)

# %%
# Use inspect to get classes and functions
classes = [name for name, obj in inspect.getmembers(module, inspect.isclass)]

# Print results
print("Classes in module:")
for cls in classes:
    print(f"  - {cls}")
# Out:
# Classes in module:
#   - Line2D
#   - build_txn_subnetwork
#   - combinations
#   - defaultdict
#   - reporting
#   - visualise_subnetwork

# %%
# Instantiate the classes
build_network = module.build_txn_subnetwork()
build_report = module.reporting()

# %% [markdown]
# --------------
# ##### Read in Datasets
# --------------

# %%
# Get txn edgelist
# %%bigquery df_txn_edgelist
select * from `extreme-torch-467913-m6.txn.txn_edgelist`;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df_txn_edgelist.head(1)
# Out:
#       txId1  txId2
# 0  36186840   1076

# %%
# get txn prediction
# %%bigquery df_txn_pred
select * from `extreme-torch-467913-m6.txn.txn_pred_final`;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df_txn_pred.head(1)
# Out:
#         txId  Time step  class class_label     pred_model  \
# 0  230550390          1      2       Licit  Random Forest
#
#    pred_model_threshold  pred_proba  pred_class pred_class_label  final_class  \
# 0                0.4000      0.0932           0            Licit            0
#
#   final_class_label
# 0             Licit

# %%
list_illicit_seeds = df_txn_pred[(df_txn_pred['final_class_label'] == 'Illicit')]['txId'].tolist()

# %%
len(list_illicit_seeds)
# Out:
# 28542

# %% [markdown]
# --------------
# ##### Build Subnetworks for all Illicit Nodes
# --------------

# %% [markdown]
# Build subnetwork

# %%
start_time = time.time()

# 1) Build naive (possibly overlapping) subnetworks per seed
nodes_all, edges_all = build_network.build_subnetworks_naive(
    edges_df=df_txn_edgelist,
    labels_df=df_txn_pred,
    seed_txns=list_illicit_seeds,
    progress=True,
    progress_every=1000,   # summary every 100 seeds
)

end_time = time.time()
elapsed_minutes = (end_time - start_time) / 60
print(f"Function took {elapsed_minutes:.2f} minutes")
# Out:
# Commencing subnetwork development from seed nodes. seeds=28542  update_per_batch=1000
# [  1000/28542] single node network: 844  |  multi-node network: 156  (cumulative single: 844, multi: 156)  largest_nodes=6 (seed=232359167)
# [  2000/28542] single node network: 782  |  multi-node network: 218  (cumulative single: 1626, multi: 374)  largest_nodes=10 (seed=191191261)
# [  3000/28542] single node network: 757  |  multi-node network: 243  (cumulative single: 2383, multi: 617)  largest_nodes=10 (seed=191191261)
# [  4000/28542] single node network: 791  |  multi-node network: 209  (cumulative single: 3174, multi: 826)  largest_nodes=10 (seed=191191261)
# [  5000/28542] single node network: 748  |  multi-node network: 252  (cumulative single: 3922, multi: 1078)  largest_nodes=13 (seed=235427528)
# [  6000/28542] single node network: 764  |  multi-node network: 236  (cumulative single: 4686, multi: 1314)  largest_nodes=13 (seed=235427528)
# [  7000/28542] single node network: 701  |  multi-node network: 299  (cumulative single: 5387, multi: 1613)  largest_nodes=13 (seed=235427528)
# [  8000/28542] single node network: 628  |  multi-node network: 372  (cumulative single: 6015, multi: 1985)  largest_nodes=13 (seed=235427528)
# [  9000/28542] single node network: 625  |  multi-node network: 375  (cumulative single: 6640, multi: 2360)  largest_nodes=13 (seed=235427528)
# [ 10000/28542] single node network: 557  |  multi-node network: 443  (cumulative single: 7197, multi: 2803)  largest_nodes=24 (seed=114124039)
# [ 11000/28542] single node network: 381  |  multi-node network: 619  (cumulative single: 7578, multi: 3422)  largest_nodes=25 (seed=321987855)
# [ 12000/28542] single node network: 608  |  multi-node network: 392  (cumulative single: 8186, multi: 3814)  largest_nodes=25 (seed=321987855)
# [ 13000/28542] single node network: 428  |  multi-node network: 572  (cumulative single: 8614, multi: 4386)  largest_nodes=27 (seed=289228146)
# [ 14000/28542] single node network: 498  |  multi-node network: 502  (cumulative single: 9112, multi: 4888)  largest_nodes=27 (seed=289228146)
# [ 15000/28542] single node network: 545  |  multi-node network: 455  (cumulative single: 9657, multi: 5343)  largest_nodes=27 (seed=289228146)
# [ 16000/28542] single node network: 425  |  multi-node network: 575  (cumulative single: 10082, multi: 5918)  largest_nodes=183 (seed=46085970)
# [ 17000/28542] single node network: 511  |  multi-node network: 489  (cumulative single: 10593, multi: 6407)  largest_nodes=183 (seed=46085970)
# [ 18000/28542] single node network: 610  |  multi-node network: 390  (cumulative single: 11203, multi: 6797)  largest_nodes=183 (seed=46085970)
# [ 19000/28542] single node network: 547  |  multi-node network: 453  (cumulative single: 11750, multi: 7250)  largest_nodes=183 (seed=46085970)
# [ 20000/28542] single node network: 734  |  multi-node network: 266  (cumulative single: 12484, multi: 7516)  largest_nodes=183 (seed=46085970)
# [ 21000/28542] single node network: 731  |  multi-node network: 269  (cumulative single: 13215, multi: 7785)  largest_nodes=183 (seed=46085970)
# [ 22000/28542] single node network: 767  |  multi-node network: 233  (cumulative single: 13982, multi: 8018)  largest_nodes=183 (seed=46085970)
# [ 23000/28542] single node network: 720  |  multi-node network: 280  (cumulative single: 14702, multi: 8298)  largest_nodes=183 (seed=46085970)
# [ 24000/28542] single node network: 718  |  multi-node network: 282  (cumulative single: 15420, multi: 8580)  largest_nodes=183 (seed=46085970)
# [ 25000/28542] single node network: 697  |  multi-node network: 303  (cumulative single: 16117, multi: 8883)  largest_nodes=183 (seed=46085970)
# [ 26000/28542] single node network: 666  |  multi-node network: 334  (cumulative single: 16783, multi: 9217)  largest_nodes=183 (seed=46085970)
# [ 27000/28542] single node network: 769  |  multi-node network: 231  (cumulative single: 17552, multi: 9448)  largest_nodes=183 (seed=46085970)
# [ 28000/28542] single node network: 526  |  multi-node network: 474  (cumulative single: 18078, multi: 9922)  largest_nodes=183 (seed=46085970)
# Seed list scanning is now complete. seeds=28542  single node network=18425 (64.6%)  multi-node network=10117 (35.4%)  largest_nodes=183 (seed=46085970)
# Function took 40.24 minutes

# %% [markdown]
# Deduplicate subnetworks which are a subset of a larger subnetwork

# %%
# 2) Deduplicate: drop any subnetwork whose node set is a subset of another
nodes_dedup, edges_dedup, dedup_report, id_map = build_network.deduplicate_subnetworks_by_node_subset(
    nodes_all, edges_all, relabel=False, progress=True
)
# Out:
# Dedup by node-subset: 28542 → 21020 subnetworks kept (7522 removed).
#   - drop 44 (seed=91787015) ⊆ kept 131 (seed=230586841)
#   - drop 45 (seed=232375025) ⊆ kept 148 (seed=230451709)
#   - drop 48 (seed=231994234) ⊆ kept 92 (seed=231994227)
#   - drop 51 (seed=233997270) ⊆ kept 121 (seed=232359167)
#   - drop 54 (seed=2718109) ⊆ kept 69 (seed=230586765)
#   - drop 59 (seed=232345695) ⊆ kept 89 (seed=232364856)
#   - drop 62 (seed=230330969) ⊆ kept 87 (seed=91224338)
#   - drop 63 (seed=231994241) ⊆ kept 92 (seed=231994227)
#   - drop 67 (seed=233997266) ⊆ kept 121 (seed=232359167)
#   - drop 72 (seed=230582115) ⊆ kept 60 (seed=231994199)
#   - drop 75 (seed=37232608) ⊆ kept 87 (seed=91224338)
#   - drop 76 (seed=60492142) ⊆ kept 124 (seed=231994189)
#   - drop 77 (seed=230586846) ⊆ kept 131 (seed=230586841)
#   - drop 85 (seed=231994103) ⊆ kept 79 (seed=231994093)
#   - drop 88 (seed=230540205) ⊆ kept 121 (seed=232359167)
#   - drop 90 (seed=62111535) ⊆ kept 89 (seed=232364856)
#   - drop 91 (seed=230402461) ⊆ kept 84 (seed=230402464)
#   - drop 94 (seed=22508445) ⊆ kept 80 (seed=232366613)
#   - drop 98 (seed=230330975) ⊆ kept 87 (seed=91224338)
#   - drop 100 (seed=230569374) ⊆ kept 86 (seed=31730193)
#   - drop 102 (seed=232377194) ⊆ kept 50 (seed=230331777)
#   - drop 104 (seed=231994202) ⊆ kept 60 (seed=231994199)
#   - drop 106 (seed=232375027) ⊆ kept 148 (seed=230451709)
#   - drop 107 (seed=231994080) ⊆ kept 47 (seed=144657595)
#   - drop 110 (seed=230401687) ⊆ kept 112 (seed=230401350)
#   - drop 111 (seed=58140282) ⊆ kept 52 (seed=232634240)
#   - drop 114 (seed=232608734) ⊆ kept 121 (seed=232359167)
#   - drop 115 (seed=86711289) ⊆ kept 95 (seed=231994205)
#   - drop 116 (seed=230814629) ⊆ kept 79 (seed=231994093)
#   - drop 119 (seed=230586868) ⊆ kept 139 (seed=53204358)
#   - drop 122 (seed=32484448) ⊆ kept 47 (seed=144657595)
#   - drop 125 (seed=2302253) ⊆ kept 124 (seed=231994189)
#   - drop 126 (seed=232895350) ⊆ kept 80 (seed=232366613)
#   - drop 127 (seed=230401717) ⊆ kept 112 (seed=230401350)
#   - drop 128 (seed=53637885) ⊆ kept 86 (seed=31730193)
#   - drop 135 (seed=231994232) ⊆ kept 92 (seed=231994227)
#   - drop 136 (seed=51571237) ⊆ kept 121 (seed=232359167)
#   - drop 137 (seed=230400865) ⊆ kept 83 (seed=230569371)
#   - drop 138 (seed=230451671) ⊆ kept 105 (seed=231994024)
#   - drop 143 (seed=91416769) ⊆ kept 86 (seed=31730193)
#   - drop 146 (seed=232895771) ⊆ kept 117 (seed=232895769)
#   - drop 147 (seed=82937696) ⊆ kept 47 (seed=144657595)
#   - drop 172 (seed=230658142) ⊆ kept 0 (seed=3084073)
#   - drop 173 (seed=27405707) ⊆ kept 50 (seed=230331777)
#   - drop 174 (seed=75603986) ⊆ kept 187 (seed=79480955)
#   - drop 178 (seed=232000573) ⊆ kept 185 (seed=232000574)
#   - drop 181 (seed=231136221) ⊆ kept 190 (seed=14407957)
#   - drop 182 (seed=35125414) ⊆ kept 191 (seed=231184466)
#   - drop 184 (seed=233393437) ⊆ kept 186 (seed=232688102)
#   - drop 188 (seed=5119724) ⊆ kept 189 (seed=212382148)
#   - drop 192 (seed=87889652) ⊆ kept 197 (seed=231193618)
#   - drop 193 (seed=3880946) ⊆ kept 198 (seed=81421232)
#   - drop 202 (seed=17863556) ⊆ kept 17 (seed=232455961)
#   - drop 215 (seed=232023197) ⊆ kept 218 (seed=230531151)
#   - drop 258 (seed=310457364) ⊆ kept 305 (seed=309927402)
#   - drop 301 (seed=310067990) ⊆ kept 297 (seed=309938432)
#   - drop 302 (seed=310415582) ⊆ kept 297 (seed=309938432)
#   - drop 309 (seed=310415897) ⊆ kept 316 (seed=309970292)
#   - drop 313 (seed=310414968) ⊆ kept 335 (seed=312807984)
#   - drop 314 (seed=310414787) ⊆ kept 325 (seed=310414790)
#   - drop 321 (seed=310064831) ⊆ kept 358 (seed=312115193)
#   - drop 324 (seed=310415048) ⊆ kept 335 (seed=312807984)
#   - drop 326 (seed=309927727) ⊆ kept 317 (seed=309927730)
#   - drop 328 (seed=310067206) ⊆ kept 331 (seed=309970289)
#   - drop 333 (seed=310064836) ⊆ kept 358 (seed=312115193)
#   - drop 338 (seed=310415586) ⊆ kept 297 (seed=309938432)
#   - drop 340 (seed=310415767) ⊆ kept 316 (seed=309970292)
#   - drop 344 (seed=310065960) ⊆ kept 317 (seed=309927730)
#   - drop 345 (seed=247114712) ⊆ kept 318 (seed=310066495)
#   - drop 347 (seed=236798499) ⊆ kept 358 (seed=312115193)
#   - drop 349 (seed=310067210) ⊆ kept 331 (seed=309970289)
#   - drop 351 (seed=310419869) ⊆ kept 318 (seed=310066495)
#   - drop 352 (seed=310068450) ⊆ kept 316 (seed=309970292)
#   - drop 356 (seed=310415320) ⊆ kept 310 (seed=310415405)
#   - drop 373 (seed=310484373) ⊆ kept 387 (seed=312940219)
#   - drop 378 (seed=310420237) ⊆ kept 358 (seed=312115193)
#   - drop 395 (seed=310075518) ⊆ kept 399 (seed=134371258)
#   - drop 397 (seed=310075149) ⊆ kept 406 (seed=310075151)
#   - drop 412 (seed=310459382) ⊆ kept 310 (seed=310415405)
#   - drop 416 (seed=312217303) ⊆ kept 346 (seed=309927738)
#   - drop 419 (seed=312881634) ⊆ kept 327 (seed=309930098)
#   - drop 438 (seed=245791235) ⊆ kept 514 (seed=246065037)
#   - drop 487 (seed=245162316) ⊆ kept 492 (seed=244282218)
#   - drop 488 (seed=245430339) ⊆ kept 492 (seed=244282218)
#   - drop 496 (seed=245162042) ⊆ kept 492 (seed=244282218)
#   - drop 499 (seed=245786770) ⊆ kept 492 (seed=244282218)
#   - drop 507 (seed=245811295) ⊆ kept 511 (seed=245787009)
#   - drop 518 (seed=245427441) ⊆ kept 498 (seed=244659797)
#   - drop 522 (seed=245789076) ⊆ kept 514 (seed=246065037)
#   - drop 527 (seed=119264177) ⊆ kept 514 (seed=246065037)
#   - drop 528 (seed=241985683) ⊆ kept 498 (seed=244659797)
#   - drop 571 (seed=28387608) ⊆ kept 654 (seed=88979033)
#   - drop 576 (seed=86720686) ⊆ kept 623 (seed=86720131)
#   - drop 601 (seed=279437707) ⊆ kept 573 (seed=87743860)
#   - drop 609 (seed=19786836) ⊆ kept 616 (seed=86546606)
#   - drop 618 (seed=86721196) ⊆ kept 616 (seed=86546606)
#   - drop 620 (seed=279125608) ⊆ kept 617 (seed=1842885)
#   - drop 621 (seed=86715022) ⊆ kept 619 (seed=18470309)
#   - drop 625 (seed=7660709) ⊆ kept 619 (seed=18470309)
#   - drop 628 (seed=86900129) ⊆ kept 641 (seed=86714561)
#   - drop 629 (seed=87604182) ⊆ kept 616 (seed=86546606)
#   - drop 631 (seed=9587540) ⊆ kept 616 (seed=86546606)
#   - drop 633 (seed=279008519) ⊆ kept 617 (seed=1842885)
#   - drop 638 (seed=8740239) ⊆ kept 614 (seed=86610426)
#   - drop 639 (seed=86810200) ⊆ kept 596 (seed=279925683)
#   - drop 643 (seed=86761325) ⊆ kept 707 (seed=279004203)
#   - drop 644 (seed=70209736) ⊆ kept 641 (seed=86714561)
#   - drop 656 (seed=86720122) ⊆ kept 623 (seed=86720131)
#   - drop 659 (seed=279424082) ⊆ kept 702 (seed=44995911)
#   - drop 662 (seed=258961960) ⊆ kept 698 (seed=96258779)
#   - drop 671 (seed=250450096) ⊆ kept 652 (seed=279133780)
#   - drop 672 (seed=67943877) ⊆ kept 641 (seed=86714561)
#   - drop 678 (seed=87606969) ⊆ kept 682 (seed=86589161)
#   - drop 690 (seed=87707396) ⊆ kept 641 (seed=86714561)
#   - drop 693 (seed=279437696) ⊆ kept 641 (seed=86714561)
#   - drop 695 (seed=86725177) ⊆ kept 647 (seed=86725179)
#   - drop 704 (seed=86706815) ⊆ kept 653 (seed=86706819)
#   - drop 710 (seed=97107057) ⊆ kept 655 (seed=87697210)
#   - drop 736 (seed=224654893) ⊆ kept 728 (seed=224655093)
#   - drop 742 (seed=225689154) ⊆ kept 747 (seed=225689150)
#   - drop 744 (seed=225689158) ⊆ kept 747 (seed=225689150)
#   - drop 755 (seed=225341767) ⊆ kept 774 (seed=226689101)
#   - drop 766 (seed=78215171) ⊆ kept 780 (seed=183095531)
#   - drop 798 (seed=224196225) ⊆ kept 803 (seed=226400308)
#   - drop 802 (seed=225898967) ⊆ kept 823 (seed=183746270)
#   - drop 809 (seed=224695303) ⊆ kept 819 (seed=224203931)
#   - drop 813 (seed=224195617) ⊆ kept 804 (seed=226400327)
#   - drop 815 (seed=224697457) ⊆ kept 811 (seed=66230923)
#   - drop 816 (seed=224204149) ⊆ kept 823 (seed=183746270)
#   - drop 827 (seed=224204146) ⊆ kept 823 (seed=183746270)
#   - drop 830 (seed=225349188) ⊆ kept 729 (seed=225055156)
#   - drop 833 (seed=225366376) ⊆ kept 728 (seed=224655093)
#   - drop 842 (seed=225711361) ⊆ kept 787 (seed=225715271)
#   - drop 879 (seed=121712094) ⊆ kept 891 (seed=9605827)
#   - drop 881 (seed=121885039) ⊆ kept 866 (seed=8866984)
#   - drop 884 (seed=121885010) ⊆ kept 866 (seed=8866984)
#   - drop 893 (seed=103558851) ⊆ kept 920 (seed=121657236)
#   - drop 903 (seed=121855218) ⊆ kept 943 (seed=121743487)
#   - drop 911 (seed=121855276) ⊆ kept 912 (seed=121712535)
#   - drop 922 (seed=121712510) ⊆ kept 920 (seed=121657236)
#   - drop 925 (seed=134722161) ⊆ kept 906 (seed=8961748)
#   - drop 927 (seed=134722164) ⊆ kept 906 (seed=8961748)
#   - drop 928 (seed=121259962) ⊆ kept 941 (seed=121259960)
#   - drop 929 (seed=121712852) ⊆ kept 930 (seed=121610162)
#   - drop 942 (seed=121802124) ⊆ kept 948 (seed=121295571)
#   - drop 944 (seed=134722158) ⊆ kept 906 (seed=8961748)
#   - drop 949 (seed=53419873) ⊆ kept 906 (seed=8961748)
#   - drop 958 (seed=94121693) ⊆ kept 1267 (seed=94121917)
#   - drop 983 (seed=94654135) ⊆ kept 1336 (seed=94373276)
#   - drop 985 (seed=98623027) ⊆ kept 1342 (seed=94372683)
#   - drop 989 (seed=94682526) ⊆ kept 1011 (seed=98652540)
#   - drop 993 (seed=94370920) ⊆ kept 1394 (seed=94370921)
#   - drop 994 (seed=98651288) ⊆ kept 1314 (seed=98622995)
#   - drop 1002 (seed=94654161) ⊆ kept 1297 (seed=94299583)
#   - drop 1005 (seed=94682082) ⊆ kept 1426 (seed=98629513)
#   - drop 1010 (seed=98623109) ⊆ kept 1437 (seed=94658328)
#   - drop 1022 (seed=94386398) ⊆ kept 1279 (seed=96347349)
#   - drop 1024 (seed=94653822) ⊆ kept 1422 (seed=94653823)
#   - drop 1053 (seed=96550490) ⊆ kept 1211 (seed=94386702)
#   - drop 1055 (seed=94148647) ⊆ kept 1565 (seed=94148639)
#   - drop 1059 (seed=94299047) ⊆ kept 1180 (seed=94299048)
#   - drop 1060 (seed=94304704) ⊆ kept 1528 (seed=94125547)
#   - drop 1065 (seed=94370777) ⊆ kept 1408 (seed=94299895)
#   - drop 1096 (seed=94370493) ⊆ kept 1497 (seed=94370658)
#   - drop 1105 (seed=98671117) ⊆ kept 1315 (seed=98670812)
#   - drop 1110 (seed=94654132) ⊆ kept 1230 (seed=94393322)
#   - drop 1143 (seed=94371218) ⊆ kept 1488 (seed=94371220)
#   - drop 1151 (seed=115115468) ⊆ kept 1167 (seed=94386704)
#   - drop 1155 (seed=94371211) ⊆ kept 1409 (seed=94371214)
#   - drop 1173 (seed=94127776) ⊆ kept 1078 (seed=94122250)
#   - drop 1196 (seed=94371031) ⊆ kept 1508 (seed=94371032)
#   - drop 1198 (seed=94299108) ⊆ kept 1169 (seed=94112842)
#   - drop 1200 (seed=94654156) ⊆ kept 1369 (seed=94299574)
#   - drop 1214 (seed=94371233) ⊆ kept 1171 (seed=94371235)
#   - drop 1224 (seed=94371033) ⊆ kept 1029 (seed=94123979)
#   - drop 1233 (seed=94654133) ⊆ kept 1360 (seed=94373283)
#   - drop 1234 (seed=94654139) ⊆ kept 1352 (seed=94299580)
#   - drop 1258 (seed=94654140) ⊆ kept 1414 (seed=94373739)
#   - drop 1270 (seed=98626751) ⊆ kept 1303 (seed=94372886)
#   - drop 1272 (seed=94129514) ⊆ kept 1439 (seed=94111982)
#   - drop 1275 (seed=94125533) ⊆ kept 1310 (seed=94137810)
#   - drop 1280 (seed=94520801) ⊆ kept 1482 (seed=94299416)
#   - drop 1284 (seed=94123339) ⊆ kept 1279 (seed=96347349)
#   - drop 1286 (seed=94123343) ⊆ kept 1393 (seed=94123350)
#   - drop 1289 (seed=94517550) ⊆ kept 1276 (seed=94514808)
#   - drop 1293 (seed=84370891) ⊆ kept 1403 (seed=94051990)
#   - drop 1319 (seed=99222168) ⊆ kept 1341 (seed=94123384)
#   - drop 1321 (seed=96545576) ⊆ kept 1341 (seed=94123384)
#   - drop 1323 (seed=94372607) ⊆ kept 1413 (seed=94003168)
#   - drop 1325 (seed=96446560) ⊆ kept 1350 (seed=96446555)
#   - drop 1327 (seed=94187714) ⊆ kept 1504 (seed=115081089)
#   - drop 1329 (seed=94481288) ⊆ kept 1299 (seed=94481280)
#   - drop 1331 (seed=94482168) ⊆ kept 1307 (seed=94481275)
#   - drop 1333 (seed=94551532) ⊆ kept 1279 (seed=96347349)
#   - drop 1335 (seed=94372603) ⊆ kept 1413 (seed=94003168)
#   - drop 1338 (seed=94123922) ⊆ kept 1029 (seed=94123979)
#   - drop 1339 (seed=94481353) ⊆ kept 1299 (seed=94481280)
#   - drop 1348 (seed=94374208) ⊆ kept 1355 (seed=94123692)
#   - drop 1353 (seed=94689740) ⊆ kept 1489 (seed=98629063)
#   - drop 1354 (seed=99222753) ⊆ kept 1412 (seed=94002870)
#   - drop 1356 (seed=94126495) ⊆ kept 1479 (seed=94126482)
#   - drop 1357 (seed=96432891) ⊆ kept 1345 (seed=96432714)
#   - drop 1367 (seed=94654271) ⊆ kept 1342 (seed=94372683)
#   - drop 1368 (seed=96446440) ⊆ kept 1514 (seed=96446436)
#   - drop 1377 (seed=94372894) ⊆ kept 1341 (seed=94123384)
#   - drop 1380 (seed=94654269) ⊆ kept 1461 (seed=94654255)
#   - drop 1382 (seed=94372918) ⊆ kept 1355 (seed=94123692)
#   - drop 1387 (seed=94687585) ⊆ kept 1438 (seed=98629833)
#   - drop 1388 (seed=94059605) ⊆ kept 1400 (seed=94059598)
#   - drop 1390 (seed=94688507) ⊆ kept 1281 (seed=98768726)
#   - drop 1395 (seed=94373976) ⊆ kept 1279 (seed=96347349)
#   - drop 1398 (seed=94834612) ⊆ kept 1484 (seed=94373503)
#   - drop 1419 (seed=99222039) ⊆ kept 1271 (seed=94001389)
#   - drop 1421 (seed=98625115) ⊆ kept 1434 (seed=94372262)
#   - drop 1423 (seed=94374185) ⊆ kept 1355 (seed=94123692)
#   - drop 1429 (seed=94127771) ⊆ kept 1078 (seed=94122250)
#   - drop 1432 (seed=94377604) ⊆ kept 1391 (seed=94377146)
#   - drop 1436 (seed=94373780) ⊆ kept 1352 (seed=94299580)
#   - drop 1440 (seed=94481286) ⊆ kept 1299 (seed=94481280)
#   - drop 1449 (seed=94644518) ⊆ kept 1424 (seed=94631452)
#   - drop 1454 (seed=96446730) ⊆ kept 1350 (seed=96446555)
#   - drop 1455 (seed=99224660) ⊆ kept 1277 (seed=98661148)
#   - drop 1467 (seed=94123341) ⊆ kept 1279 (seed=96347349)
#   - drop 1469 (seed=94654272) ⊆ kept 1342 (seed=94372683)
#   - drop 1475 (seed=93990111) ⊆ kept 1332 (seed=93990106)
#   - drop 1477 (seed=94373979) ⊆ kept 1402 (seed=94618913)
#   - drop 1485 (seed=94373981) ⊆ kept 1402 (seed=94618913)
#   - drop 1499 (seed=94184649) ⊆ kept 1347 (seed=94184658)
#   - drop 1501 (seed=94324993) ⊆ kept 1403 (seed=94051990)
#   - drop 1510 (seed=94683607) ⊆ kept 1468 (seed=94119393)
#   - drop 1512 (seed=94658603) ⊆ kept 1403 (seed=94051990)
#   - drop 1519 (seed=48243178) ⊆ kept 1342 (seed=94372683)
#   - drop 1521 (seed=94324979) ⊆ kept 1411 (seed=2889415)
#   - drop 1522 (seed=94137806) ⊆ kept 1310 (seed=94137810)
#   - drop 1526 (seed=98734847) ⊆ kept 1403 (seed=94051990)
#   - drop 1529 (seed=94167767) ⊆ kept 1403 (seed=94051990)
#   - drop 1532 (seed=96564456) ⊆ kept 1403 (seed=94051990)
#   - drop 1534 (seed=115106096) ⊆ kept 1029 (seed=94123979)
#   - drop 1535 (seed=94460766) ⊆ kept 1444 (seed=94123379)
#   - drop 1538 (seed=94654134) ⊆ kept 1459 (seed=94366773)
#   - drop 1540 (seed=94654137) ⊆ kept 1435 (seed=94373746)
#   - drop 1564 (seed=94385993) ⊆ kept 1476 (seed=94190113)
#   - drop 1566 (seed=94654057) ⊆ kept 1474 (seed=94654059)
#   - drop 1571 (seed=99222000) ⊆ kept 1468 (seed=94119393)
#   - drop 1576 (seed=94654172) ⊆ kept 1483 (seed=94361451)
#   - drop 1582 (seed=94299423) ⊆ kept 1528 (seed=94125547)
#   - drop 1607 (seed=142084577) ⊆ kept 1874 (seed=190015685)
#   - drop 1609 (seed=92544521) ⊆ kept 1911 (seed=191191261)
#   - drop 1627 (seed=190452289) ⊆ kept 1894 (seed=190016840)
#   - drop 1629 (seed=190427083) ⊆ kept 1939 (seed=190015494)
#   - drop 1633 (seed=190005883) ⊆ kept 1949 (seed=54504625)
#   - drop 1638 (seed=191107595) ⊆ kept 1900 (seed=191107596)
#   - drop 1640 (seed=191107597) ⊆ kept 1702 (seed=189800862)
#   - drop 1643 (seed=190427069) ⊆ kept 1917 (seed=190015790)
#   - drop 1649 (seed=191113011) ⊆ kept 1732 (seed=190877900)
#   - drop 1651 (seed=190426239) ⊆ kept 1807 (seed=22717814)
#   - drop 1652 (seed=190427052) ⊆ kept 1866 (seed=189800868)
#   - drop 1655 (seed=190005880) ⊆ kept 2058 (seed=190005881)
#   - drop 1661 (seed=191108348) ⊆ kept 1833 (seed=190432666)
#   - drop 1663 (seed=191107806) ⊆ kept 1834 (seed=190432704)
#   - drop 1666 (seed=190005864) ⊆ kept 1907 (seed=190005865)
#   - drop 1672 (seed=190426245) ⊆ kept 1923 (seed=190015197)
#   - drop 1676 (seed=191107780) ⊆ kept 1814 (seed=191107782)
#   - drop 1691 (seed=191203844) ⊆ kept 1983 (seed=191192071)
#   - drop 1693 (seed=222791191) ⊆ kept 1928 (seed=192136233)
#   - drop 1696 (seed=191631948) ⊆ kept 1810 (seed=191110884)
#   - drop 1708 (seed=191557390) ⊆ kept 1940 (seed=190038831)
#   - drop 1718 (seed=192099711) ⊆ kept 1749 (seed=192099709)
#   - drop 1720 (seed=190427249) ⊆ kept 1851 (seed=1532109)
#   - drop 1722 (seed=36525351) ⊆ kept 1858 (seed=189800885)
#   - drop 1727 (seed=190006224) ⊆ kept 2038 (seed=190006225)
#   - drop 1730 (seed=93935773) ⊆ kept 1908 (seed=190017332)
#   - drop 1731 (seed=191108962) ⊆ kept 1914 (seed=189799148)
#   - drop 1736 (seed=189800499) ⊆ kept 1911 (seed=191191261)
#   - drop 1755 (seed=7675168) ⊆ kept 1868 (seed=190847816)
#   - drop 1767 (seed=192125472) ⊆ kept 1774 (seed=192125468)
#   - drop 1771 (seed=191410865) ⊆ kept 1791 (seed=191410078)
#   - drop 1783 (seed=155382862) ⊆ kept 1860 (seed=192127276)
#   - drop 1785 (seed=190016607) ⊆ kept 1825 (seed=190016601)
#   - drop 1790 (seed=192126566) ⊆ kept 1847 (seed=192126456)
#   - drop 1796 (seed=192104062) ⊆ kept 1803 (seed=192104055)
#   - drop 1804 (seed=191132699) ⊆ kept 1794 (seed=20309993)
#   - drop 1809 (seed=190432423) ⊆ kept 1917 (seed=190015790)
#   - drop 1813 (seed=190426242) ⊆ kept 1807 (seed=22717814)
#   - drop 1815 (seed=191632680) ⊆ kept 1827 (seed=191111249)
#   - drop 1819 (seed=190825629) ⊆ kept 1941 (seed=190434250)
#   - drop 1823 (seed=189984406) ⊆ kept 2059 (seed=189984660)
#   - drop 1824 (seed=192125967) ⊆ kept 1821 (seed=192125962)
#   - drop 1828 (seed=191191262) ⊆ kept 1911 (seed=191191261)
#   - drop 1831 (seed=190013172) ⊆ kept 1911 (seed=191191261)
#   - drop 1835 (seed=93936154) ⊆ kept 1866 (seed=189800868)
#   - drop 1836 (seed=190012085) ⊆ kept 1861 (seed=190012065)
#   - drop 1838 (seed=189800856) ⊆ kept 1702 (seed=189800862)
#   - drop 1840 (seed=192125597) ⊆ kept 1774 (seed=192125468)
#   - drop 1841 (seed=191386351) ⊆ kept 1911 (seed=191191261)
#   - drop 1843 (seed=190020429) ⊆ kept 1864 (seed=190020413)
#   - drop 1848 (seed=190013166) ⊆ kept 1911 (seed=191191261)
#   - drop 1849 (seed=190434551) ⊆ kept 1941 (seed=190434250)
#   - drop 1850 (seed=7620976) ⊆ kept 1911 (seed=191191261)
#   - drop 1853 (seed=192127129) ⊆ kept 1855 (seed=19303393)
#   - drop 1862 (seed=190013182) ⊆ kept 1807 (seed=22717814)
#   - drop 1863 (seed=190432429) ⊆ kept 1917 (seed=190015790)
#   - drop 1873 (seed=179584554) ⊆ kept 1942 (seed=190013732)
#   - drop 1876 (seed=190015793) ⊆ kept 1917 (seed=190015790)
#   - drop 1879 (seed=191108964) ⊆ kept 1914 (seed=189799148)
#   - drop 1881 (seed=190010038) ⊆ kept 1911 (seed=191191261)
#   - drop 1882 (seed=190015807) ⊆ kept 1917 (seed=190015790)
#   - drop 1886 (seed=190017134) ⊆ kept 1917 (seed=190015790)
#   - drop 1887 (seed=192127039) ⊆ kept 1878 (seed=192127033)
#   - drop 1888 (seed=190014303) ⊆ kept 1930 (seed=189801215)
#   - drop 1889 (seed=190848303) ⊆ kept 1845 (seed=190848308)
#   - drop 1890 (seed=190016405) ⊆ kept 1917 (seed=190015790)
#   - drop 1892 (seed=190432817) ⊆ kept 1885 (seed=64466460)
#   - drop 1897 (seed=190017287) ⊆ kept 1866 (seed=189800868)
#   - drop 1898 (seed=190434549) ⊆ kept 1941 (seed=190434250)
#   - drop 1899 (seed=189800832) ⊆ kept 1911 (seed=191191261)
#   - drop 1901 (seed=190016401) ⊆ kept 1917 (seed=190015790)
#   - drop 1904 (seed=191654675) ⊆ kept 1924 (seed=191134144)
#   - drop 1910 (seed=191127869) ⊆ kept 1906 (seed=190435728)
#   - drop 1920 (seed=190016822) ⊆ kept 1825 (seed=190016601)
#   - drop 1922 (seed=190015525) ⊆ kept 1874 (seed=190015685)
#   - drop 1929 (seed=15093493) ⊆ kept 1806 (seed=190016837)
#   - drop 1931 (seed=190015796) ⊆ kept 1917 (seed=190015790)
#   - drop 1933 (seed=190014509) ⊆ kept 1702 (seed=189800862)
#   - drop 1936 (seed=190434068) ⊆ kept 1702 (seed=189800862)
#   - drop 1937 (seed=190017330) ⊆ kept 1908 (seed=190017332)
#   - drop 1946 (seed=190015194) ⊆ kept 1923 (seed=190015197)
#   - drop 1956 (seed=191247958) ⊆ kept 1844 (seed=191247952)
#   - drop 1958 (seed=191430138) ⊆ kept 1683 (seed=191409136)
#   - drop 1960 (seed=190826177) ⊆ kept 1866 (seed=189800868)
#   - drop 1964 (seed=190448361) ⊆ kept 1923 (seed=190015197)
#   - drop 1965 (seed=190020422) ⊆ kept 1864 (seed=190020413)
#   - drop 1967 (seed=193060612) ⊆ kept 1861 (seed=190012065)
#   - drop 1969 (seed=192125760) ⊆ kept 1811 (seed=14886191)
#   - drop 1971 (seed=193060646) ⊆ kept 1861 (seed=190012065)
#   - drop 1972 (seed=192125486) ⊆ kept 1774 (seed=192125468)
#   - drop 1986 (seed=192125610) ⊆ kept 1774 (seed=192125468)
#   - drop 1988 (seed=190448358) ⊆ kept 1930 (seed=189801215)
#   - drop 1989 (seed=191784154) ⊆ kept 1866 (seed=189800868)
#   - drop 1993 (seed=192136137) ⊆ kept 1928 (seed=192136233)
#   - drop 1994 (seed=190008850) ⊆ kept 1918 (seed=190009102)
#   - drop 1997 (seed=190426175) ⊆ kept 1979 (seed=79367072)
#   - drop 2001 (seed=190829747) ⊆ kept 1880 (seed=192084724)
#   - drop 2005 (seed=190826195) ⊆ kept 1918 (seed=190009102)
#   - drop 2006 (seed=26731774) ⊆ kept 1770 (seed=191132692)
#   - drop 2011 (seed=191764978) ⊆ kept 2012 (seed=191764969)
#   - drop 2013 (seed=191631370) ⊆ kept 1914 (seed=189799148)
#   - drop 2029 (seed=192096994) ⊆ kept 2033 (seed=192095548)
#   - drop 2030 (seed=189799145) ⊆ kept 1914 (seed=189799148)
#   - drop 2042 (seed=41249229) ⊆ kept 1870 (seed=189805127)
#   - drop 2065 (seed=226629481) ⊆ kept 2532 (seed=179270531)
#   - drop 2070 (seed=179098885) ⊆ kept 2580 (seed=226669375)
#   - drop 2072 (seed=184443795) ⊆ kept 2561 (seed=226669368)
#   - drop 2073 (seed=226629459) ⊆ kept 2516 (seed=226586488)
#   - drop 2082 (seed=226629497) ⊆ kept 2735 (seed=226580790)
#   - drop 2094 (seed=121285263) ⊆ kept 2449 (seed=226580628)
#   - drop 2104 (seed=226579037) ⊆ kept 2239 (seed=175782592)
#   - drop 2105 (seed=175522678) ⊆ kept 2542 (seed=175048250)
#   - drop 2106 (seed=179061035) ⊆ kept 2097 (seed=175771419)
#   - drop 2109 (seed=226667641) ⊆ kept 2317 (seed=179025344)
#   - drop 2112 (seed=179039634) ⊆ kept 2485 (seed=198221240)
#   - drop 2119 (seed=179039635) ⊆ kept 2299 (seed=226682043)
#   - drop 2123 (seed=5298273) ⊆ kept 2453 (seed=222886065)
#   - drop 2141 (seed=179039633) ⊆ kept 2595 (seed=226692761)
#   - drop 2143 (seed=226666704) ⊆ kept 2466 (seed=174758947)
#   - drop 2144 (seed=179100048) ⊆ kept 2438 (seed=5298384)
#   - drop 2147 (seed=179039638) ⊆ kept 2456 (seed=213406254)
#   - drop 2149 (seed=175406504) ⊆ kept 2483 (seed=174759156)
#   - drop 2154 (seed=179039631) ⊆ kept 2103 (seed=175434388)
#   - drop 2160 (seed=175756710) ⊆ kept 2540 (seed=13912763)
#   - drop 2177 (seed=179120469) ⊆ kept 2396 (seed=179120466)
#   - drop 2178 (seed=5298236) ⊆ kept 2618 (seed=175544518)
#   - drop 2181 (seed=226666695) ⊆ kept 2542 (seed=175048250)
#   - drop 2185 (seed=175755821) ⊆ kept 2758 (seed=175410711)
#   - drop 2187 (seed=175046606) ⊆ kept 2479 (seed=33356722)
#   - drop 2195 (seed=226667559) ⊆ kept 2564 (seed=192703497)
#   - drop 2197 (seed=222886059) ⊆ kept 2594 (seed=175061431)
#   - drop 2199 (seed=175756281) ⊆ kept 2570 (seed=175433937)
#   - drop 2206 (seed=179039630) ⊆ kept 2543 (seed=226669526)
#   - drop 2208 (seed=226667175) ⊆ kept 2567 (seed=226630262)
#   - drop 2221 (seed=186031106) ⊆ kept 2475 (seed=175411114)
#   - drop 2224 (seed=175756274) ⊆ kept 2334 (seed=175062175)
#   - drop 2237 (seed=226667167) ⊆ kept 2461 (seed=200623725)
#   - drop 2260 (seed=175435152) ⊆ kept 2511 (seed=175404467)
#   - drop 2263 (seed=175046772) ⊆ kept 2439 (seed=120687916)
#   - drop 2267 (seed=226668060) ⊆ kept 2501 (seed=124942041)
#   - drop 2269 (seed=175755628) ⊆ kept 2593 (seed=175507922)
#   - drop 2271 (seed=175046769) ⊆ kept 2760 (seed=174759163)
#   - drop 2272 (seed=175756857) ⊆ kept 2629 (seed=175534017)
#   - drop 2281 (seed=222886064) ⊆ kept 2551 (seed=175759428)
#   - drop 2283 (seed=179039640) ⊆ kept 2815 (seed=226669358)
#   - drop 2290 (seed=179171691) ⊆ kept 2737 (seed=65928277)
#   - drop 2301 (seed=205921115) ⊆ kept 2474 (seed=174759148)
#   - drop 2303 (seed=175757684) ⊆ kept 2233 (seed=175434878)
#   - drop 2304 (seed=179039776) ⊆ kept 2535 (seed=146051893)
#   - drop 2306 (seed=175046937) ⊆ kept 2480 (seed=117536420)
#   - drop 2309 (seed=218020239) ⊆ kept 2736 (seed=226786194)
#   - drop 2311 (seed=205248696) ⊆ kept 2627 (seed=110051656)
#   - drop 2312 (seed=226668039) ⊆ kept 2593 (seed=175507922)
#   - drop 2313 (seed=226668089) ⊆ kept 2389 (seed=226629847)
#   - drop 2315 (seed=175046935) ⊆ kept 2537 (seed=174759181)
#   - drop 2316 (seed=175756775) ⊆ kept 2533 (seed=175411820)
#   - drop 2321 (seed=179039767) ⊆ kept 2742 (seed=226695100)
#   - drop 2322 (seed=179100516) ⊆ kept 2738 (seed=175048242)
#   - drop 2323 (seed=226668066) ⊆ kept 2536 (seed=218190265)
#   - drop 2327 (seed=216384922) ⊆ kept 2385 (seed=175758299)
#   - drop 2335 (seed=175757554) ⊆ kept 2737 (seed=65928277)
#   - drop 2336 (seed=179039626) ⊆ kept 2491 (seed=198221236)
#   - drop 2341 (seed=226668579) ⊆ kept 2531 (seed=183035845)
#   - drop 2343 (seed=175757665) ⊆ kept 2743 (seed=175534667)
#   - drop 2346 (seed=226668057) ⊆ kept 2351 (seed=175439148)
#   - drop 2348 (seed=175089406) ⊆ kept 2611 (seed=174764428)
#   - drop 2352 (seed=175407499) ⊆ kept 2243 (seed=174763686)
#   - drop 2356 (seed=175757332) ⊆ kept 2609 (seed=175438583)
#   - drop 2359 (seed=205920729) ⊆ kept 2816 (seed=175759710)
#   - drop 2366 (seed=179107411) ⊆ kept 2413 (seed=175416534)
#   - drop 2368 (seed=175047477) ⊆ kept 2367 (seed=174758796)
#   - drop 2370 (seed=179108022) ⊆ kept 2416 (seed=179108015)
#   - drop 2371 (seed=179042488) ⊆ kept 2384 (seed=175415704)
#   - drop 2372 (seed=185602768) ⊆ kept 2424 (seed=175047482)
#   - drop 2373 (seed=175050555) ⊆ kept 2375 (seed=175050552)
#   - drop 2376 (seed=175761581) ⊆ kept 2433 (seed=175416030)
#   - drop 2380 (seed=175409330) ⊆ kept 2399 (seed=175408608)
#   - drop 2383 (seed=175049042) ⊆ kept 2367 (seed=174758796)
#   - drop 2387 (seed=179042783) ⊆ kept 2395 (seed=179042759)
#   - drop 2388 (seed=191931821) ⊆ kept 2421 (seed=179004068)
#   - drop 2398 (seed=175051277) ⊆ kept 2430 (seed=174760944)
#   - drop 2410 (seed=24752898) ⊆ kept 2511 (seed=175404467)
#   - drop 2415 (seed=179042705) ⊆ kept 2395 (seed=179042759)
#   - drop 2417 (seed=179004064) ⊆ kept 2421 (seed=179004068)
#   - drop 2420 (seed=175409116) ⊆ kept 2399 (seed=175408608)
#   - drop 2422 (seed=175051579) ⊆ kept 2375 (seed=175050552)
#   - drop 2426 (seed=175409338) ⊆ kept 2399 (seed=175408608)
#   - drop 2427 (seed=179042778) ⊆ kept 2395 (seed=179042759)
#   - drop 2445 (seed=179039073) ⊆ kept 2561 (seed=226669368)
#   - drop 2446 (seed=175410060) ⊆ kept 2431 (seed=175047497)
#   - drop 2448 (seed=175758689) ⊆ kept 2475 (seed=175411114)
#   - drop 2451 (seed=175410826) ⊆ kept 2737 (seed=65928277)
#   - drop 2452 (seed=179046146) ⊆ kept 2393 (seed=170872918)
#   - drop 2457 (seed=179270532) ⊆ kept 2351 (seed=175439148)
#   - drop 2460 (seed=179104528) ⊆ kept 2552 (seed=179039609)
#   - drop 2465 (seed=199613093) ⊆ kept 2467 (seed=179029073)
#   - drop 2469 (seed=189240321) ⊆ kept 2525 (seed=220552607)
#   - drop 2471 (seed=175758696) ⊆ kept 2618 (seed=175544518)
#   - drop 2476 (seed=179039608) ⊆ kept 2580 (seed=226669375)
#   - drop 2486 (seed=181190422) ⊆ kept 2618 (seed=175544518)
#   - drop 2487 (seed=175093611) ⊆ kept 2436 (seed=175093608)
#   - drop 2490 (seed=179039070) ⊆ kept 2561 (seed=226669368)
#   - drop 2495 (seed=175411118) ⊆ kept 2474 (seed=174759148)
#   - drop 2497 (seed=179001968) ⊆ kept 2566 (seed=175411798)
#   - drop 2500 (seed=179038940) ⊆ kept 2601 (seed=179038943)
#   - drop 2503 (seed=87348210) ⊆ kept 2467 (seed=179029073)
#   - drop 2504 (seed=175410705) ⊆ kept 2594 (seed=175061431)
#   - drop 2507 (seed=179103450) ⊆ kept 2506 (seed=179039082)
#   - drop 2508 (seed=44081248) ⊆ kept 2461 (seed=200623725)
#   - drop 2509 (seed=179038755) ⊆ kept 2235 (seed=179038891)
#   - drop 2514 (seed=5298349) ⊆ kept 2593 (seed=175507922)
#   - drop 2515 (seed=179103444) ⊆ kept 2527 (seed=179103446)
#   - drop 2518 (seed=179100250) ⊆ kept 2438 (seed=5298384)
#   - drop 2522 (seed=115351209) ⊆ kept 2382 (seed=179038737)
#   - drop 2523 (seed=179105985) ⊆ kept 2447 (seed=179038902)
#   - drop 2526 (seed=175488274) ⊆ kept 2437 (seed=175488167)
#   - drop 2528 (seed=179105636) ⊆ kept 2611 (seed=174764428)
#   - drop 2529 (seed=179105973) ⊆ kept 2561 (seed=226669368)
#   - drop 2538 (seed=175048831) ⊆ kept 2243 (seed=174763686)
#   - drop 2545 (seed=179105743) ⊆ kept 2431 (seed=175047497)
#   - drop 2548 (seed=175411861) ⊆ kept 2393 (seed=170872918)
#   - drop 2550 (seed=199569488) ⊆ kept 2458 (seed=225184613)
#   - drop 2553 (seed=205922315) ⊆ kept 2593 (seed=175507922)
#   - drop 2556 (seed=175759430) ⊆ kept 2594 (seed=175061431)
#   - drop 2560 (seed=175759445) ⊆ kept 2474 (seed=174759148)
#   - drop 2565 (seed=175048827) ⊆ kept 2474 (seed=174759148)
#   - drop 2572 (seed=226578722) ⊆ kept 2511 (seed=175404467)
#   - drop 2573 (seed=175048408) ⊆ kept 2483 (seed=174759156)
#   - drop 2574 (seed=31952158) ⊆ kept 2334 (seed=175062175)
#   - drop 2578 (seed=175759450) ⊆ kept 2393 (seed=170872918)
#   - drop 2579 (seed=179039605) ⊆ kept 2580 (seed=226669375)
#   - drop 2583 (seed=175110810) ⊆ kept 2597 (seed=174783408)
#   - drop 2585 (seed=179061034) ⊆ kept 2097 (seed=175771419)
#   - drop 2588 (seed=211486777) ⊆ kept 2438 (seed=5298384)
#   - drop 2602 (seed=151844114) ⊆ kept 2547 (seed=175048204)
#   - drop 2607 (seed=179101640) ⊆ kept 2462 (seed=175399158)
#   - drop 2610 (seed=195359527) ⊆ kept 2458 (seed=225184613)
#   - drop 2613 (seed=179029069) ⊆ kept 2467 (seed=179029073)
#   - drop 2617 (seed=226705227) ⊆ kept 2097 (seed=175771419)
#   - drop 2625 (seed=48904782) ⊆ kept 2462 (seed=175399158)
#   - drop 2630 (seed=175755078) ⊆ kept 2758 (seed=175410711)
#   - drop 2631 (seed=226599907) ⊆ kept 2626 (seed=175799946)
#   - drop 2634 (seed=226606242) ⊆ kept 2097 (seed=175771419)
#   - drop 2639 (seed=179111367) ⊆ kept 2772 (seed=179111372)
#   - drop 2642 (seed=181065775) ⊆ kept 2475 (seed=175411114)
#   - drop 2645 (seed=179111804) ⊆ kept 2594 (seed=175061431)
#   - drop 2646 (seed=175481458) ⊆ kept 2566 (seed=175411798)
#   - drop 2652 (seed=179021316) ⊆ kept 2399 (seed=175408608)
#   - drop 2667 (seed=179084696) ⊆ kept 2367 (seed=174758796)
#   - drop 2670 (seed=179084653) ⊆ kept 2399 (seed=175408608)
#   - drop 2682 (seed=179084647) ⊆ kept 2367 (seed=174758796)
#   - drop 2690 (seed=179084440) ⊆ kept 2362 (seed=175415665)
#   - drop 2692 (seed=179084655) ⊆ kept 2400 (seed=174760064)
#   - drop 2699 (seed=179084642) ⊆ kept 2399 (seed=175408608)
#   - drop 2706 (seed=179084651) ⊆ kept 2375 (seed=175050552)
#   - drop 2714 (seed=226667562) ⊆ kept 2300 (seed=175435177)
#   - drop 2716 (seed=5298340) ⊆ kept 2241 (seed=226586195)
#   - drop 2719 (seed=205248444) ⊆ kept 2638 (seed=175790574)
#   - drop 2721 (seed=175046597) ⊆ kept 2324 (seed=174763705)
#   - drop 2744 (seed=175142222) ⊆ kept 2722 (seed=175059886)
#   - drop 2746 (seed=184106940) ⊆ kept 2773 (seed=175075472)
#   - drop 2751 (seed=175142230) ⊆ kept 2722 (seed=175059886)
#   - drop 2753 (seed=226586261) ⊆ kept 2711 (seed=226464294)
#   - drop 2757 (seed=175756861) ⊆ kept 2159 (seed=175434874)
#   - drop 2759 (seed=220287063) ⊆ kept 2103 (seed=175434388)
#   - drop 2763 (seed=178912806) ⊆ kept 2767 (seed=179095234)
#   - drop 2765 (seed=179095198) ⊆ kept 2762 (seed=179095199)
#   - drop 2779 (seed=142357067) ⊆ kept 2778 (seed=144994729)
#   - drop 2783 (seed=181769456) ⊆ kept 2546 (seed=226629453)
#   - drop 2814 (seed=205920497) ⊆ kept 2462 (seed=175399158)
#   - drop 2819 (seed=122160849) ⊆ kept 2820 (seed=175480682)
#   - drop 2821 (seed=114565438) ⊆ kept 2820 (seed=175480682)
#   - drop 2832 (seed=226594555) ⊆ kept 2837 (seed=182135713)
#   - drop 2833 (seed=226594542) ⊆ kept 2837 (seed=182135713)
#   - drop 2835 (seed=198362299) ⊆ kept 2837 (seed=182135713)
#   - drop 2836 (seed=226594526) ⊆ kept 2837 (seed=182135713)
#   - drop 2838 (seed=182135069) ⊆ kept 2837 (seed=182135713)
#   - drop 2856 (seed=31500116) ⊆ kept 2854 (seed=179024144)
#   - drop 2898 (seed=68459514) ⊆ kept 3448 (seed=68459506)
#   - drop 2937 (seed=43522466) ⊆ kept 2990 (seed=43348468)
#   - drop 2955 (seed=43116103) ⊆ kept 3417 (seed=43007262)
#   - drop 3039 (seed=43325892) ⊆ kept 3415 (seed=43038024)
#   - drop 3155 (seed=42638124) ⊆ kept 2889 (seed=68466748)
#   - drop 3254 (seed=43004050) ⊆ kept 3445 (seed=43004053)
#   - drop 3278 (seed=42638128) ⊆ kept 3449 (seed=68460734)
#   - drop 3374 (seed=68589103) ⊆ kept 3409 (seed=68445923)
#   - drop 3391 (seed=43084779) ⊆ kept 3190 (seed=43084774)
#   - drop 3422 (seed=43115948) ⊆ kept 3417 (seed=43007262)
#   - drop 3431 (seed=42666336) ⊆ kept 3085 (seed=68445626)
#   - drop 3433 (seed=42666326) ⊆ kept 3085 (seed=68445626)
#   - drop 3451 (seed=43317326) ⊆ kept 3498 (seed=43007101)
#   - drop 3456 (seed=43517733) ⊆ kept 3430 (seed=43006688)
#   - drop 3460 (seed=43521039) ⊆ kept 3168 (seed=43005276)
#   - drop 3461 (seed=43140809) ⊆ kept 3453 (seed=41162086)
#   - drop 3466 (seed=43523023) ⊆ kept 3489 (seed=43329878)
#   - drop 3467 (seed=43325909) ⊆ kept 3486 (seed=43005393)
#   - drop 3469 (seed=43523025) ⊆ kept 3497 (seed=43006692)
#   - drop 3470 (seed=43523275) ⊆ kept 3485 (seed=43329905)
#   - drop 3471 (seed=43040433) ⊆ kept 3491 (seed=68444001)
#   - drop 3473 (seed=43522413) ⊆ kept 3490 (seed=42627131)
#   - drop 3475 (seed=43004059) ⊆ kept 3495 (seed=42627205)
#   - drop 3476 (seed=43525068) ⊆ kept 3492 (seed=43329869)
#   - drop 3478 (seed=43328381) ⊆ kept 3488 (seed=43005810)
#   - drop 3479 (seed=43523669) ⊆ kept 3487 (seed=43329862)
#   - drop 3481 (seed=43002761) ⊆ kept 3493 (seed=43002763)
#   - drop 3482 (seed=43327407) ⊆ kept 3498 (seed=43007101)
#   - drop 3483 (seed=42626820) ⊆ kept 3496 (seed=42626821)
#   - drop 3484 (seed=43327215) ⊆ kept 3494 (seed=43006524)
#   - drop 3499 (seed=43126689) ⊆ kept 3304 (seed=43032694)
#   - drop 3504 (seed=43522449) ⊆ kept 3518 (seed=43005262)
#   - drop 3505 (seed=42626807) ⊆ kept 3544 (seed=42626811)
#   - drop 3506 (seed=43325944) ⊆ kept 3514 (seed=43007137)
#   - drop 3508 (seed=43523308) ⊆ kept 3513 (seed=43523312)
#   - drop 3509 (seed=42626835) ⊆ kept 3524 (seed=58019594)
#   - drop 3510 (seed=43524391) ⊆ kept 3168 (seed=43005276)
#   - drop 3511 (seed=43003092) ⊆ kept 3520 (seed=43003094)
#   - drop 3512 (seed=43525243) ⊆ kept 3430 (seed=43006688)
#   - drop 3515 (seed=43329900) ⊆ kept 3430 (seed=43006688)
#   - drop 3516 (seed=43330203) ⊆ kept 3168 (seed=43005276)
#   - drop 3519 (seed=43005270) ⊆ kept 3168 (seed=43005276)
#   - drop 3521 (seed=42626837) ⊆ kept 3524 (seed=58019594)
#   - drop 3522 (seed=43007128) ⊆ kept 3514 (seed=43007137)
#   - drop 3523 (seed=43330210) ⊆ kept 3518 (seed=43005262)
#   - drop 3525 (seed=43006684) ⊆ kept 3430 (seed=43006688)
#   - drop 3529 (seed=42627141) ⊆ kept 3530 (seed=42627147)
#   - drop 3531 (seed=43007143) ⊆ kept 3530 (seed=42627147)
#   - drop 3542 (seed=43002732) ⊆ kept 3441 (seed=43002734)
#   - drop 3545 (seed=43327161) ⊆ kept 3570 (seed=43007124)
#   - drop 3566 (seed=43329928) ⊆ kept 3565 (seed=42627164)
#   - drop 3569 (seed=43006515) ⊆ kept 3565 (seed=42627164)
#   - drop 3573 (seed=43327208) ⊆ kept 3334 (seed=68589101)
#   - drop 3576 (seed=43327204) ⊆ kept 3585 (seed=43007170)
#   - drop 3592 (seed=43327209) ⊆ kept 3334 (seed=68589101)
#   - drop 3601 (seed=36627188) ⊆ kept 4086 (seed=234635618)
#   - drop 3611 (seed=36627173) ⊆ kept 3804 (seed=234391503)
#   - drop 3613 (seed=234174124) ⊆ kept 4085 (seed=234174126)
#   - drop 3622 (seed=234565881) ⊆ kept 4071 (seed=235473265)
#   - drop 3623 (seed=234861274) ⊆ kept 4048 (seed=235835367)
#   - drop 3627 (seed=234560103) ⊆ kept 4213 (seed=234169860)
#   - drop 3630 (seed=236112218) ⊆ kept 4012 (seed=234836322)
#   - drop 3633 (seed=234574794) ⊆ kept 4190 (seed=234635596)
#   - drop 3634 (seed=234830762) ⊆ kept 4191 (seed=234635605)
#   - drop 3649 (seed=234565876) ⊆ kept 4021 (seed=234169256)
#   - drop 3650 (seed=234559575) ⊆ kept 4075 (seed=234169863)
#   - drop 3655 (seed=113788733) ⊆ kept 4005 (seed=234836328)
#   - drop 3656 (seed=203221795) ⊆ kept 4089 (seed=64605833)
#   - drop 3672 (seed=234166251) ⊆ kept 4064 (seed=119691078)
#   - drop 3677 (seed=234565877) ⊆ kept 3946 (seed=235447100)
#   - drop 3686 (seed=234565904) ⊆ kept 4114 (seed=234850421)
#   - drop 3688 (seed=234574643) ⊆ kept 4092 (seed=234830771)
#   - drop 3697 (seed=234574628) ⊆ kept 4193 (seed=102250802)
#   - drop 3702 (seed=234574784) ⊆ kept 4083 (seed=135058916)
#   - drop 3704 (seed=234574631) ⊆ kept 4191 (seed=234635605)
#   - drop 3706 (seed=234560093) ⊆ kept 3795 (seed=234169124)
#   - drop 3719 (seed=234834380) ⊆ kept 4196 (seed=234635128)
#   - drop 3723 (seed=15966722) ⊆ kept 4069 (seed=234836380)
#   - drop 3726 (seed=234560074) ⊆ kept 4103 (seed=234560075)
#   - drop 3734 (seed=236114959) ⊆ kept 4009 (seed=234836238)
#   - drop 3736 (seed=234559577) ⊆ kept 4067 (seed=235427807)
#   - drop 3741 (seed=234559673) ⊆ kept 3774 (seed=234677930)
#   - drop 3742 (seed=234635127) ⊆ kept 4196 (seed=234635128)
#   - drop 3747 (seed=234565908) ⊆ kept 3988 (seed=234635584)
#   - drop 3754 (seed=234565902) ⊆ kept 4028 (seed=127319505)
#   - drop 3762 (seed=234574635) ⊆ kept 3860 (seed=234636475)
#   - drop 3766 (seed=234574977) ⊆ kept 4074 (seed=234835414)
#   - drop 3771 (seed=234559579) ⊆ kept 3979 (seed=235425127)
#   - drop 3772 (seed=234561902) ⊆ kept 4051 (seed=234561904)
#   - drop 3773 (seed=234636472) ⊆ kept 4144 (seed=234248795)
#   - drop 3775 (seed=234167193) ⊆ kept 4025 (seed=234167195)
#   - drop 3785 (seed=234565899) ⊆ kept 4054 (seed=64580922)
#   - drop 3799 (seed=113788568) ⊆ kept 4214 (seed=234561313)
#   - drop 3810 (seed=234167203) ⊆ kept 4024 (seed=234167204)
#   - drop 3814 (seed=234565896) ⊆ kept 4212 (seed=235427814)
#   - drop 3819 (seed=236114869) ⊆ kept 4073 (seed=234836387)
#   - drop 3823 (seed=234635115) ⊆ kept 4101 (seed=15624399)
#   - drop 3825 (seed=234565878) ⊆ kept 4003 (seed=64099657)
#   - drop 3828 (seed=113788742) ⊆ kept 3939 (seed=234561299)
#   - drop 3829 (seed=234561714) ⊆ kept 4049 (seed=234561715)
#   - drop 3833 (seed=234574647) ⊆ kept 4105 (seed=234168819)
#   - drop 3834 (seed=234167188) ⊆ kept 4079 (seed=234167190)
#   - drop 3835 (seed=234574783) ⊆ kept 3993 (seed=234835263)
#   - drop 3843 (seed=234195263) ⊆ kept 3695 (seed=234195259)
#   - drop 3849 (seed=234559581) ⊆ kept 4099 (seed=234830766)
#   - drop 3850 (seed=234560979) ⊆ kept 4062 (seed=234561297)
#   - drop 3852 (seed=234565918) ⊆ kept 4004 (seed=114786141)
#   - drop 3873 (seed=234347341) ⊆ kept 3876 (seed=235065253)
#   - drop 3875 (seed=234347337) ⊆ kept 3876 (seed=235065253)
#   - drop 3878 (seed=234890844) ⊆ kept 3927 (seed=234901693)
#   - drop 3884 (seed=234901301) ⊆ kept 3933 (seed=234901298)
#   - drop 3885 (seed=234567179) ⊆ kept 3943 (seed=234567181)
#   - drop 3892 (seed=234168371) ⊆ kept 3900 (seed=234168360)
#   - drop 3895 (seed=234890847) ⊆ kept 3967 (seed=234890841)
#   - drop 3899 (seed=234172894) ⊆ kept 3886 (seed=234890849)
#   - drop 3905 (seed=234563312) ⊆ kept 3896 (seed=234563318)
#   - drop 3910 (seed=234890881) ⊆ kept 3933 (seed=234901298)
#   - drop 3914 (seed=11810414) ⊆ kept 3926 (seed=234168369)
#   - drop 3918 (seed=234890913) ⊆ kept 3933 (seed=234901298)
#   - drop 3921 (seed=234172939) ⊆ kept 3916 (seed=234172933)
#   - drop 3929 (seed=234563321) ⊆ kept 3879 (seed=234168375)
#   - drop 3932 (seed=234168403) ⊆ kept 3893 (seed=234168405)
#   - drop 3934 (seed=234567533) ⊆ kept 3948 (seed=234172889)
#   - drop 3945 (seed=234168398) ⊆ kept 4076 (seed=235427528)
#   - drop 3951 (seed=99127165) ⊆ kept 4076 (seed=235427528)
#   - drop 3955 (seed=234635571) ⊆ kept 3999 (seed=234169275)
#   - drop 3959 (seed=234172882) ⊆ kept 3923 (seed=234890861)
#   - drop 3962 (seed=234172892) ⊆ kept 3886 (seed=234890849)
#   - drop 3966 (seed=234168407) ⊆ kept 3900 (seed=234168360)
#   - drop 3970 (seed=3008443) ⊆ kept 3880 (seed=234172888)
#   - drop 3972 (seed=234168772) ⊆ kept 3879 (seed=234168375)
#   - drop 3973 (seed=234227605) ⊆ kept 4056 (seed=234227455)
#   - drop 3974 (seed=234890831) ⊆ kept 3933 (seed=234901298)
#   - drop 3975 (seed=235065688) ⊆ kept 3933 (seed=234901298)
#   - drop 3978 (seed=234830763) ⊆ kept 4191 (seed=234635605)
#   - drop 3982 (seed=234169895) ⊆ kept 4076 (seed=235427528)
#   - drop 3983 (seed=234170023) ⊆ kept 4076 (seed=235427528)
#   - drop 3986 (seed=234209014) ⊆ kept 4076 (seed=235427528)
#   - drop 3992 (seed=234559970) ⊆ kept 4005 (seed=234836328)
#   - drop 3996 (seed=234565137) ⊆ kept 4086 (seed=234635618)
#   - drop 3998 (seed=234168960) ⊆ kept 3795 (seed=234169124)
#   - drop 4002 (seed=235428548) ⊆ kept 4076 (seed=235427528)
#   - drop 4015 (seed=234564642) ⊆ kept 4084 (seed=234169263)
#   - drop 4017 (seed=119877294) ⊆ kept 4190 (seed=234635596)
#   - drop 4019 (seed=234226564) ⊆ kept 4035 (seed=16349753)
#   - drop 4020 (seed=234392221) ⊆ kept 3860 (seed=234636475)
#   - drop 4026 (seed=234168400) ⊆ kept 4076 (seed=235427528)
#   - drop 4029 (seed=235819500) ⊆ kept 4110 (seed=234671094)
#   - drop 4030 (seed=234559675) ⊆ kept 3999 (seed=234169275)
#   - drop 4033 (seed=28601468) ⊆ kept 4105 (seed=234168819)
#   - drop 4036 (seed=11895535) ⊆ kept 4086 (seed=234635618)
#   - drop 4038 (seed=234169891) ⊆ kept 4076 (seed=235427528)
#   - drop 4039 (seed=234635611) ⊆ kept 3811 (seed=234180384)
#   - drop 4043 (seed=234564954) ⊆ kept 4076 (seed=235427528)
#   - drop 4045 (seed=234564496) ⊆ kept 4084 (seed=234169263)
#   - drop 4047 (seed=234574640) ⊆ kept 3811 (seed=234180384)
#   - drop 4053 (seed=235428537) ⊆ kept 4076 (seed=235427528)
#   - drop 4058 (seed=234597373) ⊆ kept 4128 (seed=15396947)
#   - drop 4061 (seed=70677319) ⊆ kept 4193 (seed=102250802)
#   - drop 4063 (seed=234564651) ⊆ kept 3871 (seed=234564653)
#   - drop 4065 (seed=1603222) ⊆ kept 4086 (seed=234635618)
#   - drop 4070 (seed=64151684) ⊆ kept 4193 (seed=102250802)
#   - drop 4080 (seed=234169273) ⊆ kept 3999 (seed=234169275)
#   - drop 4081 (seed=234564951) ⊆ kept 4076 (seed=235427528)
#   - drop 4087 (seed=234836357) ⊆ kept 4086 (seed=234635618)
#   - drop 4088 (seed=60925856) ⊆ kept 4105 (seed=234168819)
#   - drop 4090 (seed=11897560) ⊆ kept 4076 (seed=235427528)
#   - drop 4100 (seed=234836364) ⊆ kept 4086 (seed=234635618)
#   - drop 4109 (seed=236156854) ⊆ kept 3626 (seed=234432837)
#   - drop 4112 (seed=110050423) ⊆ kept 4099 (seed=234830766)
#   - drop 4116 (seed=236146893) ⊆ kept 4006 (seed=234636461)
#   - drop 4120 (seed=234354548) ⊆ kept 3908 (seed=234822689)
#   - drop 4132 (seed=234830768) ⊆ kept 4092 (seed=234830771)
#   - drop 4133 (seed=236166422) ⊆ kept 3637 (seed=234185136)
#   - drop 4134 (seed=234752706) ⊆ kept 3811 (seed=234180384)
#   - drop 4136 (seed=10438596) ⊆ kept 3708 (seed=235843729)
#   - drop 4142 (seed=234205923) ⊆ kept 3940 (seed=147156047)
#   - drop 4147 (seed=13619073) ⊆ kept 4126 (seed=234599186)
#   - drop 4151 (seed=234633461) ⊆ kept 4084 (seed=234169263)
#   - drop 4152 (seed=234380919) ⊆ kept 3644 (seed=234380922)
#   - drop 4154 (seed=234790576) ⊆ kept 4062 (seed=234561297)
#   - drop 4156 (seed=126727276) ⊆ kept 4130 (seed=234221799)
#   - drop 4157 (seed=234849682) ⊆ kept 4130 (seed=234221799)
#   - drop 4158 (seed=234432396) ⊆ kept 3637 (seed=234185136)
#   - drop 4159 (seed=234432660) ⊆ kept 3626 (seed=234432837)
#   - drop 4160 (seed=234559571) ⊆ kept 3999 (seed=234169275)
#   - drop 4163 (seed=234890810) ⊆ kept 3933 (seed=234901298)
#   - drop 4164 (seed=234891829) ⊆ kept 3900 (seed=234168360)
#   - drop 4166 (seed=234896846) ⊆ kept 4107 (seed=234667479)
#   - drop 4167 (seed=234899430) ⊆ kept 3933 (seed=234901298)
#   - drop 4171 (seed=234574630) ⊆ kept 4095 (seed=234661332)
#   - drop 4172 (seed=234677700) ⊆ kept 4037 (seed=234677702)
#   - drop 4183 (seed=234166496) ⊆ kept 4055 (seed=234166497)
#   - drop 4184 (seed=234565906) ⊆ kept 3830 (seed=235450246)
#   - drop 4192 (seed=234836367) ⊆ kept 3777 (seed=234836371)
#   - drop 4235 (seed=234833032) ⊆ kept 4236 (seed=212671387)
#   - drop 4245 (seed=351118256) ⊆ kept 4420 (seed=346382165)
#   - drop 4258 (seed=339006986) ⊆ kept 4408 (seed=346115586)
#   - drop 4281 (seed=280526762) ⊆ kept 4419 (seed=346376915)
#   - drop 4291 (seed=280526714) ⊆ kept 4373 (seed=331204699)
#   - drop 4302 (seed=280529087) ⊆ kept 4394 (seed=346378501)
#   - drop 4315 (seed=346376198) ⊆ kept 4447 (seed=346376199)
#   - drop 4317 (seed=399842665) ⊆ kept 4404 (seed=346099510)
#   - drop 4318 (seed=399846616) ⊆ kept 4383 (seed=377099329)
#   - drop 4324 (seed=280526795) ⊆ kept 4413 (seed=346099497)
#   - drop 4327 (seed=280526778) ⊆ kept 4316 (seed=346379573)
#   - drop 4351 (seed=346379224) ⊆ kept 4407 (seed=346099498)
#   - drop 4352 (seed=339006142) ⊆ kept 4403 (seed=346422656)
#   - drop 4361 (seed=346098816) ⊆ kept 4370 (seed=391002673)
#   - drop 4365 (seed=399842926) ⊆ kept 4386 (seed=391075266)
#   - drop 4368 (seed=346381300) ⊆ kept 4386 (seed=391075266)
#   - drop 4369 (seed=346099339) ⊆ kept 4386 (seed=391075266)
#   - drop 4371 (seed=346382161) ⊆ kept 4420 (seed=346382165)
#   - drop 4378 (seed=280526433) ⊆ kept 4407 (seed=346099498)
#   - drop 4381 (seed=346381308) ⊆ kept 4407 (seed=346099498)
#   - drop 4385 (seed=346098909) ⊆ kept 4375 (seed=293419323)
#   - drop 4389 (seed=346098857) ⊆ kept 4370 (seed=391002673)
#   - drop 4393 (seed=346381306) ⊆ kept 4386 (seed=391075266)
#   - drop 4398 (seed=346099336) ⊆ kept 4386 (seed=391075266)
#   - drop 4405 (seed=346378766) ⊆ kept 4413 (seed=346099497)
#   - drop 4406 (seed=373646740) ⊆ kept 4375 (seed=293419323)
#   - drop 4409 (seed=346383430) ⊆ kept 4401 (seed=346099494)
#   - drop 4415 (seed=233584607) ⊆ kept 4396 (seed=346099516)
#   - drop 4418 (seed=346377757) ⊆ kept 4373 (seed=331204699)
#   - drop 4424 (seed=361799049) ⊆ kept 4260 (seed=399684117)
#   - drop 4425 (seed=399682848) ⊆ kept 4379 (seed=352081296)
#   - drop 4427 (seed=265386877) ⊆ kept 4443 (seed=346104449)
#   - drop 4430 (seed=399966001) ⊆ kept 4472 (seed=375134635)
#   - drop 4431 (seed=346434858) ⊆ kept 4443 (seed=346104449)
#   - drop 4436 (seed=393845935) ⊆ kept 4472 (seed=375134635)
#   - drop 4446 (seed=304131385) ⊆ kept 4443 (seed=346104449)
#   - drop 4448 (seed=285572601) ⊆ kept 4466 (seed=346466096)
#   - drop 4450 (seed=399965557) ⊆ kept 4445 (seed=396291925)
#   - drop 4451 (seed=346434860) ⊆ kept 4443 (seed=346104449)
#   - drop 4452 (seed=346466717) ⊆ kept 4443 (seed=346104449)
#   - drop 4453 (seed=399848624) ⊆ kept 4433 (seed=399692533)
#   - drop 4454 (seed=346435403) ⊆ kept 4443 (seed=346104449)
#   - drop 4455 (seed=346466974) ⊆ kept 4443 (seed=346104449)
#   - drop 4458 (seed=395197322) ⊆ kept 4472 (seed=375134635)
#   - drop 4462 (seed=399965653) ⊆ kept 4445 (seed=396291925)
#   - drop 4463 (seed=399958424) ⊆ kept 4466 (seed=346466096)
#   - drop 4464 (seed=348146561) ⊆ kept 4443 (seed=346104449)
#   - drop 4468 (seed=294746675) ⊆ kept 4472 (seed=375134635)
#   - drop 4469 (seed=346466757) ⊆ kept 4443 (seed=346104449)
#   - drop 4478 (seed=390042628) ⊆ kept 4443 (seed=346104449)
#   - drop 4480 (seed=348367796) ⊆ kept 4432 (seed=399673632)
#   - drop 4483 (seed=401339607) ⊆ kept 4311 (seed=399692340)
#   - drop 4489 (seed=375342300) ⊆ kept 4404 (seed=346099510)
#   - drop 4495 (seed=346379341) ⊆ kept 4407 (seed=346099498)
#   - drop 4507 (seed=311582973) ⊆ kept 5004 (seed=339097073)
#   - drop 4521 (seed=339059390) ⊆ kept 4910 (seed=339057883)
#   - drop 4522 (seed=339553076) ⊆ kept 4753 (seed=339061886)
#   - drop 4523 (seed=340072827) ⊆ kept 5274 (seed=339643102)
#   - drop 4527 (seed=339267336) ⊆ kept 4898 (seed=339067209)
#   - drop 4528 (seed=339964511) ⊆ kept 5142 (seed=152978344)
#   - drop 4530 (seed=339057505) ⊆ kept 4772 (seed=339057507)
#   - drop 4535 (seed=339096358) ⊆ kept 4623 (seed=339062681)
#   - drop 4538 (seed=339120978) ⊆ kept 5056 (seed=37681929)
#   - drop 4540 (seed=339093928) ⊆ kept 5082 (seed=339093930)
#   - drop 4541 (seed=339648604) ⊆ kept 4552 (seed=339099872)
#   - drop 4568 (seed=339093567) ⊆ kept 5086 (seed=339093568)
#   - drop 4575 (seed=339553088) ⊆ kept 4912 (seed=339058290)
#   - drop 4580 (seed=339094191) ⊆ kept 4876 (seed=170160489)
#   - drop 4581 (seed=339094213) ⊆ kept 5008 (seed=339058549)
#   - drop 4597 (seed=339057498) ⊆ kept 4927 (seed=339057500)
#   - drop 4606 (seed=339093287) ⊆ kept 4994 (seed=339093289)
#   - drop 4611 (seed=339553018) ⊆ kept 4807 (seed=339088162)
#   - drop 4613 (seed=339120954) ⊆ kept 4976 (seed=339058294)
#   - drop 4618 (seed=339094219) ⊆ kept 5111 (seed=339094221)
#   - drop 4625 (seed=339093786) ⊆ kept 4958 (seed=339093790)
#   - drop 4628 (seed=339057185) ⊆ kept 4949 (seed=339057187)
#   - drop 4635 (seed=339120965) ⊆ kept 5027 (seed=339058392)
#   - drop 4636 (seed=339553080) ⊆ kept 5259 (seed=339058536)
#   - drop 4641 (seed=339057167) ⊆ kept 4904 (seed=339057170)
#   - drop 4642 (seed=339094506) ⊆ kept 5080 (seed=284128608)
#   - drop 4647 (seed=339093550) ⊆ kept 4961 (seed=339093551)
#   - drop 4653 (seed=339553028) ⊆ kept 5257 (seed=339058347)
#   - drop 4658 (seed=339094202) ⊆ kept 4915 (seed=339094204)
#   - drop 4659 (seed=339552997) ⊆ kept 5120 (seed=339063671)
#   - drop 4662 (seed=339057349) ⊆ kept 4708 (seed=339057351)
#   - drop 4663 (seed=339093595) ⊆ kept 4914 (seed=339093597)
#   - drop 4664 (seed=339094217) ⊆ kept 5039 (seed=339094218)
#   - drop 4670 (seed=339099824) ⊆ kept 4983 (seed=339099827)
#   - drop 4671 (seed=339096355) ⊆ kept 4962 (seed=339058275)
#   - drop 4676 (seed=339101053) ⊆ kept 4935 (seed=339058283)
#   - drop 4678 (seed=339553086) ⊆ kept 5217 (seed=339058555)
#   - drop 4680 (seed=339057154) ⊆ kept 5065 (seed=139667444)
#   - drop 4681 (seed=339057171) ⊆ kept 5053 (seed=339057175)
# ...
#   - drop 27599 (seed=3335117) ⊆ kept 27681 (seed=3334420)
#   - drop 27605 (seed=155600304) ⊆ kept 27692 (seed=155376441)
#   - drop 27606 (seed=155600310) ⊆ kept 27692 (seed=155376441)
#   - drop 27610 (seed=3335164) ⊆ kept 27820 (seed=3334334)
#   - drop 27615 (seed=155673572) ⊆ kept 27486 (seed=3468153)
#   - drop 27617 (seed=3336408) ⊆ kept 27537 (seed=3336442)
#   - drop 27618 (seed=17735512) ⊆ kept 27793 (seed=155190643)
#   - drop 27619 (seed=55575386) ⊆ kept 27830 (seed=55575066)
#   - drop 27623 (seed=40050173) ⊆ kept 27419 (seed=15424863)
#   - drop 27628 (seed=3334422) ⊆ kept 27681 (seed=3334420)
#   - drop 27629 (seed=3336400) ⊆ kept 27454 (seed=3335818)
#   - drop 27631 (seed=2145778) ⊆ kept 27831 (seed=2145446)
#   - drop 27634 (seed=11577237) ⊆ kept 28034 (seed=155156494)
#   - drop 27635 (seed=15222163) ⊆ kept 27614 (seed=155213440)
#   - drop 27640 (seed=62455) ⊆ kept 27535 (seed=155687769)
#   - drop 27642 (seed=3335093) ⊆ kept 27820 (seed=3334334)
#   - drop 27644 (seed=15510889) ⊆ kept 27507 (seed=3294772)
#   - drop 27645 (seed=18265553) ⊆ kept 27578 (seed=2149815)
#   - drop 27646 (seed=29629847) ⊆ kept 27692 (seed=155376441)
#   - drop 27652 (seed=155602990) ⊆ kept 27425 (seed=84739112)
#   - drop 27655 (seed=3336404) ⊆ kept 27454 (seed=3335818)
#   - drop 27656 (seed=13213859) ⊆ kept 27575 (seed=155398172)
#   - drop 27657 (seed=155677243) ⊆ kept 27486 (seed=3468153)
#   - drop 27658 (seed=4620453) ⊆ kept 27486 (seed=3468153)
#   - drop 27661 (seed=155652338) ⊆ kept 27577 (seed=155652334)
#   - drop 27662 (seed=2149202) ⊆ kept 27736 (seed=2149152)
#   - drop 27663 (seed=3289968) ⊆ kept 27760 (seed=155226713)
#   - drop 27664 (seed=4713518) ⊆ kept 27814 (seed=2176913)
#   - drop 27668 (seed=155602837) ⊆ kept 27425 (seed=84739112)
#   - drop 27669 (seed=155687408) ⊆ kept 27535 (seed=155687769)
#   - drop 27675 (seed=3336399) ⊆ kept 27538 (seed=3336466)
#   - drop 27676 (seed=7129980) ⊆ kept 27433 (seed=15424847)
#   - drop 27678 (seed=73273966) ⊆ kept 27728 (seed=155450753)
#   - drop 27680 (seed=155190850) ⊆ kept 27793 (seed=155190643)
#   - drop 27682 (seed=3339529) ⊆ kept 27461 (seed=9417386)
#   - drop 27684 (seed=155430490) ⊆ kept 27620 (seed=155430482)
#   - drop 27689 (seed=3335120) ⊆ kept 27839 (seed=3335102)
#   - drop 27691 (seed=2104684) ⊆ kept 27489 (seed=2104656)
#   - drop 27697 (seed=155411733) ⊆ kept 27745 (seed=155411732)
#   - drop 27698 (seed=155446728) ⊆ kept 27779 (seed=155446726)
#   - drop 27699 (seed=155446955) ⊆ kept 28037 (seed=155446949)
#   - drop 27701 (seed=2102129) ⊆ kept 27836 (seed=2102087)
#   - drop 27703 (seed=3335178) ⊆ kept 27839 (seed=3335102)
#   - drop 27707 (seed=10115306) ⊆ kept 28076 (seed=11570439)
#   - drop 27710 (seed=3335167) ⊆ kept 27839 (seed=3335102)
#   - drop 27713 (seed=6249342) ⊆ kept 27770 (seed=155415564)
#   - drop 27715 (seed=155445775) ⊆ kept 27820 (seed=3334334)
#   - drop 27724 (seed=155430511) ⊆ kept 27637 (seed=155430496)
#   - drop 27727 (seed=26773047) ⊆ kept 27521 (seed=155674590)
#   - drop 27731 (seed=36506525) ⊆ kept 27506 (seed=155687757)
#   - drop 27733 (seed=29272) ⊆ kept 27820 (seed=3334334)
#   - drop 27735 (seed=155468366) ⊆ kept 27908 (seed=7370044)
#   - drop 27738 (seed=135883618) ⊆ kept 27647 (seed=65699277)
#   - drop 27747 (seed=3289972) ⊆ kept 27590 (seed=147847340)
#   - drop 27749 (seed=155449059) ⊆ kept 27578 (seed=2149815)
#   - drop 27751 (seed=3335118) ⊆ kept 27537 (seed=3336442)
#   - drop 27754 (seed=155450759) ⊆ kept 27501 (seed=155398806)
#   - drop 27755 (seed=3336456) ⊆ kept 27538 (seed=3336466)
#   - drop 27758 (seed=13742559) ⊆ kept 27830 (seed=55575066)
#   - drop 27759 (seed=47639925) ⊆ kept 27692 (seed=155376441)
#   - drop 27762 (seed=155451755) ⊆ kept 27712 (seed=4608557)
#   - drop 27764 (seed=14934242) ⊆ kept 28034 (seed=155156494)
#   - drop 27765 (seed=155464256) ⊆ kept 27422 (seed=42013463)
#   - drop 27768 (seed=6874554) ⊆ kept 27763 (seed=7633457)
#   - drop 27769 (seed=121925775) ⊆ kept 27793 (seed=155190643)
#   - drop 27771 (seed=155437898) ⊆ kept 27753 (seed=85362638)
#   - drop 27773 (seed=118846132) ⊆ kept 27637 (seed=155430496)
#   - drop 27774 (seed=155460909) ⊆ kept 27763 (seed=7633457)
#   - drop 27778 (seed=22970104) ⊆ kept 28030 (seed=155484366)
#   - drop 27780 (seed=29777) ⊆ kept 27706 (seed=3335034)
#   - drop 27781 (seed=2149174) ⊆ kept 27736 (seed=2149152)
#   - drop 27788 (seed=106352171) ⊆ kept 27431 (seed=26159811)
#   - drop 27792 (seed=106443645) ⊆ kept 27477 (seed=155687776)
#   - drop 27797 (seed=2103338) ⊆ kept 27805 (seed=2102756)
#   - drop 27798 (seed=3334419) ⊆ kept 27454 (seed=3335818)
#   - drop 27799 (seed=8331170) ⊆ kept 27639 (seed=155393323)
#   - drop 27800 (seed=59991417) ⊆ kept 28042 (seed=13033698)
#   - drop 27807 (seed=4608183) ⊆ kept 27486 (seed=3468153)
#   - drop 27808 (seed=46109029) ⊆ kept 27867 (seed=118788821)
#   - drop 27817 (seed=14192609) ⊆ kept 27614 (seed=155213440)
#   - drop 27818 (seed=2185383) ⊆ kept 27688 (seed=2185374)
#   - drop 27823 (seed=155424863) ⊆ kept 27793 (seed=155190643)
#   - drop 27824 (seed=155437893) ⊆ kept 27753 (seed=85362638)
#   - drop 27826 (seed=3336487) ⊆ kept 27454 (seed=3335818)
#   - drop 27827 (seed=4603550) ⊆ kept 27497 (seed=3287194)
#   - drop 27832 (seed=3289102) ⊆ kept 27717 (seed=24242052)
#   - drop 27833 (seed=42621630) ⊆ kept 27706 (seed=3335034)
#   - drop 27840 (seed=13056504) ⊆ kept 27425 (seed=84739112)
#   - drop 27842 (seed=37070295) ⊆ kept 27494 (seed=155449065)
#   - drop 27844 (seed=155422679) ⊆ kept 27575 (seed=155398172)
#   - drop 27846 (seed=3287177) ⊆ kept 27497 (seed=3287194)
#   - drop 27847 (seed=3335111) ⊆ kept 27454 (seed=3335818)
#   - drop 27848 (seed=3335175) ⊆ kept 27425 (seed=84739112)
#   - drop 27851 (seed=6874641) ⊆ kept 27572 (seed=4604098)
#   - drop 27853 (seed=3336471) ⊆ kept 27839 (seed=3335102)
#   - drop 27855 (seed=3335063) ⊆ kept 27820 (seed=3334334)
#   - drop 27861 (seed=6310625) ⊆ kept 27533 (seed=4714029)
#   - drop 27864 (seed=155190923) ⊆ kept 27793 (seed=155190643)
#   - drop 27865 (seed=155600287) ⊆ kept 27692 (seed=155376441)
#   - drop 27868 (seed=155591670) ⊆ kept 28071 (seed=11567844)
#   - drop 27874 (seed=9525874) ⊆ kept 27885 (seed=9520554)
#   - drop 27883 (seed=46637528) ⊆ kept 28018 (seed=13056149)
#   - drop 27886 (seed=19710753) ⊆ kept 27574 (seed=155393955)
#   - drop 27890 (seed=3542028) ⊆ kept 27985 (seed=3542010)
#   - drop 27891 (seed=7156629) ⊆ kept 27734 (seed=77733632)
#   - drop 27893 (seed=3336411) ⊆ kept 27463 (seed=13056824)
#   - drop 27900 (seed=155633643) ⊆ kept 27590 (seed=147847340)
#   - drop 27901 (seed=2109055) ⊆ kept 27897 (seed=2109032)
#   - drop 27903 (seed=4590250) ⊆ kept 27915 (seed=155373199)
#   - drop 27904 (seed=155441465) ⊆ kept 27574 (seed=155393955)
#   - drop 27906 (seed=50524084) ⊆ kept 27574 (seed=155393955)
#   - drop 27907 (seed=29261837) ⊆ kept 27777 (seed=5763490)
#   - drop 27909 (seed=3338665) ⊆ kept 27461 (seed=9417386)
#   - drop 27910 (seed=4707590) ⊆ kept 27461 (seed=9417386)
#   - drop 27912 (seed=155415572) ⊆ kept 27660 (seed=13016004)
#   - drop 27917 (seed=18488301) ⊆ kept 27504 (seed=63432654)
#   - drop 27919 (seed=155602992) ⊆ kept 27425 (seed=84739112)
#   - drop 27920 (seed=3294774) ⊆ kept 27934 (seed=11569447)
#   - drop 27923 (seed=37711877) ⊆ kept 27761 (seed=155401850)
#   - drop 27925 (seed=105683978) ⊆ kept 27488 (seed=65481371)
#   - drop 27926 (seed=155415585) ⊆ kept 27770 (seed=155415564)
#   - drop 27927 (seed=7081685) ⊆ kept 27704 (seed=7081965)
#   - drop 27931 (seed=113930167) ⊆ kept 27870 (seed=1950027)
#   - drop 27932 (seed=37694332) ⊆ kept 27753 (seed=85362638)
#   - drop 27939 (seed=155443914) ⊆ kept 27793 (seed=155190643)
#   - drop 27949 (seed=4590257) ⊆ kept 27915 (seed=155373199)
#   - drop 27959 (seed=4642630) ⊆ kept 27380 (seed=9503156)
#   - drop 27960 (seed=3335070) ⊆ kept 27366 (seed=9535504)
#   - drop 27962 (seed=7200439) ⊆ kept 27753 (seed=85362638)
#   - drop 27965 (seed=12051) ⊆ kept 27895 (seed=61821257)
#   - drop 27967 (seed=9531729) ⊆ kept 27942 (seed=1971216)
#   - drop 27970 (seed=4611296) ⊆ kept 27789 (seed=2176865)
#   - drop 27972 (seed=3135990) ⊆ kept 27690 (seed=5785759)
#   - drop 27974 (seed=4804679) ⊆ kept 27942 (seed=1971216)
#   - drop 27975 (seed=40052308) ⊆ kept 27492 (seed=36182210)
#   - drop 27976 (seed=2218501) ⊆ kept 27433 (seed=15424847)
#   - drop 27978 (seed=155453097) ⊆ kept 27802 (seed=155453081)
#   - drop 27984 (seed=4658354) ⊆ kept 27935 (seed=1963736)
#   - drop 27986 (seed=40050883) ⊆ kept 27553 (seed=36182192)
#   - drop 27991 (seed=155382968) ⊆ kept 27895 (seed=61821257)
#   - drop 27992 (seed=4804156) ⊆ kept 27941 (seed=1961935)
#   - drop 27994 (seed=4827347) ⊆ kept 27433 (seed=15424847)
#   - drop 27995 (seed=4645918) ⊆ kept 27551 (seed=9333490)
#   - drop 28000 (seed=3382616) ⊆ kept 27937 (seed=1962408)
#   - drop 28002 (seed=3382256) ⊆ kept 27937 (seed=1962408)
#   - drop 28003 (seed=9529315) ⊆ kept 27935 (seed=1963736)
#   - drop 28004 (seed=49351435) ⊆ kept 27969 (seed=9531747)
#   - drop 28008 (seed=4596352) ⊆ kept 27491 (seed=4596353)
#   - drop 28009 (seed=3546434) ⊆ kept 28041 (seed=3545882)
#   - drop 28010 (seed=81511055) ⊆ kept 28041 (seed=3545882)
#   - drop 28011 (seed=81511054) ⊆ kept 28041 (seed=3545882)
#   - drop 28012 (seed=3546447) ⊆ kept 28041 (seed=3545882)
#   - drop 28013 (seed=3546421) ⊆ kept 28041 (seed=3545882)
#   - drop 28014 (seed=3604630) ⊆ kept 28041 (seed=3545882)
#   - drop 28015 (seed=3546429) ⊆ kept 28041 (seed=3545882)
#   - drop 28016 (seed=3546439) ⊆ kept 28041 (seed=3545882)
#   - drop 28017 (seed=81511053) ⊆ kept 28041 (seed=3545882)
#   - drop 28019 (seed=3604637) ⊆ kept 28041 (seed=3545882)
#   - drop 28020 (seed=155813257) ⊆ kept 28041 (seed=3545882)
#   - drop 28021 (seed=50484055) ⊆ kept 28041 (seed=3545882)
#   - drop 28022 (seed=155813246) ⊆ kept 28041 (seed=3545882)
#   - drop 28023 (seed=116103569) ⊆ kept 27870 (seed=1950027)
#   - drop 28025 (seed=3546414) ⊆ kept 28041 (seed=3545882)
#   - drop 28026 (seed=3603606) ⊆ kept 28041 (seed=3545882)
#   - drop 28027 (seed=155813251) ⊆ kept 28041 (seed=3545882)
#   - drop 28028 (seed=3289903) ⊆ kept 28034 (seed=155156494)
#   - drop 28031 (seed=3546389) ⊆ kept 28041 (seed=3545882)
#   - drop 28032 (seed=3546401) ⊆ kept 28041 (seed=3545882)
#   - drop 28036 (seed=3604187) ⊆ kept 28041 (seed=3545882)
#   - drop 28039 (seed=3604208) ⊆ kept 28041 (seed=3545882)
#   - drop 28040 (seed=3603596) ⊆ kept 28041 (seed=3545882)
#   - drop 28046 (seed=2144073) ⊆ kept 28069 (seed=2144054)
#   - drop 28058 (seed=9501890) ⊆ kept 28056 (seed=9501884)
#   - drop 28082 (seed=157579683) ⊆ kept 28330 (seed=158867787)
#   - drop 28083 (seed=157642479) ⊆ kept 28161 (seed=157641092)
#   - drop 28098 (seed=158569771) ⊆ kept 28181 (seed=193992040)
#   - drop 28112 (seed=157581544) ⊆ kept 28217 (seed=188700477)
#   - drop 28123 (seed=188724589) ⊆ kept 28093 (seed=188724580)
#   - drop 28124 (seed=172786076) ⊆ kept 28239 (seed=174546201)
#   - drop 28131 (seed=194083733) ⊆ kept 28274 (seed=194083726)
#   - drop 28138 (seed=188852620) ⊆ kept 28160 (seed=188756758)
#   - drop 28143 (seed=157653328) ⊆ kept 28151 (seed=157587950)
#   - drop 28144 (seed=194428176) ⊆ kept 28210 (seed=159174646)
#   - drop 28167 (seed=109080471) ⊆ kept 28169 (seed=157589221)
#   - drop 28175 (seed=158398815) ⊆ kept 28400 (seed=158398801)
#   - drop 28188 (seed=158603717) ⊆ kept 28400 (seed=158398801)
#   - drop 28213 (seed=178874252) ⊆ kept 28232 (seed=188678239)
#   - drop 28224 (seed=194023024) ⊆ kept 28253 (seed=194023016)
#   - drop 28243 (seed=158383149) ⊆ kept 28158 (seed=158383145)
#   - drop 28244 (seed=158398810) ⊆ kept 28400 (seed=158398801)
#   - drop 28248 (seed=188679300) ⊆ kept 28186 (seed=188679296)
#   - drop 28252 (seed=159101316) ⊆ kept 28186 (seed=188679296)
#   - drop 28254 (seed=100456594) ⊆ kept 28286 (seed=158671379)
#   - drop 28255 (seed=157581547) ⊆ kept 28186 (seed=188679296)
#   - drop 28277 (seed=188677483) ⊆ kept 28287 (seed=188677475)
#   - drop 28281 (seed=157595848) ⊆ kept 28162 (seed=157595965)
#   - drop 28282 (seed=157600403) ⊆ kept 28380 (seed=158585912)
#   - drop 28283 (seed=157607828) ⊆ kept 28400 (seed=158398801)
#   - drop 28292 (seed=157577571) ⊆ kept 28377 (seed=157577573)
#   - drop 28293 (seed=163234354) ⊆ kept 28424 (seed=188650969)
#   - drop 28301 (seed=188787597) ⊆ kept 28482 (seed=158627579)
#   - drop 28310 (seed=157638563) ⊆ kept 28122 (seed=194374170)
#   - drop 28312 (seed=158587793) ⊆ kept 28358 (seed=180415975)
#   - drop 28313 (seed=157610513) ⊆ kept 28185 (seed=157610517)
#   - drop 28315 (seed=157600390) ⊆ kept 28403 (seed=158275512)
#   - drop 28316 (seed=188965393) ⊆ kept 28210 (seed=159174646)
#   - drop 28325 (seed=158589548) ⊆ kept 28223 (seed=188623818)
#   - drop 28326 (seed=158280174) ⊆ kept 28198 (seed=158280179)
#   - drop 28327 (seed=157578876) ⊆ kept 28257 (seed=157578884)
#   - drop 28328 (seed=158612798) ⊆ kept 28467 (seed=189992045)
#   - drop 28333 (seed=158587831) ⊆ kept 28370 (seed=158281690)
#   - drop 28336 (seed=136350983) ⊆ kept 28331 (seed=157605706)
#   - drop 28337 (seed=158587865) ⊆ kept 28363 (seed=194044252)
#   - drop 28338 (seed=159736134) ⊆ kept 28234 (seed=158354492)
#   - drop 28345 (seed=158281469) ⊆ kept 28370 (seed=158281690)
#   - drop 28347 (seed=168258956) ⊆ kept 28415 (seed=188624030)
#   - drop 28349 (seed=157620920) ⊆ kept 28375 (seed=194091937)
#   - drop 28356 (seed=158589551) ⊆ kept 28353 (seed=194044254)
#   - drop 28365 (seed=158275506) ⊆ kept 28403 (seed=158275512)
#   - drop 28369 (seed=70310599) ⊆ kept 28223 (seed=188623818)
#   - drop 28373 (seed=158589543) ⊆ kept 28223 (seed=188623818)
#   - drop 28385 (seed=158585907) ⊆ kept 28380 (seed=158585912)
#   - drop 28388 (seed=158587830) ⊆ kept 28415 (seed=188624030)
#   - drop 28391 (seed=157607824) ⊆ kept 28400 (seed=158398801)
#   - drop 28394 (seed=158571071) ⊆ kept 28425 (seed=158571075)
#   - drop 28395 (seed=98661407) ⊆ kept 28128 (seed=158716248)
#   - drop 28396 (seed=158716256) ⊆ kept 28190 (seed=158345925)
#   - drop 28404 (seed=157620914) ⊆ kept 28375 (seed=194091937)
#   - drop 28407 (seed=188641628) ⊆ kept 28234 (seed=158354492)
#   - drop 28409 (seed=158589466) ⊆ kept 28481 (seed=158589476)
#   - drop 28410 (seed=158587871) ⊆ kept 28363 (seed=194044252)
#   - drop 28416 (seed=159178696) ⊆ kept 28375 (seed=194091937)
#   - drop 28417 (seed=188753533) ⊆ kept 28425 (seed=158571075)
#   - drop 28421 (seed=158612795) ⊆ kept 28403 (seed=158275512)
#   - drop 28426 (seed=157600399) ⊆ kept 28380 (seed=158585912)
#   - drop 28428 (seed=158571403) ⊆ kept 28113 (seed=158571478)
#   - drop 28429 (seed=194312038) ⊆ kept 28344 (seed=193974869)
#   - drop 28430 (seed=194023031) ⊆ kept 28253 (seed=194023016)
#   - drop 28433 (seed=158586386) ⊆ kept 28287 (seed=188677475)
#   - drop 28434 (seed=158586302) ⊆ kept 28403 (seed=158275512)
#   - drop 28435 (seed=158612797) ⊆ kept 28274 (seed=194083726)
#   - drop 28436 (seed=158716652) ⊆ kept 28401 (seed=158716989)
#   - drop 28440 (seed=158575483) ⊆ kept 28208 (seed=158348917)
#   - drop 28441 (seed=158586389) ⊆ kept 28403 (seed=158275512)
#   - drop 28442 (seed=159310917) ⊆ kept 28311 (seed=188664306)
#   - drop 28443 (seed=157638553) ⊆ kept 28122 (seed=194374170)
#   - drop 28446 (seed=158612765) ⊆ kept 28403 (seed=158275512)
#   - drop 28448 (seed=171332573) ⊆ kept 28375 (seed=194091937)
#   - drop 28449 (seed=158612801) ⊆ kept 28297 (seed=193944608)
#   - drop 28450 (seed=157600382) ⊆ kept 28403 (seed=158275512)
#   - drop 28453 (seed=157585526) ⊆ kept 28294 (seed=158704419)
#   - drop 28454 (seed=157584676) ⊆ kept 28099 (seed=157584683)
#   - drop 28455 (seed=158315410) ⊆ kept 28306 (seed=158315423)
#   - drop 28456 (seed=158585895) ⊆ kept 28234 (seed=158354492)
#   - drop 28457 (seed=158569764) ⊆ kept 28181 (seed=193992040)
#   - drop 28461 (seed=157585120) ⊆ kept 28294 (seed=158704419)
#   - drop 28465 (seed=158612761) ⊆ kept 28424 (seed=188650969)
#   - drop 28466 (seed=159039422) ⊆ kept 28536 (seed=158378208)
#   - drop 28469 (seed=157600389) ⊆ kept 28128 (seed=158716248)
#   - drop 28470 (seed=158290692) ⊆ kept 28309 (seed=158291559)
#   - drop 28473 (seed=158612799) ⊆ kept 28093 (seed=188724580)
#   - drop 28474 (seed=190135471) ⊆ kept 28185 (seed=157610517)
#   - drop 28488 (seed=158612793) ⊆ kept 28100 (seed=188612885)
#   - drop 28490 (seed=193972634) ⊆ kept 28227 (seed=193972434)
#   - drop 28491 (seed=187681886) ⊆ kept 28489 (seed=194353118)

# %% [markdown]
# Merge networks that have overlapping nodes

# %%
txn_expanded, edges_expanded, txn_final, edges_final = build_network.merge_subnetworks_by_node_overlap(
    nodes_dedup, edges_dedup,
    min_shared_nodes=1,
    progress=True,
    print_unmerged=False,  # <- only merged groups printed
    collapse=True
)
# Out:
# Merge by node-overlap (≥1): 21020 → 17864 merged subnetworks.
#   group 0: subnetwork_ids=[0, 1, 2, 32, 71, 73, 142] seeds=[3084073, 9907558, 39915271, 230658165, 230658519, 230659124, 230659444]
#   group 310: subnetwork_ids=[310, 325] seeds=[310414790, 310415405]
#   group 327: subnetwork_ids=[327, 386] seeds=[309930098, 310071274]
#   group 623: subnetwork_ids=[623, 665] seeds=[86595203, 86720131]
#   group 641: subnetwork_ids=[641, 651] seeds=[86714561, 86966335]
#   group 724: subnetwork_ids=[724, 728, 749] seeds=[224655093, 224656953, 225054971]
#   group 729: subnetwork_ids=[729, 765] seeds=[225054523, 225055156]
#   group 787: subnetwork_ids=[787, 793] seeds=[91306418, 225715271]
#   group 1014: subnetwork_ids=[1014, 1029, 1103, 1164, 1253, 1394, 1408, 1409, 1413, 1574, 1580] seeds=[94003168, 94123979, 94299895, 94370759, 94370914, 94370921, 94370929, 94370938, 94371207, 94371214, 94371216]
#   group 1019: subnetwork_ids=[1019, 1292, 1347, 1403, 1500, 1502] seeds=[94051990, 94157300, 94184658, 94189129, 94189346, 94328680]
#   group 1068: subnetwork_ids=[1068, 1342, 1474] seeds=[94372683, 94653853, 94654059]
#   group 1444: subnetwork_ids=[1444, 1487] seeds=[94123379, 94377704]
#   group 1610: subnetwork_ids=[1610, 1681, 1738, 1763, 1814, 1827, 1900, 1914, 2036] seeds=[189799148, 191107596, 191107782, 191108346, 191108947, 191108949, 191108954, 191108972, 191111249]
#   group 1617: subnetwork_ids=[1617, 1741, 1866, 1949] seeds=[54504625, 189799399, 189800868, 190005875]
#   group 1656: subnetwork_ids=[1656, 1664, 1930] seeds=[189801215, 190005963, 190006176]
#   group 1701: subnetwork_ids=[1701, 1923] seeds=[190006226, 190015197]
#   group 1770: subnetwork_ids=[1770, 1794, 1861] seeds=[20309993, 190012065, 191132692]
#   group 1774: subnetwork_ids=[1774, 1776] seeds=[131973736, 192125468]
txn_final.head(1)
# Out:
# (28542, 4)
# 17864
#    merged_subnetwork_id   txn_id  min_hop  \
# 0                     0  3084073        0
#
#                                       seeds_in_group
# 0  [3084073, 9907558, 39915271, 230658165, 230658...

# %%
print(edges_expanded.shape)
edges_expanded.head(1)
# Out:
# (12063, 7)
#    src_txn_id  dst_txn_id  src_txn_hop  dst_txn_hop  subnetwork_id  seed_txn  \
# 0     3084073   230658142            0            1              0   3084073
#
#    merged_subnetwork_id
# 0                     0

# %%
print(edges_final.shape)
print(edges_final['merged_subnetwork_id'].nunique()) # <-- Only 3254 networks have more than 2 nodes in the subnetwork (i.e. 1 edge).
edges_final.head(1)
# Out:
# (10877, 5)
# 3254
#    merged_subnetwork_id  src_txn_id  dst_txn_id  min_src_hop  min_dst_hop
# 0                     0     3084073   230658142            0            1

# %% [markdown]
# Build network summary table

# %%
summary_final = build_report.summarise_subnetworks(
    txn_expanded, edges_expanded,
    id_col="merged_subnetwork_id",   # <- merged group id from the overlap step
    sort_by="size"
)

# %%
print(len(summary_final))
summary_final.head()
# Out:
# 17864
#    merged_subnetwork_id                                            txn_ids  \
# 0                  9719  [138779422, 274995025, 288474188, 306817114, 3...
# 1                 15775  [10000476, 15254893, 17763829, 17942794, 21627...
# 2                 27202  [3093780, 4377108, 7314214, 9025948, 15410565,...
# 3                 11723  [76314770, 153388422, 154828129, 157769334, 16...
# 4                 13075  [37925917, 84313895, 84316588, 84321107, 84321...
#
#    node_count  edge_count  depth  \
# 0         186         201      9
# 1         183         182    182
# 2         157         206    104
# 3         126         128      5
# 4         121         154      6
#
#                                                seeds  seed_count  \
# 0  [306817114, 307096649, 308031465, 308871228, 3...         109
# 1                                         [46085970]           1
# 2                             [218055898, 218056365]           2
# 3  [76314770, 153388422, 154828129, 157769334, 16...          89
# 4  [84313895, 84316588, 84321107, 84321251, 84321...          67
#
#    linked_txn_count
# 0                77
# 1               182
# 2               155
# 3                37
# 4                54

# %% [markdown]
# Check the distribution of subnetworks by node count in the dataset

# %%
# 1) Pull the node counts as integers
s = pd.to_numeric(summary_final["node_count"], errors="coerce").dropna().astype(int)
n = int(s.size)

# 2) Distribution table (ascending by node_count)
dist = (
    s.value_counts()
     .sort_index()
     .rename_axis("node_count")
     .reset_index(name="count")
)
dist["pct_population"] = (dist["count"] / n * 100).round(2)
dist["cum_count"] = dist["count"].cumsum()
dist["cum_pct_population"] = (dist["cum_count"] / n * 100).round(2)

dist

# 82% of the subnetworks are composed of only 1 illicit node.
# Out:
#     node_count  count  pct_population  cum_count  cum_pct_population
# 0            1  14610         81.7800      14610             81.7800
# 1            2   2053         11.4900      16663             93.2800
# 2            3    488          2.7300      17151             96.0100
# 3            4    214          1.2000      17365             97.2100
# 4            5    120          0.6700      17485             97.8800
# 5            6     68          0.3800      17553             98.2600
# 6            7     44          0.2500      17597             98.5100
# 7            8     43          0.2400      17640             98.7500
# 8            9     26          0.1500      17666             98.8900
# 9           10     23          0.1300      17689             99.0200
# 10          11     23          0.1300      17712             99.1500
# 11          12     12          0.0700      17724             99.2200
# 12          13     13          0.0700      17737             99.2900
# 13          14     11          0.0600      17748             99.3500
# 14          15     10          0.0600      17758             99.4100
# 15          16      8          0.0400      17766             99.4500
# 16          17      7          0.0400      17773             99.4900
# 17          18      9          0.0500      17782             99.5400
# 18          19      3          0.0200      17785             99.5600
# 19          20      4          0.0200      17789             99.5800
# 20          21      1          0.0100      17790             99.5900
# 21          22      5          0.0300      17795             99.6100
# 22          23      6          0.0300      17801             99.6500
# 23          24      5          0.0300      17806             99.6800
# 24          25      3          0.0200      17809             99.6900
# 25          26      1          0.0100      17810             99.7000
# 26          27      2          0.0100      17812             99.7100
# 27          28      1          0.0100      17813             99.7100
# 28          29      2          0.0100      17815             99.7300
# 29          30      3          0.0200      17818             99.7400
# 30          31      4          0.0200      17822             99.7600
# 31          32      1          0.0100      17823             99.7700
# 32          33      1          0.0100      17824             99.7800
# 33          36      2          0.0100      17826             99.7900
# 34          37      2          0.0100      17828             99.8000
# 35          39      2          0.0100      17830             99.8100
# 36          41      1          0.0100      17831             99.8200
# 37          42      1          0.0100      17832             99.8200
# 38          45      1          0.0100      17833             99.8300
# 39          47      1          0.0100      17834             99.8300
# 40          49      1          0.0100      17835             99.8400
# 41          51      1          0.0100      17836             99.8400
# 42          52      1          0.0100      17837             99.8500
# 43          55      1          0.0100      17838             99.8500
# 44          57      1          0.0100      17839             99.8600
# 45          58      1          0.0100      17840             99.8700
# 46          61      1          0.0100      17841             99.8700
# 47          64      1          0.0100      17842             99.8800
# 48          70      1          0.0100      17843             99.8800
# 49          71      2          0.0100      17845             99.8900
# 50          72      1          0.0100      17846             99.9000
# 51          74      2          0.0100      17848             99.9100
# 52          75      2          0.0100      17850             99.9200
# 53          83      1          0.0100      17851             99.9300
# 54          86      1          0.0100      17852             99.9300
# 55          87      1          0.0100      17853             99.9400
# 56          91      1          0.0100      17854             99.9400
# 57          94      1          0.0100      17855             99.9500
# 58          99      1          0.0100      17856             99.9600
# 59         100      1          0.0100      17857             99.9600
# 60         101      1          0.0100      17858             99.9700
# 61         115      1          0.0100      17859             99.9700
# 62         121      1          0.0100      17860             99.9800
# 63         126      1          0.0100      17861             99.9800
# 64         157      1          0.0100      17862             99.9900
# 65         183      1          0.0100      17863             99.9900
# 66         186      1          0.0100      17864            100.0000

# %% [markdown]
# --------------
# ##### Export Subnetwork Tables to BigQuery
# --------------

# %%
# Define your project ID
project_id = 'extreme-torch-467913-m6'

# %%
# Save DataFrame to BigQuery
to_gbq(dataframe = txn_expanded, destination_table = 'networks.network_txn_expanded', project_id=project_id, if_exists='replace')
to_gbq(dataframe = txn_final, destination_table = 'networks.network_txn_final', project_id=project_id, if_exists='replace')
to_gbq(dataframe = edges_expanded, destination_table = 'networks.network_edges_expanded', project_id=project_id, if_exists='replace')
to_gbq(dataframe = edges_final, destination_table = 'networks.network_edges_final', project_id=project_id, if_exists='replace')
to_gbq(dataframe = summary_final, destination_table = 'networks.network_summary', project_id=project_id, if_exists='replace')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 7973.96it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10894.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10645.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 9362.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 8943.08it/s]

# %% [markdown]
# END
